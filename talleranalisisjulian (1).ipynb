# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2020.11.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.10)

# %%
pip install urlopen
# Out:
# Requirement already satisfied: urlopen in /usr/local/lib/python3.6/dist-packages (1.0.0)

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.6/dist-packages (0.8.1)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (3.0.0.post1)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.1.4)
# Requirement already satisfied: fiona in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.8.18)
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from pyproj>=2.2.0->geopandas) (2020.11.8)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (1.18.5)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (0.7.1)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.15.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (20.3.0)

# %%
import requests
import urlopen
import matplotlib.pyplot as plt
import pandas as pd
import plotly.graph_objects as go
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler
import geopandas as gpd


page = requests.get("https://coronavirus.wilkinsonpc.com.co/")
pageedad = requests.get("https://coronavirus.wilkinsonpc.com.co/casos-por-edad.html")
pagegeneral =  requests.get("https://datosmacro.expansion.com/otros/coronavirus/colombia")

# %%
page.status_code
pageedad.status_code
pagegeneral.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="es">\r\n<head>\r\n\t<meta charset="utf-8">\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\r\n\t<title>Casos de CoronaVirus en Colombia Hoy</title>\r\n\t<meta name="description" content="Conozca los casos de CoronaVirus en Colombia Hoy, por edad, sexo y por departamentos, conozca sus sintomas y recomendaciones de cuidados.">\r\n\t<meta name="keywords" content="colombia coronavirus,el coronavirus,coronavirus en colombia,coronavirus sintomas,casos coronavirus,casos de coronavirus,sintomas del coronavirus,coronavirus colombia casos,coronavirus hoy,coronavirus mapa,casos coronavirus en colombia,que es coronavirus">\r\n\t<meta name="google-site-verification" content="" />\r\n\t<meta property="fb:admins" content="683506109"/>\r\n\t<meta property="og:title" content="Casos de CoronaVirus en Colombia Hoy"/>\r\n\t<meta property="og:type" content="website"\';\r\n\t<meta property="og:url" content="https://coronavirus.wilkinsonpc.com.co/"/>\r\n\t<meta property="og:site_name" content="Coronavirus Colombia"/>\r\n\t<meta property="og:image" content="https://coronavirus.wilkinsonpc.com.co/img/coronavirus-colombia-logo-share.png"/>\r\n\t<meta property="og:locale" content="es_CO"/>\r\n\t<link rel="canonical" href="https://coronavirus.wilkinsonpc.com.co" />\r\n\r\n\t<!-- Bootstrap v3.4.1 -->\r\n\t<link rel="stylesheet" type="text/css" href="https://coronavirus.wilkinsonpc.com.co/css/bootstrap.min.css">\r\n\t<!-- Bootstrap GlyphIcons (bootstrap theme required) -->\r\n\t<link href="//netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css" rel="stylesheet">\r\n\t<!-- Dise\xc3\xb1o de las Tablas tablesorter -->\r\n\t<link rel="stylesheet" href="https://coronavirus.wilkinsonpc.com.co/css/tablesorter.theme.bootstrap.css">\r\n\t<!-- Font Awesome Free v5.13.0 -->\r\n\t<link rel="stylesheet" type="text/css" href="https://coronavirus.wilkinsonpc.com.co/css/fontawesome.free.css">\r\n\t<!-- Custom CSS -->\r\n\t<link rel="stylesheet" type="text/css" href="https://coronavirus.wilkinsonpc.com.co/css/estilos.css?version=06121721">\r\n\r\n\r\n<script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>\r\n<script>\r\n  (adsbygoogle = window.adsbygoogle || []).push({\r\n    google_ad_client: "ca-pub-6096990144436709",\r\n    enable_page_level_ads: true\r\n  });\r\n</script>\r\n\r\n\t<!-- jQuery 3.1.1 -->\r\n\t<script type="text/javascript" src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js"></script>\r\n\r\n    <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->\r\n    <!-- WARNING: Respond.js doesn\'t work if you view the page via file:// -->\r\n    <!--[if lt IE 9]>\r\n      <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\r\n      <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\r\n    <![endif]-->\r\n\r\n\t<!-- jQuery tablesorter -->\r\n\t<script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery.tablesorter/2.31.3/js/jquery.tablesorter.min.js"></script>\r\n\t<!-- jQuery tablesorter widgets (bootstrap theme required) -->\r\n\t<script type="text/javascript" src="https://mottie.github.io/tablesorter/js/jquery.tablesorter.widgets.js"></script>\r\n\t<!-- Facebook show/hide comments box -->\r\n\t<script type="text/javascript" src="https://coronavirus.wilkinsonpc.com.co/js/facebook-button-show-hide.js"></script>\r\n<!-- Global site tag (gtag.js) - Google Analytics -->\r\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-87105-21"></script>\r\n<script>\r\n  window.dataLayer = window.dataLayer || [];\r\n  function gtag(){dataLayer.push(arguments);}\r\n  gtag(\'js\', new Date());\r\n\r\n  gtag(\'config\', \'UA-87105-21\');\r\n</script>\r\n\r\n<script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" async=""></script>\r\n<script>\r\n  var OneSignal = window.OneSi ...

# %%
pageedad.content
# Out:
# b'<!DOCTYPE html>\r\n<html lang="es">\r\n<head>\r\n\t<meta charset="utf-8">\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\r\n\t<title>Casos por Edad CoronaVirus en Colombia</title>\r\n\t<meta name="description" content="Listado de casos de coronavirus en Colombia por edades, recuperados, en casa, hospitalizados, hospitalizados en cuidados intensivos y fallecidos.">\r\n\t<meta name="keywords" content="coronavirus por edad en colombia, casos coronavirus colombia">\r\n\t<meta name="google-site-verification" content="" />\r\n\t<meta property="fb:admins" content="683506109"/>\r\n\t<meta property="og:title" content="Casos por Edad CoronaVirus en Colombia"/>\r\n\t<meta property="og:type" content="website"/>\r\n\t<meta property="og:url" content="https://coronavirus.wilkinsonpc.com.co/casos-por-edad.html"/>\r\n\t<meta property="og:site_name" content="Coronavirus Colombia"/>\r\n\t<meta property="og:image" content="https://coronavirus.wilkinsonpc.com.co/img/coronavirus-colombia-logo-share.png"/>\r\n\t<meta property="og:locale" content="es_CO"/>\r\n\r\n\t<!-- Bootstrap v3.4.1 -->\r\n\t<link rel="stylesheet" type="text/css" href="https://coronavirus.wilkinsonpc.com.co/css/bootstrap.min.css">\r\n\t<!-- Bootstrap GlyphIcons (bootstrap theme required) -->\r\n\t<link href="//netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css" rel="stylesheet">\r\n\t<!-- Dise\xc3\xb1o de las Tablas tablesorter -->\r\n\t<link rel="stylesheet" href="https://coronavirus.wilkinsonpc.com.co/css/tablesorter.theme.bootstrap.css">\r\n\t<!-- Font Awesome Free v5.13.0 -->\r\n\t<link rel="stylesheet" type="text/css" href="https://coronavirus.wilkinsonpc.com.co/css/fontawesome.free.css">\r\n\t<!-- Custom CSS -->\r\n\t<link rel="stylesheet" type="text/css" href="https://coronavirus.wilkinsonpc.com.co/css/estilos.css?version=06121721">\r\n\r\n\r\n<script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>\r\n<script>\r\n  (adsbygoogle = window.adsbygoogle || []).push({\r\n    google_ad_client: "ca-pub-6096990144436709",\r\n    enable_page_level_ads: true\r\n  });\r\n</script>\r\n\r\n\t<!-- jQuery 3.1.1 -->\r\n\t<script type="text/javascript" src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js"></script>\r\n\r\n    <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->\r\n    <!-- WARNING: Respond.js doesn\'t work if you view the page via file:// -->\r\n    <!--[if lt IE 9]>\r\n      <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\r\n      <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\r\n    <![endif]-->\r\n\r\n\t<!-- jQuery tablesorter -->\r\n\t<script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery.tablesorter/2.31.3/js/jquery.tablesorter.min.js"></script>\r\n\t<!-- jQuery tablesorter widgets (bootstrap theme required) -->\r\n\t<script type="text/javascript" src="https://mottie.github.io/tablesorter/js/jquery.tablesorter.widgets.js"></script>\r\n\t<!-- Facebook show/hide comments box -->\r\n\t<script type="text/javascript" src="https://coronavirus.wilkinsonpc.com.co/js/facebook-button-show-hide.js"></script>\r\n<!-- Global site tag (gtag.js) - Google Analytics -->\r\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-87105-21"></script>\r\n<script>\r\n  window.dataLayer = window.dataLayer || [];\r\n  function gtag(){dataLayer.push(arguments);}\r\n  gtag(\'js\', new Date());\r\n\r\n  gtag(\'config\', \'UA-87105-21\');\r\n</script>\r\n\r\n<script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js" async=""></script>\r\n<script>\r\n  var OneSignal = window.OneSignal || [];\r\n  OneSignal.push(function() {\r\n    OneSignal.init({\r\n      appId: "dd336a46-d4ac-47b6-a98f-14b358ce68a9",\r\n    });\r\n  });\r\n</script>\t<script data-ad-client="ca-pub-6096990144436709" async src="https://pagead2.goog ...

# %%
pagegeneral.content
# Out:
# b'<!DOCTYPE html>\n<html lang="es" dir="ltr">\n<head>\n  <link rel="profile" href="http://www.w3.org/1999/xhtml/vocab" />\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<link rel="apple-touch-icon" sizes="114x114" href="/dm/apple-touch-icon-114x114.png" />\n<link rel="apple-touch-icon" sizes="152x152" href="/dm/apple-touch-icon-152x152.png" />\n<link rel="apple-touch-icon" sizes="76x76" href="/dm/apple-touch-icon-76x76.png" />\n<link rel="apple-touch-icon" sizes="120x120" href="/dm/apple-touch-icon-120x120.png" />\n<link rel="apple-touch-icon" sizes="60x60" href="/dm/apple-touch-icon-60x60.png" />\n<link rel="apple-touch-icon" sizes="144x144" href="/dm/apple-touch-icon-144x144.png" />\n<link rel="apple-touch-icon" sizes="72x72" href="/dm/apple-touch-icon-72x72.png" />\n<link rel="apple-touch-icon" sizes="57x57" href="/dm/apple-touch-icon-57x57.png" />\n<link rel="icon" type="image/png" sizes="32x32" href="/dm/favicon-32x32.png" />\n<link rel="icon" type="image/png" sizes="16x16" href="/dm/favicon-16x16.png" />\n<link rel="icon" type="image/png" sizes="96x96" href="/dm/favicon-96x96.png" />\n<link rel="icon" type="image/png" sizes="160x160" href="/dm/favicon-160x160.png" />\n<link rel="icon" type="image/png" sizes="196x196" href="/dm/favicon-196x196.png" />\n<meta name="msapplication-TileColor" content="#4e80c0" />\n<meta name="msapplication-TileImage" content="/dm/mstile-144x144.png" />\n<link rel="up" href="https://datosmacro.expansion.com/otros/coronavirus" />\n<link rel="next" href="https://datosmacro.expansion.com/otros/coronavirus/comoras" />\n<link rel="prev" href="https://datosmacro.expansion.com/otros/coronavirus/chipre" />\n<link rel="canonical" href="https://datosmacro.expansion.com/otros/coronavirus/colombia" />\n<link rel="alternate" hreflang="pt" href="https://pt.countryeconomy.com/outros/coronavirus/colombia" />\n<link rel="alternate" hreflang="fr" href="https://fr.countryeconomy.com/autres/coronavirus/colombie" />\n<link rel="alternate" hreflang="en" href="https://countryeconomy.com/others/coronavirus/colombia" />\n<link rel="alternate" hreflang="es" href="https://datosmacro.expansion.com/otros/coronavirus/colombia" />\n<meta name="description" content="  Colombia contabiliza, 1.334.089 personas confirmadas de coronavirus, 9.297 personas confirmadas m\xc3\xa1s que el d\xc3\xada anterior. " />\n<meta property="og:description" content="  Colombia contabiliza, 1.334.089 personas confirmadas de coronavirus, 9.297 personas confirmadas m\xc3\xa1s que el d\xc3\xada anterior. " />\n<meta property="og:image" content="https://datosmacro.expansion.com/img/flag/COg.png" />\n<meta name="twitter:site" content="@datosmacro" />\n<meta name="twitter:description" content="  Colombia contabiliza, 1.334.089 personas confirmadas de coronavirus, 9.297 personas confirmadas m\xc3\xa1s que el d\xc3\xada anterior. " />\n<meta name="twitter:image:src" content="https://datosmacro.expansion.com/img/flag/COg.png" />\n<meta property="fb:app_id" content="1436132716631029" />\n<meta property="og:site_name" content="datosmacro.com" />\n<meta property="og:type" content="article" />\n<meta property="og:url" content="https://datosmacro.expansion.com/otros/coronavirus/colombia" />\n<meta property="og:title" content="Colombia - COVID-19 - Crisis del coronavirus 2020" />\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:url" content="https://datosmacro.expansion.com/otros/coronavirus/colombia" />\n<meta name="twitter:title" content="Colombia - COVID-19 - Crisis del coronavirus 2020" />\n  <title>Colombia - COVID-19 - Crisis del coronavirus  2020 | datosmacro.com</title>\n  <link type="text/css" rel="stylesheet" href="https://datosmacro.expansion.com/sites/default/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" />\n<link type="text/css" rel="stylesheet" href="https://datosmacro.expansion.com/sites/default/fi ...

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)

# %%
#importing the BeautifulSoup library
from bs4 import BeautifulSoup

# %%
#Instatiating the BeautifulSoup Class
soup = BeautifulSoup(page.content, 'lxml')
soupedad = BeautifulSoup(pageedad.content, 'lxml')
soupgen = BeautifulSoup(pagegeneral.content, 'lxml')
#Where soup is a variable containing the HTML of the webpage

# %%
#Lets formatt it nicely, using the prettify method as contrasts as cell 3
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Casos de CoronaVirus en Colombia Hoy
#   </title>
#   <meta content="Conozca los casos de CoronaVirus en Colombia Hoy, por edad, sexo y por departamentos, conozca sus sintomas y recomendaciones de cuidados." name="description"/>
#   <meta content="colombia coronavirus,el coronavirus,coronavirus en colombia,coronavirus sintomas,casos coronavirus,casos de coronavirus,sintomas del coronavirus,coronavirus colombia casos,coronavirus hoy,coronavirus mapa,casos coronavirus en colombia,que es coronavirus" name="keywords"/>
#   <meta content="" name="google-site-verification"/>
#   <meta content="683506109" property="fb:admins"/>
#   <meta content="Casos de CoronaVirus en Colombia Hoy" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Coronavirus Colombia" property="og:site_name"/>
#   <meta content="https://coronavirus.wilkinsonpc.com.co/img/coronavirus-colombia-logo-share.png" property="og:image"/>
#   <meta content="es_CO" property="og:locale"/>
#   <link href="https://coronavirus.wilkinsonpc.com.co" rel="canonical"/>
#   <!-- Bootstrap v3.4.1 -->
#   <link href="https://coronavirus.wilkinsonpc.com.co/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <!-- Bootstrap GlyphIcons (bootstrap theme required) -->
#   <link href="//netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css" rel="stylesheet"/>
#   <!-- Diseño de las Tablas tablesorter -->
#   <link href="https://coronavirus.wilkinsonpc.com.co/css/tablesorter.theme.bootstrap.css" rel="stylesheet"/>
#   <!-- Font Awesome Free v5.13.0 -->
#   <link href="https://coronavirus.wilkinsonpc.com.co/css/fontawesome.free.css" rel="stylesheet" type="text/css"/>
#   <!-- Custom CSS -->
#   <link href="https://coronavirus.wilkinsonpc.com.co/css/estilos.css?version=06121721" rel="stylesheet" type="text/css"/>
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script>
#    (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-6096990144436709",
#     enable_page_level_ads: true
#   });
#   </script>
#   <!-- jQuery 3.1.1 -->
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript">
#   </script>
#   <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
#   <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
#   <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#       <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
#   <!-- jQuery tablesorter -->
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery.tablesorter/2.31.3/js/jquery.tablesorter.min.js" type="text/javascript">
#   </script>
#   <!-- jQuery tablesorter widgets (bootstrap theme required) -->
#   <script src="https://mottie.github.io/tablesorter/js/jquery.tablesorter.widgets.js" type="text/javascript">
#   </script>
#   <!-- Facebook show/hide comments box -->
#   <script src="https://coronavirus.wilkinsonpc.com.co/js/facebook-button-show-hide.js" type="text/javascript">
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-87105-21">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-87105-21');
#   </script>
#   <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
#   </script>
#   <script>
#    var OneSignal = window.OneSignal || [];
#   OneSignal.push(function() {
#     OneSignal.init({
#       appId: "dd336a46-d4ac-47b6-a98f-14b358ce68a9",
#     });
#   });
#   </script>
#   <script async="" data-ad-client="ca-pub-6096990144436709" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <!-- favicon -->
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#5bbad5" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <!-- cookies warning -->
#   <link href="/css/cookiealert.css" rel="stylesheet"/>
#   <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    google.charts.load('current', {'packages':['corechart']});
#       google.charts.setOnLoadCallback(drawChart);
#
#       function drawChart() {
# 		var data = google.visualization.arrayToDataTable([
# 			['Fecha', 'Fallecidos'],
# 			[new Date(2020,2,6), null],[new Date(2020,2,9), null],[new Date(2020,2,11), null],[new Date(2020,2,12), null],[new Date(2020,2,13), null],[new Date(2020,2,14), null],[new Date(2020,2,15), null],[new Date(2020,2,16), null],[new Date(2020,2,17), null],[new Date(2020,2,18), null],[new Date(2020,2,19), null],[new Date(2020,2,20), null],[new Date(2020,2,21), 1],[new Date(2020,2,22), 1],[new Date(2020,2,23), 1],[new Date(2020,2,24), null],[new Date(2020,2,25), 1],[new Date(2020,2,26), 2],[new Date(2020,2,27), null],[new Date(2020,2,28), null],[new Date(2020,2,29), 4],[new Date(2020,2,30), 4],[new Date(2020,2,31), 2],[new Date(2020,3,1), 1],[new Date(2020,3,2), 2],[new Date(2020,3,3), 6],[new Date(2020,3,4), 7],[new Date(2020,3,5), 3],[new Date(2020,3,6), 11],[new Date(2020,3,7), 4],[new Date(2020,3,8), 5],[new Date(2020,3,9), 14],[new Date(2020,3,10), 11],[new Date(2020,3,11), 20],[new Date(2020,3,12), 9],[new Date(2020,3,13), 3],[new Date(2020,3,14), 15],[new Date(2020,3,15), 4],[new Date(2020,3,16), 13],[new Date(2020,3,17), 9],[new Date(2020,3,18), 13],[new Date(2020,3,19), 13],[new Date(2020,3,20), 10],[new Date(2020,3,21), 7],[new Date(2020,3,22), 10],[new Date(2020,3,23), 9],[new Date(2020,3,24), 10],[new Date(2020,3,25), 8],[new Date(2020,3,26), 11],[new Date(2020,3,27), 9],[new Date(2020,3,28), 16],[new Date(2020,3,29), 9],[new Date(2020,3,30), 15],[new Date(2020,4,1), 21],[new Date(2020,4,2), 10],[new Date(2020,4,3), 16],[new Date(2020,4,4), 18],[new Date(2020,4,5), 20],[new Date(2020,4,6), 19],[new Date(2020,4,7), 10],[new Date(2020,4,8), 21],[new Date(2020,4,9), 17],[new Date(2020,4,10), 18],[new Date(2020,4,11), 16],[new Date(2020,4,12), 14],[new Date(2020,4,13), 16],[new Date(2020,4,14), 16],[new Date(2020,4,15), 21],[new Date(2020,4,16), 16],[new Date(2020,4,17), 13],[new Date(2020,4,18), 18],[new Date(2020,4,19), 21],[new Date(2020,4,20), 17],[new Date(2020,4,21), 23],[new Date(2020,4,22), 30],[new Date(2020,4,23), 23],[new Date(2020,4,24), 22],[new Date(2020,4,25), 23],[new Date(2020,4,26), 26],[new Date(2020,4,27), 27],[new Date(2020,4,28), 19],[new Date(2020,4,29), 31],[new Date(2020,4,30), 37],[new Date(2020,4,31), 49],[new Date(2020,5,1), 30],[new Date(2020,5,2), 40],[new Date(2020,5,3), 36],[new Date(2020,5,4), 42],[new Date(2020,5,5), 58],[new Date(2020,5,6), 60],[new Date(2020,5,7), 54],[new Date(2020,5,8), 49],[new Date(2020,5,9), 64],[new Date(2020,5,10), 61],[new Date(2020,5,11), 55],[new Date(2020,5,12), 57],[new Date(2020,5,13), 47],[new Date(2020,5,14), 75],[new Date(2020,5,15), 59],[new Date(2020,5,16), 75],[new Date(2020,5,17), 63],[new Date(2020,5,18), 86],[new Date(2020,5,19), 96],[new Date(2020,5,20), 82],[new Date(2020,5,21), 111],[new Date(2020,5,22), 73],[new Date(2020,5,23), 94],[new Date(2020,5,24), 87],[new Date(2020,5,25), 163],[new Date(2020,5,26), 157],[new Date(2020,5,27), 128],[new Date(2020,5,28), 167],[new Date(2020,5,29), 117],[new Date(2020,5,30), 111],[new Date(2020,6,1), 136],[new Date(2020,6,2), 171],[new Date(2020,6,3), 136],[new Date(2020,6,4), 165],[new Date(2020,6,5), 122],[new Date(2020,6,6), 146],[new Date(2020,6,7), 149],[new Date(2020,6,8), 168],[new Date(2020,6,9), 187],[new Date(2020,6,10), 211],[new Date(2020,6,11), 194],[new Date(2020,6,12), 188],[new Date(2020,6,13), 148],[new Date(2020,6,14), 170],[new Date(2020,6,15), 189],[new Date(2020,6,16), 215],[new Date(2020,6,17), 259],[new Date(2020,6,18), 228],[new Date(2020,6,19), 220],[new Date(2020,6,20), 193],[new Date(2020,6,21), 237],[new Date(2020,6,22), 207],[new Date(2020,6,23), 315],[new Date(2020,6,24), 287],[new Date(2020,6,25), 294],[new Date(2020,6,26), 256],[new Date(2020,6,27), 252],[new Date(2020,6,28), 298],[new Date(2020,6,29), 380],[new Date(2020,6,30), 356],[new Date(2020,6,31), 295],[new Date(2020,7,1), 225],[new Date(2020,7,2), 321],[new Date(2020,7,3), 367],[new Date(2020,7,4), 298],[new Date(2020,7,5), 309],[new Date(2020,7,6), 315],[new Date(2020,7,7), 311],[new Date(2020,7,8), 290],[new Date(202 ...
#
# 		var options = {
# 			title: 'Fallecidos por Día y Tendencia',
# 			titlePosition: 'out',
# 			titleTextStyle: {color: 'black', fontSize: 20},
# 			curveType: 'function',	// The angles of the line will be smoothed
# 			selectionMode: 'single', // only allow to select one item at once
# 			tooltip: {trigger: 'focus',isHtml:false,ignoreBounds:false}, // focus: toltip appear when mouse over
# 			focusTarget: 'category', // show all series on tooltip
# 	  		aggregationTarget: 'none', // show only one tooltip per selection
# 	  		colors:['#ED0905'],	  		backgroundColor: 'transparent',
# 			chartArea:{left:60,top:60,right:10,width:'100%',height:'80%','backgroundColor': {'fill': 'transparent','opacity': 50},},
# 			vAxis: {scaleType: 'log', title: 'FALLECIDOS AL DIA', viewWindow:{ min: 0 }, gridlines: {color: '#DBDBDB'}},
# 			hAxis: {format: 'dd/MMM', // 05/Jul
# 			gridlines: {color: '#DBDBDB'}
# 			},
# 			explorer: { actions: ['dragToZoom', 'rightClickToReset'] },
# 			pointSize:4,
# 			trendlines: { 0: {type: 'polynomial', degree: 2, visibleInLegend: false, color: 'black', opacity: 0.3, lineWidth: 10, pointShape: 'diamond', pointSize:1} },
# 	  		series: {
# 		            0: {color: '#ED0905', lineWidth: 2, pointShape: 'square'}},
# 			legend: {position: 'top', maxLines: 1,textStyle: {color: 'black'} } // legend location of series name
# 	        };
#
# 	        var chart = new google.visualization.LineChart(document.getElementById('fallecidos'));
# 	        chart.draw(data, options);
#
# 	        // ocultar lineas al hacer click en legend
# 		var columns = [];
# 		var series = {};
# 		for (var i = 0; i < data.getNumberOfColumns(); i++) {
# 			columns.push(i);
# 			if (i > 0) {
# 				series[i - 1] = {};
# 			}
# 		}
# 		google.visualization.events.addListener(chart, 'select', function () {
# 			var sel = chart.getSelection();
# 			// if selection length is 0, we deselected an element
# 			if (sel.length > 0) {
# 				// if row is undefined, we clicked on the legend
# 				if (sel[0].row === null) {
# 					var col = sel[0].column;
# 					if (columns[col] == col) {
# 						// hide the data series
# 						columns[col] = {
# 							label: data.getColumnLabel(col),
# 							type: data.getColumnType(col),
# 							calc: function () {
# 								return null;
# 							}
# 						};
# 						// grey out the legend entry
# 						options.series[col - 1].color = 'gray';
# 					} else {
# 						// show the data series
# 						columns[col] = col;
# 						options.series[col - 1].color = null;
# 					}
# 					var view = new google.visualization.DataView(data);
# 					view.setColumns(columns);
# 					chart.draw(view, options);
# 				}
# 			}
# 		});
# 	}
#   </script>
#   <script id="js">
#    $(function() {
#
# 	// show different colors for consecutive rows values
# 	$.extend($.tablesorter.defaults, {
# 		widthFixed: true,
# 		widgets : ['zebra','columns']
# 	});
# 	// tablas con datos
#
# 	$('.tabla1').tablesorter({
# 		theme : 'bootstrap',
# 		headerTemplate: '{content} {icon}',
# 		widgets    : ['zebra', 'stickyHeaders', 'columns', 'uitheme'],
# 		widgetOptions : {
# 			stickyHeaders_attachTo : '.table_box1', // or $('.wrapper')
# 		}
# 	});
#
# 	$('.tabla2').tablesorter({
# 		theme : 'bootstrap',
# 		headerTemplate: '{content} {icon}',
# 		widgets    : ['zebra', 'stickyHeaders', 'columns', 'uitheme'],
# 		widgetOptions : {
# 			stickyHeaders_attachTo : '.table_box2', // or $('.wrapper')
# 		}
# 	});
#
#
# });
#   </script>
#  </head>
#  <body>
#   <!--  facebook sdk -->
#   <div id="fb-root">
#   </div>
#   <script async="" crossorigin="anonymous" defer="" src="https://connect.facebook.net/es_LA/sdk.js#xfbml=1&amp;version=v6.0&amp;appId=1567895109902705&amp;autoLogAppEvents=1">
#   </script>
#   <!-- enable tooltip everywhere -->
#   <script>
#    $(function () {
# 	$('[data-toggle="tooltip"]').tooltip()
# })
#   </script>
#   <!-- menu navegacion -->
#   <nav class="navbar navbar-inverse navbar-fixed-top" id="navbar" role="navigation">
#    <!-- contenedor menu navegacion -->
#    <div class="container" id="navbar_container">
#     <!-- logo y boton menu mobile -->
#     <div class="navbar-header">
#      <button class="navbar-toggle navbar-left" data-target="#nav_bar_collapse" data-toggle="collapse" type="button">
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-brand" href="https://coronavirus.wilkinsonpc.com.co/">
#       <img alt="Coronavirus Colombia" border="0" src="https://coronavirus.wilkinsonpc.com.co/img/coronavirus-colombia-logo.png" title="Coronavirus Colombia" width="200"/>
#      </a>
#     </div>
#     <!-- enlaces, botones y demas -->
#     <div class="collapse navbar-collapse" id="nav_bar_collapse">
#      <ul class="nav navbar-nav">
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#" style="padding-left:35px;padding-right:5px;" title="Coronavirus Colombia Total">
#         COLOMBIA
#         <b class="caret">
#         </b>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/pruebas-realizadas-vs-casos-diarios.html">
#           PRUEBAS VS CASOS
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-confirmados.html">
#           TODOS LOS CASOS
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-dia.html" style="color:#E0B107;">
#           CASOS POR DIA
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-detalle.html" style="color:#E0B107;">
#           DETALLE POR CASO
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-fallecidos.html">
#           FALLECIDOS
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-fallecidos-hoy.html">
#           FALLECIDOS HOY
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-recuperados.html">
#           RECUPERADOS
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-recuperados-hoy.html">
#           RECUPERADOS HOY
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-departamento.html">
#           POR DEPARTAMENTO
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html">
#           POR CIUDAD
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-edad.html">
#           POR EDAD
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-mujeres-vs-hombres.html">
#           POR SEXO
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-pais-de-origen.html">
#           POR PAÍS DE ORIGEN
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/">
#           ESTADÍSTICAS
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#" style="padding-left:35px;padding-right:5px;" title="Coronavirus en el Mundo">
#         MUNDO
#         <b class="caret">
#         </b>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-confirmados-mundo.html">
#           TODOS LOS PAISES
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-fallecidos-mundo.html">
#           FALLECIDOS POR PAIS
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-mundo.html">
#           ESTADÍSTICAS
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav">
#       <li>
#        <a href="https://coronavirus.wilkinsonpc.com.co/noticias/">
#         NOTICIAS
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav">
#       <li>
#        <a href="https://coronavirus.wilkinsonpc.com.co/ayuda.html">
#         AYUDA
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right">
#       <li class="dropdown visible-lg">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#" style="padding-left:35px;padding-right:5px;color:#AD2516;" title="Patrocinado por:">
#         by:
#         <b class="caret">
#         </b>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="https://dolar.wilkinsonpc.com.co">
#           Dolar en Colombia
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </div>
#     <!-- / enlaces, botones y demas -->
#    </div>
#    <!-- / contenedor menu navegacion -->
#   </nav>
#   <!-- / menu navegacion -->
#   <script>
#    $(document).ready(function () {
# 			  $(".navbar-toggle").on("click", function () {
# 				    $(this).toggleClass("active");
# 			  });
# 		});
#   </script>
#   <!-- contenedor body -->
#   <div class="container" id="container_container" style="">
#    <div class="row">
#     <div class="col-xs-24 col-sm-24 col-md-24 col-lg-24" id="buscar_form" style="padding:20px; margin:0; background-color:#eee; border-top:1px solid #D9D9D9; border-bottom:1px solid #999;">
#      <form action="https://www.google.com/search" id="buscar_google" method="get" style="padding:0; margin:0; ">
#       <input name="sitesearch" type="hidden" value="coronavirus.wilkinsonpc.com.co"/>
#       <div class="row">
#        <div class="col-xs-24 col-sm-24 col-md-18 col-lg-24">
#         <div class="input-group input-group-lg input-large search-query">
#          <input autocomplete="on" class="form-control search" id="search_bot" name="q" placeholder="Buscar en coronavirus.wilkinsonpc.com.co" required="" type="text"/>
#          <span class="input-group-btn">
#           <button class="btn btn-default" type="submit">
#            Buscar
#           </button>
#          </span>
#         </div>
#        </div>
#       </div>
#      </form>
#     </div>
#    </div>
#    <div class="row" style="margin-bottom: 5px;">
#     <div class="hidden-xs hidden-sm" style="padding:10px;">
#      <div class="btn-group btn-group-justified">
#       <a class="btn btn-info" href="/pruebas-realizadas-vs-casos-diarios.html" style="color:#fff;" title="Pruebas vs Casos">
#        Pruebas vs Casos
#       </a>
#       <a class="btn btn-info" href="/casos-confirmados.html" style="color:#fff;" title="Detalle de Casos">
#        Detalle Casos
#       </a>
#       <a class="btn btn-info" href="/casos-por-departamento.html" style="color:#fff;" title="Casos por Departamentos">
#        Departamento
#       </a>
#       <a class="btn btn-info" href="/casos-por-ciudad.html" style="color:#fff;" title="Casos por Ciudad">
#        Ciudades
#       </a>
#       <a class="btn btn-info" href="/casos-por-edad.html" style="color:#fff;" title="Casos por Edad">
#        Edades
#       </a>
#       <a class="btn btn-info" href="/casos-mujeres-vs-hombres.html" style="color:#fff;" title="Casos por Género">
#        Género
#       </a>
#       <a class="btn btn-info" href="/noticias/" style="color:#fff;" title="Noticias del Coronavirus">
#        Noticias
#       </a>
#       <a class="btn btn-info" href="/ayuda.html" style="color:#fff;" title="Ayuda">
#        Ayuda
#       </a>
#      </div>
#     </div>
#    </div>
#    <!-- esqueleto contenido -->
#    <div class="row" style="margin-bottom: 5px;">
#     <!-- fila principal -->
#     <div class="col-xs-24 col-sm-24 col-md-16 col-lg-16">
#      <!-- columna izquierda -->
#      <!-- esqueleto contenido -->
#      <!-- seccion dolar -->
#      <div class="div_box">
#       <div class="row">
#        <div class="col-xs-24 col-sm-24 col-md-24 col-lg-24" style="padding:5px;text-align:center;">
#         <h1 class="hidden-xs hidden-sm titulo">
#          <a href="/casos-confirmados.html">
#           CASOS DE CORONAVIRUS EN COLOMBIA
#          </a>
#         </h1>
#         <h1 class="hidden-md hidden-lg titulo">
#          <a href="/casos-confirmados.html">
#           CORONAVIRUS COLOMBIA
#          </a>
#         </h1>
#         <span class="fecha_cierre">
#          <a href="/noticias/">
#           Sábado 5 de Diciembre (6pm)
#          </a>
#          <span style="color:#29921D;">
#           <i class="fas fa-head-side-mask">
#           </i>
#          </span>
#         </span>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-xs-24 col-sm-24 col-md-24 col-lg-24" style="margin:0;padding:0;text-align:center;border-bottom:1px solid #485243;border-top:1px solid #485243;">
#         <h2 class="subtitulo">
#          <i class="fas fa-house-user">
#          </i>
#          Ya terminó, fueron 160 días.
#         </h2>
#        </div>
#        <div class="col-xs-12 col-sm-8 col-md-8 col-lg-8" style="padding:10px 0 0 0;text-align:center;">
#         <h2 class="hidden-xs subtitulo">
#          <a href="/casos-confirmados.html">
#           Total Confirmados
#          </a>
#         </h2>
#         <h2 class="hidden-sm hidden-md hidden-lg subtitulo">
#          <a href="/casos-confirmados.html">
#           Total
#          </a>
#         </h2>
#         <h3 class="detalle">
#          Confirmados
#         </h3>
#         <h1 class="valor_confirm">
#          <a href="/casos-confirmados.html">
#           1,362,249
#          </a>
#          <sup class="valor">
#           <a href="/casos-por-dia.html?fecha=2020-12-05">
#            +9642
#           </a>
#          </sup>
#         </h1>
#        </div>
#        <div class="hidden-xs col-sm-1 col-md-1 col-lg-1" style="padding:10px 0 0 0;height:140px;text-align:center;border-right:1px dotted #cccccc;">
#        </div>
#        <div class="col-xs-12 col-sm-7 col-md-7 col-lg-7" style="padding:10px 0 0 0;text-align:center;">
#         <h2 class="hidden-xs subtitulo">
#          <a href="/casos-recuperados.html">
#           Casos Recuperados
#          </a>
#         </h2>
#         <h2 class="hidden-sm hidden-md hidden-lg subtitulo">
#          Recuperados
#         </h2>
#         <h3 class="detalle">
#          Dados de alta
#         </h3>
#         <h1 class="valor_recuper">
#          <a href="/casos-recuperados.html">
#           1,249,702
#          </a>
#          <sup class="valor">
#           <a href="/casos-recuperados-hoy.html">
#            +8881
#           </a>
#          </sup>
#         </h1>
#        </div>
#        <div class="hidden-xs col-sm-1 col-md-1 col-lg-1" style="padding:10px 0 0 0;height:140px;text-align:center;border-right:1px dotted #cccccc;">
#        </div>
#        <div class="col-xs-12 col-sm-7 col-md-7 col-lg-7" style="padding:10px 0 0 0;text-align:center;">
#         <h2 class="hidden-xs subtitulo">
#          <a href="/casos-fallecidos.html">
#           Casos Fallecidos
#          </a>
#         </h2>
#         <h2 class="hidden-sm hidden-md hidden-lg subtitulo">
#          Fallecidos
#         </h2>
#         <h3 class="detalle">
#          <span style="font-size: 1em; color: #000;">
#           <i class="fas fa-ribbon">
#           </i>
#          </span>
#         </h3>
#         <h1 class="valor_falleci">
#          <a href="/casos-fallecidos.html">
#           37,633
#          </a>
#          <sup class="valor">
#           <a href="/casos-fallecidos-hoy.html">
#            +166
#           </a>
#          </sup>
#         </h1>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-sm-24 col-md-24 col-lg-24 hidden-xs" style="margin:0;padding:0;text-align:center;border-bottom:1px solid #E0B107;border-top:1px solid #E0B107;">
#         <h2 class="subtitulo">
#          Casos Activos
#         </h2>
#        </div>
#        <div class="col-xs-12 col-sm-8 col-md-8 col-lg-8" style="padding:10px 0 0 0;text-align:center;">
#         <h2 class="subtitulo">
#          Casa
#         </h2>
#         <h3 class="detalle">
#          En Observación
#         </h3>
#         <h1 class="valor_casa">
#          51,527
#          <sup class="valor">
#           <a href="">
#            +9260
#           </a>
#          </sup>
#         </h1>
#        </div>
#        <div class="hidden-xs col-sm-1 col-md-1 col-lg-1" style="padding:10px 0 0 0;height:140px;text-align:center;border-right:1px dotted #cccccc;">
#        </div>
#        <div class="col-xs-12 col-sm-7 col-md-7 col-lg-7" style="padding:10px 0 0 0;text-align:center;">
#         <h2 class="subtitulo">
#          Hospital
#         </h2>
#         <h3 class="detalle">
#          En Observación
#         </h3>
#         <h1 class="valor_hospital">
#          17,790
#          <sup class="valor">
#           <a href="">
#            +379
#           </a>
#          </sup>
#         </h1>
#        </div>
#        <div class="hidden-xs col-sm-1 col-md-1 col-lg-1" style="padding:10px 0 0 0;height:140px;text-align:center;border-right:1px dotted #cccccc;">
#        </div>
#        <div class="col-xs-12 col-sm-7 col-md-7 col-lg-7" style="padding:10px 0 0 0;text-align:center;">
#         <h2 class="subtitulo">
#          Críticos
#         </h2>
#         <h3 class="detalle">
#          Terapia Intensiva
#         </h3>
#         <h1 class="valor_critico">
#          2,388
#          <sup class="valor">
#           <a href="">
#            +3
#           </a>
#          </sup>
#         </h1>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-xs-24 col-sm-24 col-md-24 col-lg-24" style="margin:0;padding:0;text-align:center;border-bottom:1px solid #798A71;border-top:1px solid #798A71;">
#         <h2 class="subtitulo">
#          Tipo de Contagio
#         </h2>
#        </div>
#        <div class="col-xs-12 col-sm-8 col-md-8 col-lg-8" style="padding:10px 0 0 0;text-align:center;">
#         <h2 class="subtitulo">
#          Importado
#         </h2>
#         <h3 class="detalle">
#          Contagia en otro país
#         </h3>
#         <h1 class="valor_importado">
#          916
#          <sup class="valor">
#           <a href="">
#            +0
#           </a>
#          </sup>
#         </h1>
#        </div>
#        <div class="hidden-xs col-sm-1 col-md-1 col-lg-1" style="padding:10px 0 0 0;height:140px;text-align:center;border-right:1px dotted #cccccc;">
#        </div>
#        <div class="col-xs-12 col-sm-7 col-md-7 col-lg-7" style="padding:10px 0 0 0;text-align:center;">
#         <h2 class="subtitulo">
#          Relacionado
#         </h2>
#         <h3 class="detalle">
#          Contagia en Colombia
#         </h3>
#         <h1 class="valor_relacionado">
#          128,321
#          <sup class="valor">
#           <a href="">
#            +0
#           </a>
#          </sup>
#         </h1>
#        </div>
#        <div class="hidden-xs col-sm-1 col-md-1 col-lg-1" style="padding:10px 0 0 0;height:140px;text-align:center;border-right:1px dotted #cccccc;">
#        </div>
#        <div class="col-xs-12 col-sm-7 col-md-7 col-lg-7" style="padding:10px 0 0 0;text-align:center;">
#         <h2 class="subtitulo">
#          En Estudio
#         </h2>
#         <h3 class="detalle">
#          Se investiga el origen
#         </h3>
#         <h1 class="valor_estudio">
#          1,233,012
#          <sup class="valor">
#           <a href="">
#            +9642
#           </a>
#          </sup>
#         </h1>
#        </div>
#        <div class="visible-xs col-xs-12" style="padding:10px 0 0 0;text-align:center; background-color:#F9F9F9; border: 1px dashed #666; min-height:135px;">
#         <h2 class="subtitulo">
#          Descartados
#         </h2>
#         <h3 class="detalle">
#          +21703
#         </h3>
#         <h1 class="valor_descartado">
#          3,885,964
#         </h1>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-xs-24" style="padding:10px;">
#         <p>
#          <i>
#           Fuente: INS - Ministerio de Salud
#          </i>
#         </p>
#         <p>
#          En las últimas 24 horas se procesaron
#          <b>
#           31,345
#          </b>
#          pruebas de las cuales se han descartado
#          <b>
#           21,703
#          </b>
#          . Esto representa una disminución de 125 pruebas, ya que ayer se procesaron
#          <b>
#           31,470
#          </b>
#          . En el global de pruebas realizadas, se han hecho un total de
#          <b>
#           5,248,213
#          </b>
#          hasta la fecha, de las cuales se han descartado
#          <b>
#           3,885,964
#          </b>
#          pruebas. Basado en estas cifras, la tasa de contagio de hoy se encuentra en
#          <b>
#           30.76%
#          </b>
#          y la tasa de contagio total en
#          <b>
#           25.96%
#          </b>
#         </p>
#        </div>
#       </div>
#       <div class="addthis_inline_share_toolbox" style="padding:15px;">
#       </div>
#       <div style="text-align:center; margin:5px 0;">
#        <script type="text/javascript">
#         <!--
# google_ad_client = "ca-pub-7363809219244122";
# google_ad_width = 468;
# google_ad_height = 60;
# //-->
#        </script>
#        <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#        </script>
#        <script>
#         var _comscore = _comscore || [];
#   _comscore.push({ c1: "8", c2: "14880948" ,c3: "3" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#        </script>
#        <noscript>
#         <img src="https://b.scorecardresearch.com/p?c1=8&amp;c2=14880948&amp;c3=3&amp;c15=&amp;cv=2.0&amp;cj=1"/>
#        </noscript>
#        <script id="navegg" src="//tag.navdmp.com/tm18475.js" type="text/javascript">
#        </script>
#       </div>
#       <div class="row">
#        <div class="col-xs-24" style="padding:10px;text-align:justify;">
#         <div>
#          Debido a la importancia de la gráfica de los casos fallecidos, hemos decidido destacarla y ponerla en escala logarítmica, así como acompañarla de una línea de tendencia polinómica, para reconocer aún mejor los datos.
#         </div>
#         <div class="fallecidos" id="fallecidos" style="width: 100%; height: 400px;">
#         </div>
#         <p class="hidden-xs hidden-sm notas_pie_tablas">
#          <i class="fas fa-lightbulb">
#          </i>
#          Haz click en los puntos del gráfico para ver detalles. Puedes hacer click y arrastrar para hacer zoom, para salir haz click derecho sobre el gráfico.
#         </p>
#         <p class="hidden-md hidden-lg notas_pie_tablas">
#          <i class="fas fa-lightbulb">
#          </i>
#          Toca los puntos del grafico para ver detalles. Puedes hacer zoom con los dedos.
#         </p>
#        </div>
#        <div class="hidden-xs col-sm-24" style="padding:10px;text-align:justify;">
#         <p>
#          Hoy (
#          <a href="/casos-por-dia.html?fecha=2020-12-05">
#           Sábado 5 de Diciembre
#          </a>
#          ) se suman
#          <b>
#           9,642
#          </b>
#          nuevos casos de personas que dieron positivo a la prueba del coronavirus. Comparado con el reporte del día anterior, tuvo un incremento de 357 casos (9,285 ayer), por lo que el total de casos positivos del COVID-19 en Colombia llega a
#          <b>
#           1,362,249
#          </b>
#          .
#         </p>
#         <p>
#          El último caso se reporta en la ciudad de BUCARAMANGA (SANTANDER), al paciente aún se le está estudiando para conocer como adquirió el coronavirus, si se infectó en otro país o lo adquirió de forma local. Es un hombre de 38 años, que por presentar un cuadro infeccioso estable, se encuentra en su casa bajo monitoreo médico. Empezó a manifestar síntomas de la enfermedad desde el 15 de Noviembre.
#         </p>
#         <p>
#          En el caso de las
#          <b>
#           9,642
#          </b>
#          nuevas personas que ingresan hoy al histórico  de casos con covid-19, su condición es esta: se mantienen
#          <b>
#           379
#          </b>
#          hospitalizados,
#          <b>
#           3
#          </b>
#          luchan por su vida en la unidad de cuidados intensivos (UCI) y finalmente
#          <b>
#           9,260
#          </b>
#          (96.04%) personas se reportan en casa, estables pero bajo monitoreo médico.
#         </p>
#         <p>
#          De los nuevos contagiados,  y
#          <b>
#           9,642
#          </b>
#          se encuentran en estudio para determinar como ocurrió el contagio.
#         </p>
#         <p>
#          Los casos confirmados por el Ministerio de Salud por departamentos se registraron así: BOGOTA (
#          <b>
#           3158
#          </b>
#          ), ANTIOQUIA (
#          <b>
#           1487
#          </b>
#          ), VALLE (
#          <b>
#           848
#          </b>
#          ), CUNDINAMARCA (
#          <b>
#           451
#          </b>
#          ), NORTE SANTANDER (
#          <b>
#           437
#          </b>
#          ), SANTANDER (
#          <b>
#           400
#          </b>
#          ), RISARALDA (
#          <b>
#           323
#          </b>
#          ), TOLIMA (
#          <b>
#           269
#          </b>
#          ), CALDAS (
#          <b>
#           251
#          </b>
#          ), CARTAGENA (
#          <b>
#           248
#          </b>
#          ), BARRANQUILLA (
#          <b>
#           245
#          </b>
#          ), BOYACA (
#          <b>
#           224
#          </b>
#          ), NARIÑO (
#          <b>
#           208
#          </b>
#          ), QUINDIO (
#          <b>
#           197
#          </b>
#          ), HUILA (
#          <b>
#           147
#          </b>
#          ), STA MARTA D.E. (
#          <b>
#           113
#          </b>
#          ), ATLANTICO (
#          <b>
#           88
#          </b>
#          ), GUAJIRA (
#          <b>
#           80
#          </b>
#          ), META (
#          <b>
#           79
#          </b>
#          ), CAQUETA (
#          <b>
#           54
#          </b>
#          ), BOLIVAR (
#          <b>
#           41
#          </b>
#          ), CAUCA (
#          <b>
#           39
#          </b>
#          ), PUTUMAYO (
#          <b>
#           38
#          </b>
#          ), CASANARE (
#          <b>
#           36
#          </b>
#          ), CESAR (
#          <b>
#           36
#          </b>
#          ), MAGDALENA (
#          <b>
#           35
#          </b>
#          ), SUCRE (
#          <b>
#           32
#          </b>
#          ), ARAUCA (
#          <b>
#           25
#          </b>
#          ), SAN ANDRES (
#          <b>
#           20
#          </b>
#          ), CHOCO (
#          <b>
#           15
#          </b>
#          ), CORDOBA (
#          <b>
#           12
#          </b>
#          ), VICHADA (
#          <b>
#           2
#          </b>
#          ), AMAZONAS (
#          <b>
#           2
#          </b>
#          ), GUAVIARE (
#          <b>
#           1
#          </b>
#          ), GUAINIA (
#          <b>
#           1
#          </b>
#          ).
#         </p>
#         <p>
#          Con respecto al género, de los
#          <b>
#           9,642
#          </b>
#          positivos,
#          <b>
#           5162
#          </b>
#          son mujeres y
#          <b>
#           4480
#          </b>
#          son hombres, discriminados así:
#         </p>
#         <ul>
#          <li>
#           <b>
#            241
#           </b>
#           niños hasta los 9 años.
#          </li>
#          <li>
#           <b>
#            553
#           </b>
#           jóvenes entre los 10 y los 19 años.
#          </li>
#          <li>
#           <b>
#            2146
#           </b>
#           adultos jóvenes hasta los 29 años.
#          </li>
#          <li>
#           <b>
#            2211
#           </b>
#           adultos hasta los 39 años.
#          </li>
#          <li>
#           <b>
#            1655
#           </b>
#           adultos hasta los 49 años.
#          </li>
#          <li>
#           <b>
#            1360
#           </b>
#           adultos hasta los 59 años.
#          </li>
#          <li>
#           <b>
#            830
#           </b>
#           adultos mayores hasta los 69 años.
#          </li>
#          <li>
#           <b>
#            400
#           </b>
#           adultos mayores hasta los 79 años.
#          </li>
#          <li>
#           <b>
#            246
#           </b>
#           adultos mayores de 80 o más años.
#          </li>
#         </ul>
#         <p>
#          Hoy se suman a la lista de fallecidos
#          <a href="/casos-fallecidos-hoy.html">
#           <b>
#            166
#           </b>
#           personas
#          </a>
#          (55 mujeres y 111 hombres), para un total de
#          <b>
#           37,633
#          </b>
#          hasta la fecha, lo que significa una tasa de mortalidad del
#          <b>
#           2.8%
#          </b>
#          sobre el total de positivos.
#         </p>
#         <p>
#          Gracias a Dios muchos superan el covid-19, hoy también se informa sobre la recuperación de
#          <b>
#           8,881
#          </b>
#          pacientes que han superado la infección, han dado negativo a nuevas pruebas para COVID-19, por el momento lo han logrado unas
#          <b>
#           1,249,702
#          </b>
#          personas, el
#          <b>
#           91.7%
#          </b>
#          del total de positivos.
#         </p>
#         <p>
#          Novedad en recuperados: 169 casos, así: "76138, 200223, 253428, 290706, 322803, 333860, 410446, 496761, 502386, 522132, 529945, 532699, 543843, 543899, 543931, 543977, 567877, 568288, 568292, 568599, 568638, 568708, 568839, 568946, 569076, 569398, 569399, 569583, 569757, 569787, 569842, 569939, 570053, 570055, 570156, 570157, 570272, 570280, 570365, 570367, 570374, 570645, 570646, 579979, 580143, 637749, 710957, 799057, 834137, 860254, 947056, 996071, 1003687, 1030209, 1062770, 1065633, 1111112, 1118184, 1131173, 1134290, 1141060, 1141328, 1144134, 1146586, 1155103, 1173447, 1177205, 1177719, 1179228, 1181671, 1186042, 1189715, 1196805, 1199423, 1201416, 1202865, 1204056, 1205008, 1206013, 1206251, 1208609, 1208780, 1208817, 1209170, 1209296, 1210664, 1211268, 1212640, 1213271, 1216248, 1216428, 1217330, 1220764, 1222567, 1223105, 1223184, 1223637, 1226899, 1227941, 1228025, 1232501, 1234659, 1234709, 1235235, 1235639, 1237153, 1237494, 1237724, 1238066, 1238195, 1243783, 1244041, 1245925, 1246530, 1247179, 1247187, 1247254, 1249218, 1249400, 1249963, 1251001, 1251193, 1251471, 1252182, 1252788, 1252832, 1253307, 1253639, 1253928, 1254022, 1254090, 1257389, 1257623, 1258198, 1258297, 1258786, 1259327, 1261239, 1261876, 1264132, 1264921, 1265160, 1265298, 1266005, 1266588, 1266670, 1266694, 1268079, 1273101, 1274166, 1274487, 1275082, 1275085, 1275559, 1278558, 1284265, 1290852, 1294879, 1303426, 1303904, 1303974, 1307285, 1308279, 1310043, 1311915, 1319878, 1324827, 1342414, 1343197" que fueron reportados como recuperados anteriormente, su condición ahora se reporta como: "Casa, Fallecido No Covid, Fallecido, Casa, Casa, Casa, Fallecido No Covid, Casa, Fallecido No Covid, Fallecido, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Casa, Fallecido No Covid, Fallecido No Covid, Fallecido, Hospital UCI, Fallecido, Fallecido No Covid, Fallecido, Fallecido No Covid, Fallecido No Covid, Fallecido, Fallecido No Covid, Fallecido, Fallecido, Fallecido, Fallecido, Fallecido, Fallecido, Fallecido, Fallecido, Fallecido No Covid, Hospital UCI, Fallecido, Fallecido, Hospital UCI, Fallecido, Fallecido No Covid, Hospital UCI, Fallecido, Hospital UCI, Hospital UCI, Fallecido No Covid, Fallecido No Covid, Fallecido, Fallecido, Fallecido, Hospital UCI, Fallecido, Fallecido, Hospital UCI, Hospital UCI, Fallecido, Fallecido No Covid, Fallecido, Hospital UCI, Hospital UCI, Hospital UCI, Fallecido, Fallecido, Hospital UCI, Fallecido No Covid, Hospital UCI, Fallecido, Fallecido, Hospital UCI, Hospital UCI, Hospital UCI, Fallecido, Fallecido, Fallecido, Hospital UCI, Hospital UCI, Hospital UCI, Hospital UCI, Hospital UCI, Fallecido No Covid, Hospital UCI, Hospital UCI, Fallecido, Hospital UCI, Hospital UCI, Hospital UCI, Fallecido, Hospital UCI, Fallecido, Fallecido, Fallecido, Hospital UCI, Hospital UCI, Fallecido, Hospital UCI, Fallecido, Hospital UCI, Fallecido, Hospital UCI, Fallecido, Fallecido, Fallecido, Hospital UCI, Hospital UCI, Fallecido, Hospital UCI, Hospital UCI, Hospital UCI, Hospital UCI, Hospital UCI, Fallecido, Fallecido, Fallecido, Fallecido, Hospital UCI, Hospital UCI, Hospital UCI, Hospital UCI, Fallecido No Covid, Hospital UCI, Hospital UCI, Fallecido, Hospital UCI, Fallecido, Fallecido, Fallecido, Hospital UCI, Hospital UCI, Hospital UCI, Hospital UCI, Fallecido, Hospital UCI, Fallecido, Hospital UCI, Fallecido, Fallecido, Fallecido, Fallecido, Fallecido" respectivamente, por lo que el acumulado de recuperados que con los
#          <b>
#           8,881
#          </b>
#          nuevos de hoy debería estar en
#          <b>
#           1,249,871
#          </b>
#          , disminuye a
#          <b>
#           1,249,702
#          </b>
#          .
#         </p>
#         <p>
#          Saber más de los 9,642 nuevos
#          <a href="/casos-por-dia.html?fecha=2020-12-05">
#           casos del Sábado 5 de Diciembre
#          </a>
#         </p>
#         <p>
#          No nos cansaremos de recomendar a todos nuestros visitantes, que extremen sus medidas de aseo, dentro y fuera del hogar, por favor lea cuidadosamente nuestra guía sobre "
#          <a href="https://coronavirus.wilkinsonpc.com.co/ayuda.html" style="text-decoration:underline;">
#           Cómo protegerse del CoronaVirus
#          </a>
#          ". Del
#          <b>
#           cuidado de tu salud
#          </b>
#          dependerá
#          <b>
#           la vida de otros
#          </b>
#          .
#         </p>
#        </div>
#       </div>
#      </div>
#      <!-- anuncio -->
#      <div class="row">
#       <div class="col-xs-24">
#        <div style="text-align:center; margin:5px 0;">
#         <script type="text/javascript">
#          <!--
# google_ad_client = "ca-pub-7363809219244122";
# google_ad_width = 468;
# google_ad_height = 60;
# //-->
#         </script>
#         <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#         </script>
#         <script>
#          var _comscore = _comscore || [];
#   _comscore.push({ c1: "8", c2: "14880948" ,c3: "3" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#         </script>
#         <noscript>
#          <img src="https://b.scorecardresearch.com/p?c1=8&amp;c2=14880948&amp;c3=3&amp;c15=&amp;cv=2.0&amp;cj=1"/>
#         </noscript>
#         <script id="navegg" src="//tag.navdmp.com/tm18475.js" type="text/javascript">
#         </script>
#        </div>
#       </div>
#      </div>
#      <!-- \ anuncio -->
#      <!-- seccion detalle departamentos -->
#      <div class="div_box">
#       <div class="row" style="margin-bottom: 5px;">
#        <div class="col-xs-24 col-sm-24 col-md-24 col-lg-12" style="padding:5px;">
#         <div id="secciones_body">
#          <p class="titulo" title="">
#           <a href="/casos-por-ciudad.html">
#            Casos por Ciudad
#           </a>
#           <i class="fas fa-external-link-alt">
#           </i>
#          </p>
#          <p class="table_up_tip">
#           <i class="fas fa-lightbulb">
#           </i>
#           Click en los encabezados para ordenar.
#          </p>
#          <div class="table_box1">
#           <table border="0" class="tabla1">
#            <thead>
#             <tr>
#              <td>
#               Ciudad
#              </td>
#              <td>
#               Casos
#              </td>
#             </tr>
#            </thead>
#            <tbody>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ABEJORRAL_5002">
#                ABEJORRAL
#               </a>
#              </td>
#              <td style="text-align:center;">
#               96
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ABREGO_54003">
#                ABREGO
#               </a>
#              </td>
#              <td style="text-align:center;">
#               96
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ABRIAQUI_5004">
#                ABRIAQUI
#               </a>
#              </td>
#              <td style="text-align:center;">
#               23
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ACACIAS_50006">
#                ACACIAS
#               </a>
#              </td>
#              <td style="text-align:center;">
#               2380
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ACANDI_27006">
#                ACANDI
#               </a>
#              </td>
#              <td style="text-align:center;">
#               97
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ACEVEDO_41006">
#                ACEVEDO
#               </a>
#              </td>
#              <td style="text-align:center;">
#               121
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ACHI_13006">
#                ACHI
#               </a>
#              </td>
#              <td style="text-align:center;">
#               69
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGRADO_41013">
#                AGRADO
#               </a>
#              </td>
#              <td style="text-align:center;">
#               80
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUA DE DIOS_25001">
#                AGUA DE DIOS
#               </a>
#              </td>
#              <td style="text-align:center;">
#               103
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUACHICA_20011">
#                AGUACHICA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               2309
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUADAS_17013">
#                AGUADAS
#               </a>
#              </td>
#              <td style="text-align:center;">
#               133
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUADA_68013">
#                AGUADA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               7
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUAZUL_85010">
#                AGUAZUL
#               </a>
#              </td>
#              <td style="text-align:center;">
#               450
#              </td>
#             </tr>
# ...
#                CORDOBA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               28486
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=CUNDINAMARCA">
#                CUNDINAMARCA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               54753
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=GUAINIA">
#                GUAINIA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               1210
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=GUAJIRA">
#                GUAJIRA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               12357
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=GUAVIARE">
#                GUAVIARE
#               </a>
#              </td>
#              <td style="text-align:center;">
#               1863
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=HUILA">
#                HUILA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               30870
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=MAGDALENA">
#                MAGDALENA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               6802
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=META">
#                META
#               </a>
#              </td>
#              <td style="text-align:center;">
#               29074
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=NARIÑO">
#                NARIÑO
#               </a>
#              </td>
#              <td style="text-align:center;">
#               26186
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=NORTE SANTANDER">
#                NORTE SANTANDER
#               </a>
#              </td>
#              <td style="text-align:center;">
#               30733
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=PUTUMAYO">
#                PUTUMAYO
#               </a>
#              </td>
#              <td style="text-align:center;">
#               5103
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=QUINDIO">
#                QUINDIO
#               </a>
#              </td>
#              <td style="text-align:center;">
#               18179
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=RISARALDA">
#                RISARALDA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               24619
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=SAN ANDRES">
#                SAN ANDRES
#               </a>
#              </td>
#              <td style="text-align:center;">
#               2239
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=SANTANDER">
#                SANTANDER
#               </a>
#              </td>
#              <td style="text-align:center;">
#               55434
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=STA MARTA D.E.">
#                STA MARTA D.E.
#               </a>
#              </td>
#              <td style="text-align:center;">
#               14279
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=SUCRE">
#                SUCRE
#               </a>
#              </td>
#              <td style="text-align:center;">
#               16714
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=TOLIMA">
#                TOLIMA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               31353
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=VALLE">
#                VALLE
#               </a>
#              </td>
#              <td style="text-align:center;">
#               112671
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=VAUPES">
#                VAUPES
#               </a>
#              </td>
#              <td style="text-align:center;">
#               1123
#              </td>
#             </tr>
#             <tr>
#              <td>
#               <a href="/casos-por-departamento.html?d=VICHADA">
#                VICHADA
#               </a>
#              </td>
#              <td style="text-align:center;">
#               933
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col-xs-24 col-sm-24 col-md-24 col-lg-12" style="padding:5px;">
#         <div id="secciones_body" style="padding:10px;text-align:center;">
#          <p class="titulo">
#           <a href="/casos-por-edad.html">
#            Por edad y género
#           </a>
#           <i class="fas fa-external-link-alt">
#           </i>
#          </p>
#         </div>
#        </div>
#        <div class="col-xs-24 col-sm-24 col-md-24 col-lg-12" style="padding:5px;">
#         <div id="secciones_body" style="padding:10px;text-align:center;">
#          <p class="titulo">
#           <a href="/casos-por-pais-de-origen.html">
#            Por país de procedencia
#           </a>
#           <i class="fas fa-external-link-alt">
#           </i>
#          </p>
#         </div>
#        </div>
#       </div>
#       <div style="clear:both;">
#       </div>
#       <!-- FIN seccion -->
#      </div>
#      <!-- seccion comentarios facebook -->
#      <div class="row" style="margin-bottom:5px;">
#       <div class="col-xs-4 col-sm-4 col-sm-offset-1 col-md-5 col-md-offset-1 col-lg-7 col-lg-offset-1">
#        <hr class="difum"/>
#       </div>
#       <div class="col-xs-16 col-sm-14 col-md-12 col-lg-8" id="mensajes_fb_boton">
#        <button class="btn btn-default" id="toggler" onclick="showme('comentarios', this.id);" style="font-weight:bold;background-color:#EFEFEF;color:#000;" type="button">
#         <i class="fab fa-facebook-square">
#         </i>
#         VER COMENTARIOS (
#         <fb:comments-count href="https://coronavirus.wilkinsonpc.com.co/">
#         </fb:comments-count>
#         )
#         <i class="fa fa-chevron-down">
#         </i>
#        </button>
#       </div>
#       <div class="col-xs-4 col-sm-4 col-md-5 col-lg-7">
#        <hr class="difum"/>
#       </div>
#      </div>
#      <div class="div_box" id="comentarios" style="display:none;">
#       <!-- comentarios facebook -->
#       <div class="row">
#        <div class="col-xs-24" id="mensajes_fb">
#         <div class="advertencia">
#          <i>
#           Se prohíben las publicaciones donde se oferten productos y/o servicios,
#           <b>
#            fake news
#           </b>
#           , temas políticos y cualquier otro que genere molestias y divisiones, por lo que se exige respeto y tolerancia entre usuarios, cualquier falta será penalizada con el bloqueo del usuario y/o eliminación del mensaje.
#          </i>
#         </div>
#         <div class="fb-comments mensajes" data-href="https://coronavirus.wilkinsonpc.com.co/" data-numposts="10" data-order-by="reverse_time" data-width="100%">
#         </div>
#        </div>
#       </div>
#       <!-- \ comentarios facebook -->
#      </div>
#      <!-- \ seccion comentarios facebook -->
#      <!-- esqueleto contenido -->
#     </div>
#     <!-- /columna izquierda -->
#     <div class="col-xs-24 col-sm-24 col-md-8 col-lg-8">
#      <!-- columna derecha -->
#      <!-- esqueleto contenido -->
#      <div class="onesignal-customlink-container">
#      </div>
#      <!-- anuncio -->
#      <div class="row">
#       <div class="col-xs-24">
#        <div style="text-align:center; padding:5px;">
#         <script type="text/javascript">
#          <!--
# google_ad_client = "ca-pub-7363809219244122";
# google_ad_width = 300;
# google_ad_height = 250;
# //-->
#         </script>
#         <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#         </script>
#         <script>
#          var _comscore = _comscore || [];
#   _comscore.push({ c1: "8", c2: "14880948" ,c3: "3" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#         </script>
#         <noscript>
#          <img src="https://b.scorecardresearch.com/p?c1=8&amp;c2=14880948&amp;c3=3&amp;c15=&amp;cv=2.0&amp;cj=1"/>
#         </noscript>
#         <script id="navegg" src="//tag.navdmp.com/tm18475.js" type="text/javascript">
#         </script>
#        </div>
#       </div>
#      </div>
#      <!-- \ anuncio -->
#      <div class="div_box" style="margin:0 5px;">
#       <div class="row">
#        <div class="col-xs-24" style="padding:10px; text-align:center;">
#         <h1 class="titulo">
#          <a href="/casos-confirmados-mundo.html">
#           CASOS EN EL MUNDO
#          </a>
#         </h1>
#         <span class="fecha_cierre" style="text-align:center;">
#          Actualizado el Domingo 6 de Diciembre (2pm)
#         </span>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <h1 class="valor_confirm">
#          <a href="/casos-confirmados-mundo.html">
#           67,242,622
#          </a>
#          <span style="font-size: 0.6em; color: #666;">
#           <i class="fas fa-search-plus">
#           </i>
#          </span>
#         </h1>
#         <hr class="title"/>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <h2 class="subtitulo">
#          Recuperados
#         </h2>
#         <h1 class="valor_recuper">
#          <a href="/casos-confirmados-mundo.html">
#           46,013,853
#          </a>
#         </h1>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <h2 class="subtitulo">
#          Fallecidos
#         </h2>
#         <h1 class="valor_falleci">
#          <a href="/casos-confirmados-mundo.html">
#           1,539,914
#          </a>
#         </h1>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <h2 class="subtitulo">
#          Críticos*
#         </h2>
#         <h1 class="valor_critico">
#          <a href="/casos-confirmados-mundo.html">
#           105,937
#          </a>
#          *
#         </h1>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <h2 class="subtitulo">
#          Activos
#         </h2>
#         <h1 class="valor_casa">
#          <a href="/casos-confirmados-mundo.html">
#           19,688,855
#          </a>
#         </h1>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <p>
#          * Hacen parte del total de casos activos pero se encuentran en condición delicada de salud.
#         </p>
#        </div>
#       </div>
#      </div>
#      <!-- esqueleto contenido -->
#     </div>
#     <!-- /columna derecha -->
#    </div>
#    <!-- /fila principal -->
#    <!-- esqueleto contenido -->
#    <!-- seccion enlaces noticias -->
#    <div class="div_box">
#     <div class="row" style="margin-bottom: 5px;">
#      <div class="col-xs-24 col-sm-24 col-md-24 col-lg-24" style="padding:15px;">
#       <div class="news_list_last12">
#        <p alt="NOTICIAS" title="NOTICIAS">
#         NOTICIAS
#        </p>
#        <ul>
#         <li>
#          <a href="/noticias/autoridades-entregan-nuevo-reporte-de-contagios-por-coronavirus-2020.html">
#           Autoridades entregan nuevo reporte de contagios por coronavirus
#          </a>
#         </li>
#         <li>
#          <a href="/noticias/nuevo-informe-sube-a-1-352-607-contagios-por-coronavirus-en-colombia-2020.html">
#           Nuevo informe, sube a 1,352,607 contagios por coronavirus en Colombia
#          </a>
#         </li>
#         <li>
#          <a href="/noticias/casos-de-coronavirus-en-colombia-llegan-a-1-343-322-2020.html">
#           Casos de coronavirus en Colombia llegan a 1,343,322
#          </a>
#         </li>
#         <li>
#          <a href="/noticias/cifra-de-casos-confirmados-de-coronavirus-en-colombia-sube-a-1-334-089-2020.html">
#           Cifra de casos confirmados de coronavirus en Colombia sube a 1,334,089
#          </a>
#         </li>
#         <li>
#          <a href="/noticias/ultimo-reporte-de-contagios-por-coronavirus-llega-a-1-324-792-en-colombia-2020.html">
#           Último reporte de contagios por coronavirus llega a 1,324,792 en Colombia
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- \ seccion enlaces noticias -->
#   </div>
#   <!-- /container principal -->
#   <!-- Footer -->
#   <div class="container" id="footer_container" style="background-color:#fff;border-top:1px solid #eee;margin-top:5px;">
#    <div class="row">
#     <div class="hidden-xs col-sm-2 col-md-2 col-lg-2">
#      <div style="padding:10px 10px; text-align:center;">
#       <a href="https://coronavirus.wilkinsonpc.com.co/">
#        <img border="0" src="https://coronavirus.wilkinsonpc.com.co/img/coronavirus-colombia-logo-footer.png" title="Coronavirus en Colombia"/>
#       </a>
#      </div>
#     </div>
#     <div class="col-sm-22 col-md-22 col-lg-22">
#      <div id="footer_copyright" style="padding:5px 0 0 10px;">
#       <ul class="list-inline">
#        <li>
#         <a href="https://coronavirus.wilkinsonpc.com.co/privacidad.html">
#          <small>
#           Privacidad
#          </small>
#         </a>
#        </li>
#        <li>
#         <a href="https://coronavirus.wilkinsonpc.com.co/cookies.html">
#          <small>
#           Cookies
#          </small>
#         </a>
#        </li>
#        <li>
#         <a href="https://coronavirus.wilkinsonpc.com.co/ayuda.html">
#          <small>
#           Ayuda
#          </small>
#         </a>
#        </li>
#        <li>
#         <a href="https://coronavirus.wilkinsonpc.com.co">
#          <small>
#           Contáctenos
#          </small>
#         </a>
#        </li>
#       </ul>
#       <p>
#        <i aria-hidden="true" class="fa fa-copyright">
#        </i>
#        2001
#        <a href="https://www.wilkinsonpc.com.co">
#         Wilkinsonpc
#        </a>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- / Footer -->
#   <!-- bootstrap core -->
#   <script src="https://coronavirus.wilkinsonpc.com.co/js/bootstrap.min.js">
#   </script>
#   <!-- Go to www.addthis.com/dashboard to customize your tools -->
#   <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5e8e9fb95480a3dd" type="text/javascript">
#   </script>
#   <!-- START Bootstrap-Cookie-Alert -->
#   <div class="alert text-center cookiealert" role="alert">
#    Este sitio utiliza cookies para análisis y para mostrar contenido y anuncios personalizados. Al continuar navegando por este sitio, aceptas este uso.
#    <a href="/cookies.html" target="_blank">
#     Mas información
#    </a>
#    <button aria-label="Close" class="btn btn-primary btn-sm acceptcookies" type="button">
#     Cerrar
#    </button>
#   </div>
#   <!-- END Bootstrap-Cookie-Alert -->
#   <!-- Include cookiealert script -->
#   <script src="/js/cookiealert.js">
#   </script>
#  </body>
# </html>

# %%
#Lets formatt it nicely, using the prettify method as contrasts as cell 3
print(soupedad.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Casos por Edad CoronaVirus en Colombia
#   </title>
#   <meta content="Listado de casos de coronavirus en Colombia por edades, recuperados, en casa, hospitalizados, hospitalizados en cuidados intensivos y fallecidos." name="description"/>
#   <meta content="coronavirus por edad en colombia, casos coronavirus colombia" name="keywords"/>
#   <meta content="" name="google-site-verification"/>
#   <meta content="683506109" property="fb:admins"/>
#   <meta content="Casos por Edad CoronaVirus en Colombia" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://coronavirus.wilkinsonpc.com.co/casos-por-edad.html" property="og:url"/>
#   <meta content="Coronavirus Colombia" property="og:site_name"/>
#   <meta content="https://coronavirus.wilkinsonpc.com.co/img/coronavirus-colombia-logo-share.png" property="og:image"/>
#   <meta content="es_CO" property="og:locale"/>
#   <!-- Bootstrap v3.4.1 -->
#   <link href="https://coronavirus.wilkinsonpc.com.co/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <!-- Bootstrap GlyphIcons (bootstrap theme required) -->
#   <link href="//netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css" rel="stylesheet"/>
#   <!-- Diseño de las Tablas tablesorter -->
#   <link href="https://coronavirus.wilkinsonpc.com.co/css/tablesorter.theme.bootstrap.css" rel="stylesheet"/>
#   <!-- Font Awesome Free v5.13.0 -->
#   <link href="https://coronavirus.wilkinsonpc.com.co/css/fontawesome.free.css" rel="stylesheet" type="text/css"/>
#   <!-- Custom CSS -->
#   <link href="https://coronavirus.wilkinsonpc.com.co/css/estilos.css?version=06121721" rel="stylesheet" type="text/css"/>
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script>
#    (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-6096990144436709",
#     enable_page_level_ads: true
#   });
#   </script>
#   <!-- jQuery 3.1.1 -->
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js" type="text/javascript">
#   </script>
#   <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
#   <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
#   <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#       <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
#   <!-- jQuery tablesorter -->
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery.tablesorter/2.31.3/js/jquery.tablesorter.min.js" type="text/javascript">
#   </script>
#   <!-- jQuery tablesorter widgets (bootstrap theme required) -->
#   <script src="https://mottie.github.io/tablesorter/js/jquery.tablesorter.widgets.js" type="text/javascript">
#   </script>
#   <!-- Facebook show/hide comments box -->
#   <script src="https://coronavirus.wilkinsonpc.com.co/js/facebook-button-show-hide.js" type="text/javascript">
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-87105-21">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-87105-21');
#   </script>
#   <script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js">
#   </script>
#   <script>
#    var OneSignal = window.OneSignal || [];
#   OneSignal.push(function() {
#     OneSignal.init({
#       appId: "dd336a46-d4ac-47b6-a98f-14b358ce68a9",
#     });
#   });
#   </script>
#   <script async="" data-ad-client="ca-pub-6096990144436709" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <!-- favicon -->
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#5bbad5" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#da532c" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <!-- cookies warning -->
#   <link href="/css/cookiealert.css" rel="stylesheet"/>
#   <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    google.charts.load('current', {'packages':['bar']});
#       google.charts.setOnLoadCallback(drawChart);
#
#       function drawChart() {
# 		var data = google.visualization.arrayToDataTable([
# 			['Edad', 'Mujeres', 'Hombres'],
# 			['0 a 9', 22034, 23138],['10 a 19', 43412, 43753],['20 a 29', 155295, 145124],['30 a 39', 156810, 161717],['40 a 49', 111484, 110654],['50 a 59', 92832, 89590],['60 a 69', 54972, 55538],['70 a 79', 28658, 30594],['80 a 89', 15418, 14795],['90 a 99', 3426, 2756],['100 a 109', 149, 97],['110 a 119', 1, 2]		]);
#
# 		var options = {
# 			chart: {
# 				title: 'Edad y Género',
# 				subtitle: 'Comparativo',
# 			},
# 	  		colors:['#E084FF','#265CFF'],
# 	        };
#
# 		var chart = new google.charts.Bar(document.getElementById('edades_sexo'));
# 		chart.draw(data, google.charts.Bar.convertOptions(options));
# 	}
#   </script>
#   <script id="js">
#    $(function() {
#
# 	// show different colors for consecutive rows values
# 	$.extend($.tablesorter.defaults, {
# 		widthFixed: true,
# 		widgets : ['zebra','columns']
# 	});
# 	// tablas con datos
# 	$('.tabla1').tablesorter({
# 		theme : 'bootstrap',
# 		headerTemplate: '{content} {icon}',
# 		widgets    : ['zebra','columns', 'uitheme']
# 	});
#
# });
#   </script>
#  </head>
#  <body>
#   <!--  facebook sdk -->
#   <div id="fb-root">
#   </div>
#   <script async="" crossorigin="anonymous" defer="" src="https://connect.facebook.net/es_LA/sdk.js#xfbml=1&amp;version=v6.0&amp;appId=1567895109902705&amp;autoLogAppEvents=1">
#   </script>
#   <!-- enable tooltip everywhere -->
#   <script>
#    $(function () {
# 	$('[data-toggle="tooltip"]').tooltip()
# })
#   </script>
#   <!-- menu navegacion -->
#   <nav class="navbar navbar-inverse navbar-fixed-top" id="navbar" role="navigation">
#    <!-- contenedor menu navegacion -->
#    <div class="container" id="navbar_container">
#     <!-- logo y boton menu mobile -->
#     <div class="navbar-header">
#      <button class="navbar-toggle navbar-left" data-target="#nav_bar_collapse" data-toggle="collapse" type="button">
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="navbar-brand" href="https://coronavirus.wilkinsonpc.com.co/">
#       <img alt="Coronavirus Colombia" border="0" src="https://coronavirus.wilkinsonpc.com.co/img/coronavirus-colombia-logo.png" title="Coronavirus Colombia" width="200"/>
#      </a>
#     </div>
#     <!-- enlaces, botones y demas -->
#     <div class="collapse navbar-collapse" id="nav_bar_collapse">
#      <ul class="nav navbar-nav">
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#" style="padding-left:35px;padding-right:5px;" title="Coronavirus Colombia Total">
#         COLOMBIA
#         <b class="caret">
#         </b>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/pruebas-realizadas-vs-casos-diarios.html">
#           PRUEBAS VS CASOS
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-confirmados.html">
#           TODOS LOS CASOS
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-dia.html" style="color:#E0B107;">
#           CASOS POR DIA
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-detalle.html" style="color:#E0B107;">
#           DETALLE POR CASO
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-fallecidos.html">
#           FALLECIDOS
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-fallecidos-hoy.html">
#           FALLECIDOS HOY
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-recuperados.html">
#           RECUPERADOS
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-recuperados-hoy.html">
#           RECUPERADOS HOY
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-departamento.html">
#           POR DEPARTAMENTO
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html">
#           POR CIUDAD
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-edad.html">
#           POR EDAD
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-mujeres-vs-hombres.html">
#           POR SEXO
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-por-pais-de-origen.html">
#           POR PAÍS DE ORIGEN
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/">
#           ESTADÍSTICAS
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#" style="padding-left:35px;padding-right:5px;" title="Coronavirus en el Mundo">
#         MUNDO
#         <b class="caret">
#         </b>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-confirmados-mundo.html">
#           TODOS LOS PAISES
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-fallecidos-mundo.html">
#           FALLECIDOS POR PAIS
#          </a>
#         </li>
#         <li>
#          <a href="https://coronavirus.wilkinsonpc.com.co/casos-mundo.html">
#           ESTADÍSTICAS
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav">
#       <li>
#        <a href="https://coronavirus.wilkinsonpc.com.co/noticias/">
#         NOTICIAS
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav">
#       <li>
#        <a href="https://coronavirus.wilkinsonpc.com.co/ayuda.html">
#         AYUDA
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right">
#       <li class="dropdown visible-lg">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#" style="padding-left:35px;padding-right:5px;color:#AD2516;" title="Patrocinado por:">
#         by:
#         <b class="caret">
#         </b>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="https://dolar.wilkinsonpc.com.co">
#           Dolar en Colombia
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </div>
#     <!-- / enlaces, botones y demas -->
#    </div>
#    <!-- / contenedor menu navegacion -->
#   </nav>
#   <!-- / menu navegacion -->
#   <script>
#    $(document).ready(function () {
# 			  $(".navbar-toggle").on("click", function () {
# 				    $(this).toggleClass("active");
# 			  });
# 		});
#   </script>
#   <!-- contenedor body -->
#   <div class="container" id="container_container" style="">
#    <div class="row">
#     <div class="col-xs-24 col-sm-24 col-md-24 col-lg-24" id="buscar_form" style="padding:20px; margin:0; background-color:#eee; border-top:1px solid #D9D9D9; border-bottom:1px solid #999;">
#      <form action="https://www.google.com/search" id="buscar_google" method="get" style="padding:0; margin:0; ">
#       <input name="sitesearch" type="hidden" value="coronavirus.wilkinsonpc.com.co"/>
#       <div class="row">
#        <div class="col-xs-24 col-sm-24 col-md-18 col-lg-24">
#         <div class="input-group input-group-lg input-large search-query">
#          <input autocomplete="on" class="form-control search" id="search_bot" name="q" placeholder="Buscar en coronavirus.wilkinsonpc.com.co" required="" type="text"/>
#          <span class="input-group-btn">
#           <button class="btn btn-default" type="submit">
#            Buscar
#           </button>
#          </span>
#         </div>
#        </div>
#       </div>
#      </form>
#     </div>
#    </div>
#    <div class="row" style="margin-bottom: 5px;">
#     <div class="hidden-xs hidden-sm" style="padding:10px;">
#      <div class="btn-group btn-group-justified">
#       <a class="btn btn-info" href="/pruebas-realizadas-vs-casos-diarios.html" style="color:#fff;" title="Pruebas vs Casos">
#        Pruebas vs Casos
#       </a>
#       <a class="btn btn-info" href="/casos-confirmados.html" style="color:#fff;" title="Detalle de Casos">
#        Detalle Casos
#       </a>
#       <a class="btn btn-info" href="/casos-por-departamento.html" style="color:#fff;" title="Casos por Departamentos">
#        Departamento
#       </a>
#       <a class="btn btn-info" href="/casos-por-ciudad.html" style="color:#fff;" title="Casos por Ciudad">
#        Ciudades
#       </a>
#       <a class="btn btn-info" href="/casos-por-edad.html" style="color:#fff;" title="Casos por Edad">
#        Edades
#       </a>
#       <a class="btn btn-info" href="/casos-mujeres-vs-hombres.html" style="color:#fff;" title="Casos por Género">
#        Género
#       </a>
#       <a class="btn btn-info" href="/noticias/" style="color:#fff;" title="Noticias del Coronavirus">
#        Noticias
#       </a>
#       <a class="btn btn-info" href="/ayuda.html" style="color:#fff;" title="Ayuda">
#        Ayuda
#       </a>
#      </div>
#     </div>
#    </div>
#    <!-- esqueleto contenido -->
#    <div class="row" style="margin-bottom: 5px;">
#     <!-- fila principal -->
#     <div class="col-xs-24 col-sm-24 col-md-16 col-lg-16">
#      <!-- columna izquierda -->
#      <!-- esqueleto contenido -->
#      <!-- anuncio -->
#      <div class="row">
#       <div class="col-xs-24">
#        <div style="text-align:center; margin:5px 0;">
#         <script type="text/javascript">
#          <!--
# google_ad_client = "ca-pub-7363809219244122";
# google_ad_width = 468;
# google_ad_height = 60;
# //-->
#         </script>
#         <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#         </script>
#         <script>
#          var _comscore = _comscore || [];
#   _comscore.push({ c1: "8", c2: "14880948" ,c3: "3" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#         </script>
#         <noscript>
#          <img src="https://b.scorecardresearch.com/p?c1=8&amp;c2=14880948&amp;c3=3&amp;c15=&amp;cv=2.0&amp;cj=1"/>
#         </noscript>
#         <script id="navegg" src="//tag.navdmp.com/tm18475.js" type="text/javascript">
#         </script>
#        </div>
#       </div>
#      </div>
#      <!-- \ anuncio -->
#      <!-- seccion detalle de casos -->
#      <div class="div_box">
#       <ol class="visible-xs visible-sm breadcrumb">
#        <li>
#         <a href="/">
#          Home
#         </a>
#        </li>
#        <li>
#         <a href="/casos-confirmados.html">
#          Colombia
#         </a>
#        </li>
#        <li class="active">
#         Casos por Edad
#        </li>
#       </ol>
#       <div class="row">
#        <div class="col-xs-24 col-sm-24 col-md-24 col-lg-24" style="padding:5px;text-align:center;">
#         <h1 class="hidden-xs hidden-sm titulo">
#          CORONAVIRUS EN COLOMBIA POR EDADES
#         </h1>
#         <h1 class="hidden-md hidden-lg titulo">
#          CASOS POR EDAD
#         </h1>
#         <span class="fecha_cierre">
#          Actualización: Sábado 5 de Diciembre (6pm)
#         </span>
#        </div>
#       </div>
#       <div class="row" style="margin-bottom: 5px;">
#        <div class="col-xs-24 col-sm-24 col-md-24 col-lg-24" style="padding:5px;">
#         <div id="secciones_body">
#          <p class="table_up_tip">
#           <i class="fas fa-lightbulb">
#           </i>
#           Click en los encabezados para ordenar.
#          </p>
#          <div class="table_box">
#           <table border="0" class="tabla1">
#            <thead>
#             <tr class="hidden-xs hidden-sm">
#              <td style="text-align:center;font-weight:bold;">
#               Edad
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               Mujeres
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               Hombres
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               Recuperados
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               Fallecidos
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               Críticos
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               Hospital
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               Casa
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               Total
#              </td>
#             </tr>
#            </thead>
#            <tr class="visible-xs visible-sm">
#             <td style="font-size:2.2em;color:#666;text-align:center;">
#              <i class="fas fa-id-card">
#              </i>
#             </td>
#             <td style="font-size:2.2em;color:#C822FF;text-align:center;">
#              <i class="fas fa-female">
#              </i>
#             </td>
#             <td style="font-size:2.2em;color:#265CFF;text-align:center;">
#              <i class="fas fa-male">
#              </i>
#             </td>
#             <td style="font-size:2.2em;color:#008C23;text-align:center;">
#              <i class="fas fa-thumbs-up">
#              </i>
#             </td>
#             <td style="font-size:2.2em;color:#000;text-align:center;">
#              <i class="fas fa-ribbon">
#              </i>
#             </td>
#             <td style="font-size:2.2em;color:#666;text-align:center;">
#              <i class="fas fa-equals">
#              </i>
#             </td>
#            </tr>
#            <tbody>
#             <tr>
#              <td nowrap="">
#               0 a 9
#              </td>
#              <td style="text-align:center;">
#               22034
#              </td>
#              <td style="text-align:center;">
#               23138
#              </td>
#              <td style="text-align:center;">
#               42459
#              </td>
#              <td style="text-align:center;">
#               57
#              </td>
#              <td style="text-align:center;">
#               71
#              </td>
#              <td style="text-align:center;">
#               1023
#              </td>
#              <td style="text-align:center;">
#               1506
#              </td>
#              <td style="text-align:center;">
#               45172
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               10 a 19
#              </td>
#              <td style="text-align:center;">
#               43412
#              </td>
#              <td style="text-align:center;">
#               43753
#              </td>
#              <td style="text-align:center;">
#               82988
#              </td>
#              <td style="text-align:center;">
#               54
#              </td>
#              <td style="text-align:center;">
#               40
#              </td>
#              <td style="text-align:center;">
#               484
#              </td>
#              <td style="text-align:center;">
#               3550
#              </td>
#              <td style="text-align:center;">
#               87165
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               20 a 29
#              </td>
#              <td style="text-align:center;">
#               155295
#              </td>
#              <td style="text-align:center;">
#               145124
#              </td>
#              <td style="text-align:center;">
#               286039
#              </td>
#              <td style="text-align:center;">
#               412
#              </td>
#              <td style="text-align:center;">
#               88
#              </td>
#              <td style="text-align:center;">
#               1502
#              </td>
#              <td style="text-align:center;">
#               12232
#              </td>
#              <td style="text-align:center;">
#               300419
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               30 a 39
#              </td>
#              <td style="text-align:center;">
#               156810
#              </td>
#              <td style="text-align:center;">
#               161717
#              </td>
#              <td style="text-align:center;">
#               302954
#              </td>
#              <td style="text-align:center;">
#               1027
#              </td>
#              <td style="text-align:center;">
#               196
#              </td>
#              <td style="text-align:center;">
#               1999
#              </td>
#              <td style="text-align:center;">
#               12219
#              </td>
#              <td style="text-align:center;">
#               318527
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               40 a 49
#              </td>
#              <td style="text-align:center;">
#               111484
#              </td>
#              <td style="text-align:center;">
#               110654
#              </td>
#              <td style="text-align:center;">
#               208854
#              </td>
#              <td style="text-align:center;">
#               2221
#              </td>
#              <td style="text-align:center;">
#               281
#              </td>
#              <td style="text-align:center;">
#               2188
#              </td>
#              <td style="text-align:center;">
#               8386
#              </td>
#              <td style="text-align:center;">
#               222138
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               50 a 59
#              </td>
#              <td style="text-align:center;">
#               92832
#              </td>
#              <td style="text-align:center;">
#               89590
#              </td>
#              <td style="text-align:center;">
#               166659
#              </td>
#              <td style="text-align:center;">
#               4852
#              </td>
#              <td style="text-align:center;">
#               523
#              </td>
#              <td style="text-align:center;">
#               3159
#              </td>
#              <td style="text-align:center;">
#               6879
#              </td>
#              <td style="text-align:center;">
#               182422
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               60 a 69
#              </td>
#              <td style="text-align:center;">
#               54972
#              </td>
#              <td style="text-align:center;">
#               55538
#              </td>
#              <td style="text-align:center;">
#               93348
#              </td>
#              <td style="text-align:center;">
#               8662
#              </td>
#              <td style="text-align:center;">
#               582
#              </td>
#              <td style="text-align:center;">
#               3330
#              </td>
#              <td style="text-align:center;">
#               3935
#              </td>
#              <td style="text-align:center;">
#               110510
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               70 a 79
#              </td>
#              <td style="text-align:center;">
#               28658
#              </td>
#              <td style="text-align:center;">
#               30594
#              </td>
#              <td style="text-align:center;">
#               43852
#              </td>
#              <td style="text-align:center;">
#               9915
#              </td>
#              <td style="text-align:center;">
#               427
#              </td>
#              <td style="text-align:center;">
#               2486
#              </td>
#              <td style="text-align:center;">
#               1839
#              </td>
#              <td style="text-align:center;">
#               59252
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               80 a 89
#              </td>
#              <td style="text-align:center;">
#               15418
#              </td>
#              <td style="text-align:center;">
#               14795
#              </td>
#              <td style="text-align:center;">
#               19007
#              </td>
#              <td style="text-align:center;">
#               8183
#              </td>
#              <td style="text-align:center;">
#               165
#              </td>
#              <td style="text-align:center;">
#               1371
#              </td>
#              <td style="text-align:center;">
#               819
#              </td>
#              <td style="text-align:center;">
#               30213
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               90 a 99
#              </td>
#              <td style="text-align:center;">
#               3426
#              </td>
#              <td style="text-align:center;">
#               2756
#              </td>
#              <td style="text-align:center;">
#               3404
#              </td>
#              <td style="text-align:center;">
#               2172
#              </td>
#              <td style="text-align:center;">
#               15
#              </td>
#              <td style="text-align:center;">
#               236
#              </td>
#              <td style="text-align:center;">
#               156
#              </td>
#              <td style="text-align:center;">
#               6182
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               100 a 109
#              </td>
#              <td style="text-align:center;">
#               149
#              </td>
#              <td style="text-align:center;">
#               97
#              </td>
#              <td style="text-align:center;">
#               136
#              </td>
#              <td style="text-align:center;">
#               78
#              </td>
#              <td style="text-align:center;">
#               0
#              </td>
#              <td style="text-align:center;">
#               12
#              </td>
#              <td style="text-align:center;">
#               5
#              </td>
#              <td style="text-align:center;">
#               246
#              </td>
#             </tr>
#             <tr>
#              <td nowrap="">
#               110 a 119
#              </td>
#              <td style="text-align:center;">
#               1
#              </td>
#              <td style="text-align:center;">
#               2
#              </td>
#              <td style="text-align:center;">
#               2
#              </td>
#              <td style="text-align:center;">
#               0
#              </td>
#              <td style="text-align:center;">
#               0
#              </td>
#              <td style="text-align:center;">
#               0
#              </td>
#              <td style="text-align:center;">
#               1
#              </td>
#              <td style="text-align:center;">
#               3
#              </td>
#             </tr>
#             <tr class="hidden-xs hidden-sm">
#              <td style="text-align:center;font-weight:bold;">
#               Totales
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               684491
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               677758
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               1249702
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               37633
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               2388
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               17790
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               51527
#              </td>
#              <td style="text-align:center;font-weight:bold;">
#               1362249
#              </td>
#             </tr>
#            </tbody>
#           </table>
#          </div>
#          <div class="visible-xs visible-sm tips_tabla_foot">
#           <span style="color:#008C23;">
#            <i class="fas fa-female">
#            </i>
#            mujeres
#           </span>
#           <span style="color:#265CFF;">
#            <i class="fas fa-male">
#            </i>
#            hombres
#           </span>
#           <span style="color:#008C23;">
#            <i class="fas fa-thumbs-up">
#            </i>
#            recuperados
#           </span>
#           <span style="color:#000;">
#            <i class="fas fa-ribbon">
#            </i>
#            fallecidos
#           </span>
#          </div>
#          <p>
#           Son un total de 684491 mujeres y 677758 hombres que han dado positivo a la prueba del coronavirus COVID-19 a la fecha en Colombia.
#          </p>
#          <div id="edades_sexo" style="width: 100%; height: 400px;">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div style="clear:both;">
#       </div>
#       <div class="row">
#        <div class="dw_notas">
#         <p style="font-size:1.2em;">
#         </p>
#        </div>
#       </div>
#       <!-- FIN seccion detalle de casos -->
#      </div>
#      <!-- anuncio -->
#      <div class="row">
#       <div class="col-xs-24">
#        <div style="text-align:center; margin:5px 0;">
#         <script type="text/javascript">
#          <!--
# google_ad_client = "ca-pub-7363809219244122";
# google_ad_width = 468;
# google_ad_height = 60;
# //-->
#         </script>
#         <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#         </script>
#         <script>
#          var _comscore = _comscore || [];
#   _comscore.push({ c1: "8", c2: "14880948" ,c3: "3" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#         </script>
#         <noscript>
#          <img src="https://b.scorecardresearch.com/p?c1=8&amp;c2=14880948&amp;c3=3&amp;c15=&amp;cv=2.0&amp;cj=1"/>
#         </noscript>
#         <script id="navegg" src="//tag.navdmp.com/tm18475.js" type="text/javascript">
#         </script>
#        </div>
#       </div>
#      </div>
#      <!-- \ anuncio -->
#      <style>
#       adiv {border:1px solid #660000;}
#      </style>
#      <!-- seccion comentarios facebook -->
#      <div class="row" style="margin-bottom:5px;">
#       <div class="col-xs-4 col-sm-4 col-sm-offset-1 col-md-5 col-md-offset-1 col-lg-7 col-lg-offset-1">
#        <hr class="difum"/>
#       </div>
#       <div class="col-xs-16 col-sm-14 col-md-12 col-lg-8" id="mensajes_fb_boton">
#        <button class="btn btn-default" id="toggler" onclick="showme('comentarios', this.id);" style="font-weight:bold;background-color:#EFEFEF;color:#000;" type="button">
#         <i class="fab fa-facebook-square">
#         </i>
#         VER COMENTARIOS
#         <i class="fa fa-chevron-down">
#         </i>
#        </button>
#       </div>
#       <div class="col-xs-4 col-sm-4 col-md-5 col-lg-7">
#        <hr class="difum"/>
#       </div>
#      </div>
#      <div class="div_box" id="comentarios" style="display:none;">
#       <!-- comentarios facebook -->
#       <div class="row">
#        <div class="col-xs-24" id="mensajes_fb">
#         <div class="advertencia">
#          <i>
#           Se prohíben las publicaciones donde se oferten productos y/o servicios,
#           <b>
#            fake news
#           </b>
#           , temas políticos y cualquier otro que genere molestias y divisiones, por lo que se exige respeto y tolerancia entre usuarios, cualquier falta será penalizada con el bloqueo del usuario y/o eliminación del mensaje.
#          </i>
#         </div>
#         <div class="fb-comments mensajes" data-href="https://coronavirus.wilkinsonpc.com.co/casos-por-edad.html" data-numposts="10" data-order-by="reverse_time" data-width="100%">
#         </div>
#        </div>
#       </div>
#       <!-- \ comentarios facebook -->
#      </div>
#      <!-- \ seccion comentarios facebook -->
#      <!-- esqueleto contenido -->
#     </div>
#     <!-- /columna izquierda -->
#     <div class="col-xs-24 col-sm-24 col-md-8 col-lg-8">
#      <!-- columna derecha -->
#      <!-- esqueleto contenido -->
#      <!-- anuncio -->
#      <div class="row">
#       <div class="col-xs-24">
#        <div style="text-align:center; padding:5px;">
#         <script type="text/javascript">
#          <!--
# google_ad_client = "ca-pub-7363809219244122";
# google_ad_width = 300;
# google_ad_height = 250;
# //-->
#         </script>
#         <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript">
#         </script>
#         <script>
#          var _comscore = _comscore || [];
#   _comscore.push({ c1: "8", c2: "14880948" ,c3: "3" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#         </script>
#         <noscript>
#          <img src="https://b.scorecardresearch.com/p?c1=8&amp;c2=14880948&amp;c3=3&amp;c15=&amp;cv=2.0&amp;cj=1"/>
#         </noscript>
#         <script id="navegg" src="//tag.navdmp.com/tm18475.js" type="text/javascript">
#         </script>
#        </div>
#       </div>
#      </div>
#      <!-- \ anuncio -->
#      <div class="div_box" style="margin:0 5px;">
#       <div class="row">
#        <div class="col-xs-24" style="padding:10px; text-align:center;">
#         <h1 class="titulo">
#          <a href="/casos-confirmados-mundo.html">
#           CASOS EN EL MUNDO
#          </a>
#         </h1>
#         <span class="fecha_cierre" style="text-align:center;">
#          Actualizado el Domingo 6 de Diciembre (2pm)
#         </span>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <h1 class="valor_confirm">
#          <a href="/casos-confirmados-mundo.html">
#           67,242,622
#          </a>
#          <span style="font-size: 0.6em; color: #666;">
#           <i class="fas fa-search-plus">
#           </i>
#          </span>
#         </h1>
#         <hr class="title"/>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <h2 class="subtitulo">
#          Recuperados
#         </h2>
#         <h1 class="valor_recuper">
#          <a href="/casos-confirmados-mundo.html">
#           46,013,853
#          </a>
#         </h1>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <h2 class="subtitulo">
#          Fallecidos
#         </h2>
#         <h1 class="valor_falleci">
#          <a href="/casos-confirmados-mundo.html">
#           1,539,914
#          </a>
#         </h1>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <h2 class="subtitulo">
#          Críticos*
#         </h2>
#         <h1 class="valor_critico">
#          <a href="/casos-confirmados-mundo.html">
#           105,937
#          </a>
#          *
#         </h1>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <h2 class="subtitulo">
#          Activos
#         </h2>
#         <h1 class="valor_casa">
#          <a href="/casos-confirmados-mundo.html">
#           19,688,855
#          </a>
#         </h1>
#        </div>
#        <div class="col-xs-24" style="padding:10px;text-align:center;">
#         <p>
#          * Hacen parte del total de casos activos pero se encuentran en condición delicada de salud.
#         </p>
#        </div>
#       </div>
#      </div>
#      <!-- esqueleto contenido -->
#     </div>
#     <!-- /columna derecha -->
#    </div>
#    <!-- /fila principal -->
#    <!-- esqueleto contenido -->
#    <!-- seccion enlaces noticias -->
#    <div class="div_box">
#     <div class="row" style="margin-bottom: 5px;">
#      <div class="col-xs-24 col-sm-24 col-md-24 col-lg-24" style="padding:15px;">
#       <div class="news_list_last12">
#        <p alt="NOTICIAS" title="NOTICIAS">
#         NOTICIAS
#        </p>
#        <ul>
#         <li>
#          <a href="/noticias/autoridades-entregan-nuevo-reporte-de-contagios-por-coronavirus-2020.html">
#           Autoridades entregan nuevo reporte de contagios por coronavirus
#          </a>
#         </li>
#         <li>
#          <a href="/noticias/nuevo-informe-sube-a-1-352-607-contagios-por-coronavirus-en-colombia-2020.html">
#           Nuevo informe, sube a 1,352,607 contagios por coronavirus en Colombia
#          </a>
#         </li>
#         <li>
#          <a href="/noticias/casos-de-coronavirus-en-colombia-llegan-a-1-343-322-2020.html">
#           Casos de coronavirus en Colombia llegan a 1,343,322
#          </a>
#         </li>
#         <li>
#          <a href="/noticias/cifra-de-casos-confirmados-de-coronavirus-en-colombia-sube-a-1-334-089-2020.html">
#           Cifra de casos confirmados de coronavirus en Colombia sube a 1,334,089
#          </a>
#         </li>
#         <li>
#          <a href="/noticias/ultimo-reporte-de-contagios-por-coronavirus-llega-a-1-324-792-en-colombia-2020.html">
#           Último reporte de contagios por coronavirus llega a 1,324,792 en Colombia
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- \ seccion enlaces noticias -->
#   </div>
#   <!-- /container principal -->
#   <!-- Footer -->
#   <div class="container" id="footer_container" style="background-color:#fff;border-top:1px solid #eee;margin-top:5px;">
#    <div class="row">
#     <div class="hidden-xs col-sm-2 col-md-2 col-lg-2">
#      <div style="padding:10px 10px; text-align:center;">
#       <a href="https://coronavirus.wilkinsonpc.com.co/">
#        <img border="0" src="https://coronavirus.wilkinsonpc.com.co/img/coronavirus-colombia-logo-footer.png" title="Coronavirus en Colombia"/>
#       </a>
#      </div>
#     </div>
#     <div class="col-sm-22 col-md-22 col-lg-22">
#      <div id="footer_copyright" style="padding:5px 0 0 10px;">
#       <ul class="list-inline">
#        <li>
#         <a href="https://coronavirus.wilkinsonpc.com.co/privacidad.html">
#          <small>
#           Privacidad
#          </small>
#         </a>
#        </li>
#        <li>
#         <a href="https://coronavirus.wilkinsonpc.com.co/cookies.html">
#          <small>
#           Cookies
#          </small>
#         </a>
#        </li>
#        <li>
#         <a href="https://coronavirus.wilkinsonpc.com.co/ayuda.html">
#          <small>
#           Ayuda
#          </small>
#         </a>
#        </li>
#        <li>
#         <a href="https://coronavirus.wilkinsonpc.com.co">
#          <small>
#           Contáctenos
#          </small>
#         </a>
#        </li>
#       </ul>
#       <p>
#        <i aria-hidden="true" class="fa fa-copyright">
#        </i>
#        2001
#        <a href="https://www.wilkinsonpc.com.co">
#         Wilkinsonpc
#        </a>
#       </p>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- / Footer -->
#   <!-- bootstrap core -->
#   <script src="https://coronavirus.wilkinsonpc.com.co/js/bootstrap.min.js">
#   </script>
#   <!-- Go to www.addthis.com/dashboard to customize your tools -->
#   <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5e8e9fb95480a3dd" type="text/javascript">
#   </script>
#   <!-- START Bootstrap-Cookie-Alert -->
#   <div class="alert text-center cookiealert" role="alert">
#    Este sitio utiliza cookies para análisis y para mostrar contenido y anuncios personalizados. Al continuar navegando por este sitio, aceptas este uso.
#    <a href="/cookies.html" target="_blank">
#     Mas información
#    </a>
#    <button aria-label="Close" class="btn btn-primary btn-sm acceptcookies" type="button">
#     Cerrar
#    </button>
#   </div>
#   <!-- END Bootstrap-Cookie-Alert -->
#   <!-- Include cookiealert script -->
#   <script src="/js/cookiealert.js">
#   </script>
#  </body>
# </html>

# %%
#Lets formatt it nicely, using the prettify method as contrasts as cell 3
print(soupgen.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="es">
#  <head>
#   <link href="http://www.w3.org/1999/xhtml/vocab" rel="profile"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="/dm/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/dm/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/dm/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/dm/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/dm/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/dm/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/dm/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/dm/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/dm/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/dm/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/dm/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/dm/favicon-160x160.png" rel="icon" sizes="160x160" type="image/png"/>
#   <link href="/dm/favicon-196x196.png" rel="icon" sizes="196x196" type="image/png"/>
#   <meta content="#4e80c0" name="msapplication-TileColor"/>
#   <meta content="/dm/mstile-144x144.png" name="msapplication-TileImage"/>
#   <link href="https://datosmacro.expansion.com/otros/coronavirus" rel="up"/>
#   <link href="https://datosmacro.expansion.com/otros/coronavirus/comoras" rel="next"/>
#   <link href="https://datosmacro.expansion.com/otros/coronavirus/chipre" rel="prev"/>
#   <link href="https://datosmacro.expansion.com/otros/coronavirus/colombia" rel="canonical"/>
#   <link href="https://pt.countryeconomy.com/outros/coronavirus/colombia" hreflang="pt" rel="alternate"/>
#   <link href="https://fr.countryeconomy.com/autres/coronavirus/colombie" hreflang="fr" rel="alternate"/>
#   <link href="https://countryeconomy.com/others/coronavirus/colombia" hreflang="en" rel="alternate"/>
#   <link href="https://datosmacro.expansion.com/otros/coronavirus/colombia" hreflang="es" rel="alternate"/>
#   <meta content="  Colombia contabiliza, 1.334.089 personas confirmadas de coronavirus, 9.297 personas confirmadas más que el día anterior. " name="description"/>
#   <meta content="  Colombia contabiliza, 1.334.089 personas confirmadas de coronavirus, 9.297 personas confirmadas más que el día anterior. " property="og:description"/>
#   <meta content="https://datosmacro.expansion.com/img/flag/COg.png" property="og:image"/>
#   <meta content="@datosmacro" name="twitter:site"/>
#   <meta content="  Colombia contabiliza, 1.334.089 personas confirmadas de coronavirus, 9.297 personas confirmadas más que el día anterior. " name="twitter:description"/>
#   <meta content="https://datosmacro.expansion.com/img/flag/COg.png" name="twitter:image:src"/>
#   <meta content="1436132716631029" property="fb:app_id"/>
#   <meta content="datosmacro.com" property="og:site_name"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://datosmacro.expansion.com/otros/coronavirus/colombia" property="og:url"/>
#   <meta content="Colombia - COVID-19 - Crisis del coronavirus 2020" property="og:title"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="https://datosmacro.expansion.com/otros/coronavirus/colombia" name="twitter:url"/>
#   <meta content="Colombia - COVID-19 - Crisis del coronavirus 2020" name="twitter:title"/>
#   <title>
#    Colombia - COVID-19 - Crisis del coronavirus  2020 | datosmacro.com
#   </title>
#   <link href="https://datosmacro.expansion.com/sites/default/files/css/css_lQaZfjVpwP_oGNqdtWCSpJT1EMqXdMiU84ekLLxQnc4.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://datosmacro.expansion.com/sites/default/files/css/css_JCY_XIQAlFCN_AbvjWfbNrXAa03IOm7FrXUxsDgkibE.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://datosmacro.expansion.com/sites/default/files/css/css_PGbJgHCUCBf4dg7K9Kt8aAwsApndP4GZ9RuToPy3-Fk.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.jsdelivr.net/npm/bootstrap@3.4.1/dist/css/bootstrap.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://cdn.jsdelivr.net/npm/@unicorn-fail/drupal-bootstrap-styles@0.0.2/dist/3.3.1/7.x-3.x/drupal-bootstrap.min.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://datosmacro.expansion.com/sites/default/files/css/css_STsSYI68TmOKlt-opuCXDVxYZkPW64rC20UA0BF5dYU.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://datosmacro.expansion.com/sites/default/files/css/css_L5AeO8RgGZzJo7RiYdIJUq64b8QXlnFcOn4DzM4vB74.css" media="all" rel="stylesheet" type="text/css"/>
#   <!-- HTML5 element support for IE6-8 -->
#   <!--[if lt IE 9]>
#     <script src="https://cdn.jsdelivr.net/html5shiv/3.7.3/html5shiv-printshiv.min.js"></script>
#   <![endif]-->
#   <script src="https://e00-ue.uecdn.es/cookies/js/policy_v3_utf8.js">
#   </script>
#   <script async="" data-key="03f1af55-a479-4c1f-891a-7481345171ce" id="spcloader" src="https://sdk.privacy-center.org/loader.js">
#   </script>
#   <script src="https://e00-ue.uecdn.es/cookies/js/gdpr_dfp.js">
#   </script>
#   <script>
#    function getCookieValue(e){var b = document.cookie.match("(^|;)\\s*"+e+"\\s*=\\s*([^;]+)");return b ? b.pop() : '';}
# var ue_privacyPolicyAcepted=getCookieValue('ue_privacyPolicy');var dmlang='es'; var classdol='data-dol';
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js">
#   </script>
#   <script src="https://datosmacro.expansion.com/sites/default/files/js/js_7fRzbr03YP62jLEbsC_JPPfz1D0etCQtUamE4iN3oOg.js">
#   </script>
#   <script src="https://cdn.jsdelivr.net/npm/bootstrap@3.4.1/dist/js/bootstrap.min.js">
#   </script>
#   <script src="https://datosmacro.expansion.com/sites/default/files/js/js_hs5VgUB1Ry5l_qEU1HVGCSuI_EpHNMcw9ALRckT5E5I.js">
#   </script>
#   <script src="https://www.gstatic.com/charts/loader.js">
#   </script>
#   <script>
#    var gptadslots=[];
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function(){ var gads = document.createElement('script');
# gads.async = true; gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
#   </script>
#   <script>
#    var mqlads = window.matchMedia("screen and (min-width:728px)");
# var adsIsDesktop=0;
# var prefMobile='M';
# window.ueUserContentGoogle = (function() {
#  if (!window || !window.ueCookiesPolicy || typeof window.ueCookiesPolicy.isAccepted != 'function') {
#   console.warn('Module ueCookiesPolicy not exists.')
#   return undefined;
#  }
#  var googleAccepted =  ueCookiesPolicy.isAccepted({vendors: 'google'});
#  if(googleAccepted === null) { googleAccepted = undefined }
#   return googleAccepted
# }());
# if (mqlads.matches){ adsIsDesktop=1; prefMobile='';}
# googletag.cmd.push(function() {
# if( window.ueUserContentGoogle !== undefined ){
#  if ( window.ueUserContentGoogle === true ) {
#   googletag.pubads().setRequestNonPersonalizedAds(0);
#   (adsbygoogle=window.adsbygoogle||[]).requestNonPersonalizedAds=0;
#   console.log('requestNonPersonalizedAds=0');
#  }else{
#   googletag.pubads().setRequestNonPersonalizedAds(1);
#   (adsbygoogle=window.adsbygoogle||[]).requestNonPersonalizedAds=1;
#   console.log('requestNonPersonalizedAds=1');
#  }
# }else{
#  googletag.pubads().disableInitialLoad();
#  (adsbygoogle=window.adsbygoogle||[]).pauseAdRequests=1;
# }
# var mapping_m = googletag.sizeMapping().
#  addSize([768, 0],[[1,1],[990,90],[990,200],[990,250],[980,90],[980,250],[980,200],[728,90],[728,250],[970,90],[970,250]]).
#  addSize([0, 0], [[320, 53],[320,50],[320,100],[1,1]]).
#  build();
# var mapping_r = googletag.sizeMapping().
#  addSize([768, 0],[[300,250],[300,300],[300,600],[1,1]]).
#  addSize([0, 0], [[300,250],[300,300],[300,600],[1,1]]).
#  build();
# var mapping_sky = googletag.sizeMapping().
#  addSize([768, 0],[[120,600],[120,1000],[120,1001],[1,1]]).
#  addSize([0, 0], []).
#  build();
# var mapping_skyD = googletag.sizeMapping().
#  addSize([768, 0],[[120,600],[120,1000],[120,1001],[1,1]]).
#  addSize([0, 0], []).
#  build();
# var mapping_c990x50 = googletag.sizeMapping().
#  addSize([768, 0],[[1,1],[990,50],[990,100]]).
#  addSize([0, 0], []).
#  build();
# gptadslots[1]= googletag.defineSlot('/99071977/exp2/datosmacro', [[1,1],[120,600],[120,1000]],'div-gpt-ad-dm_si').setTargeting('p',['si']).defineSizeMapping(mapping_sky).addService(googletag.pubads());
# gptadslots[2]= googletag.defineSlot('/99071977/exp2/datosmacro', [[1,1],[120,600],[120,1001]],'div-gpt-ad-dm_sd').setTargeting('p',['sd']).defineSizeMapping(mapping_skyD).addService(googletag.pubads());
#
#  gptadslots[3]= googletag.defineSlot('/99071977/exp2/datosmacro', [[1,1],[300,250],[300,300],[300,600]],'div-gpt-ad-dm_r'+prefMobile).setTargeting('p',['r']).defineSizeMapping(mapping_r).addService(googletag.pubads());
#  gptadslots[4]= googletag.defineSlot('/99071977/exp2/datosmacro', [[1,1],[300,250],[300,300],[300,600]],'div-gpt-ad-dm_rb'+prefMobile).setTargeting('p',['rb']).defineSizeMapping(mapping_r).addService(googletag.pubads());
#  gptadslots[5]= googletag.defineSlot('/99071977/exp2/datosmacro', [[1,1],[300,250],[300,300],[300,600]],'div-gpt-ad-dm_rc').setTargeting('p',['rc']).defineSizeMapping(mapping_r).addService(googletag.pubads());
#  gptadslots[6]= googletag.defineSlot('/99071977/exp2/datosmacro', [[1,1],[990,50],[990,100]],'div-gpt-ad-dm_c990x50').setTargeting('p',['c990x50']).defineSizeMapping(mapping_c990x50).addService(googletag.pubads());
#  gptadslots[7]= googletag.defineSlot('/99071977/exp2/datosmacro', [[1,1],[990,90],[980,90],[728,90],[970,90]],'div-gpt-ad-dm_mb').setTargeting('p',['mb']).defineSizeMapping(mapping_m).addService(googletag.pubads());
#  gptadslots[8]= googletag.defineSlot('/99071977/exp2/datosmacro', [[1,1],[990,90],[990,200],[990,250],[980,90],[980,250],[980,200],[728,90],[728,250],[970,90],[970,250]],'div-gpt-ad-dm_m').setTargeting('p',['m']).defineSizeMapping(mapping_m).addService(googletag.pubads());
#  gptadslots[0]= googletag.defineOutOfPageSlot('/99071977/exp2/datosmacro','div-gpt-ad-dm_f').setTargeting('p',['f']).addService(googletag.pubads());
#  googletag.pubads().enableSingleRequest();
#  googletag.pubads().enableAsyncRendering();
#  googletag.enableServices();
#
#  window.addEventListener('ueConsentChanged', function (event) {
#  googletag.cmd.push(function () {
#  if (event.detail.consents == null || event.detail.consents.vendors.google === true ){
#   googletag.pubads().setRequestNonPersonalizedAds(0);
#   (adsbygoogle=window.adsbygoogle||[]).requestNonPersonalizedAds=0;
#   console.log('requestNonPersonalizedAds=0');
#  }else{
#   googletag.pubads().setRequestNonPersonalizedAds(1);
#   (adsbygoogle=window.adsbygoogle||[]).requestNonPersonalizedAds=1;
#   console.log('requestNonPersonalizedAds=1');
#  }
#  googletag.pubads().refresh();
#  (adsbygoogle=window.adsbygoogle||[]).pauseAdRequests=0;
#  });
#  }, false);
#  const mycallback = (tcData, success) => {
#   if(success && (tcData.eventStatus === 'useractioncomplete' || tcData.eventStatus === 'tcloaded' )) {
#    // do something with tcData.tcString
#    if (window.ueUserContentGoogle !== undefined) {
#     ue_privacyPolicyAcepted = 8;
#    } else {
#     let vendor = "Google Advertising Products",
#     vendorID = 755,
#     googleConsent = tcData.vendor.consents[vendorID];
#     if (googleConsent) {
#      googletag.pubads().setRequestNonPersonalizedAds(0);
#      (adsbygoogle=window.adsbygoogle||[]).requestNonPersonalizedAds=0;
#      console.log('requestNonPersonalizedAds=0');
#     }else{
#      googletag.pubads().setRequestNonPersonalizedAds(1);
#      (adsbygoogle=window.adsbygoogle||[]).requestNonPersonalizedAds=1;
#      console.log('requestNonPersonalizedAds=1');
#     }
#     googletag.pubads().refresh();
#     (adsbygoogle=window.adsbygoogle||[]).pauseAdRequests=0;
#    }
#    // remove the ourself to not get called more than once
#    __tcfapi('removeEventListener', 2, (success) => {
#     },tcData.listenerId);
#   } else {
#    ;
#  }
# }
# window.__tcfapi('addEventListener', 2, mycallback);
# });
#
# function AdsRefresh(){
# googletag.pubads().refresh();
# (adsbygoogle=window.adsbygoogle||[]).pauseAdRequests=0;
# }
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-20583312-4">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'UA-120133634-1',{'link_attribution':true});
# gtag('config', 'UA-20583312-4',{'link_attribution':true});
#   </script>
#   <script src="//e00-apps-ue.uecdn.es/tms/js/tms-expansion.js">
#   </script>
#  </head>
#  <body class="navbar-is-fixed-top html not-front not-logged-in one-sidebar sidebar-second page-node page-node- page-node-43845 node-type-stat2 i18n-es" itemscope="" itemtype="https://schema.org/WebPage">
#   <img alt="Logo" class="imglogodm" src="/logo.png"/>
#   <div class="publicidad" id="div-gpt-ad-dm_f">
#    <script>
#     googletag.cmd.push(function () { googletag.display('div-gpt-ad-dm_f'); });
#    </script>
#   </div>
#   <div class="contenedor">
#    <header class="navbar navbar-fixed-top navbar-default" id="navbar" role="banner">
#     <div class="container">
#      <div class="navbar-header">
#       <a class="name navbar-brand" href="https://datosmacro.expansion.com/" title="Inicio">
#        datosmacro.com
#       </a>
#       <button class="navbar-toggle" data-target=".navbar-collapse" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         Toggle navigation
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#      </div>
#      <div class="navbar-collapse collapse">
#       <nav role="navigation">
#        <div class="region region-navigation">
#         <div class="block block-menu" id="block-menu-menu-top-menu">
#          <ul class="menu nav navbar-nav">
#           <li class="first expanded dropdown">
#            <a class="dropdown-toggle" data-toggle="dropdown" href="https://datosmacro.expansion.com/paises" title="">
#             Países
#             <span class="caret">
#             </span>
#            </a>
#            <ul class="dropdown-menu">
#             <li class="first leaf">
#              <a href="https://datosmacro.expansion.com/paises/espana" title="">
#               España
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/uk" title="">
#               Reino Unido
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/grecia" title="">
#               Grecia
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/usa" title="">
#               Estados Unidos
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/china" title="">
#               China
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/alemania" title="">
#               Alemania
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/argentina" title="">
#               Argentina
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/colombia" title="">
#               Colombia
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/brasil" title="">
#               Brasil
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/mexico" title="">
#               México
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/portugal" title="">
#               Portugal
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/paises/italia" title="">
#               Italia
#              </a>
#             </li>
#             <li class="last leaf">
#              <a href="https://datosmacro.expansion.com/paises" title="">
#               Otros países
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="expanded dropdown">
#            <a class="dropdown-toggle" data-toggle="dropdown" href="https://datosmacro.expansion.com/indicadores" title="">
#             Datos
#             <span class="caret">
#             </span>
#            </a>
#            <ul class="dropdown-menu">
#             <li class="first expanded">
#              <a href="https://datosmacro.expansion.com/estado" title="">
#               Cuentas Nacionales
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/precios" title="">
#               Precios
#              </a>
#             </li>
#             <li class="expanded">
#              <a href="https://datosmacro.expansion.com/mercados" title="">
#               Mercados
#              </a>
#             </li>
#             <li class="expanded">
#              <a href="https://datosmacro.expansion.com/mercado-laboral" title="">
#               Mercado laboral
#              </a>
#             </li>
#             <li class="expanded">
#              <a href="https://datosmacro.expansion.com/negocios" title="">
#               Negocios
#              </a>
#             </li>
#             <li class="expanded">
#              <a href="https://datosmacro.expansion.com/impuestos" title="">
#               Impuestos
#              </a>
#             </li>
#             <li class="expanded">
#              <a href="https://datosmacro.expansion.com/comercio" title="">
#               Comercio
#              </a>
#             </li>
#             <li class="expanded">
#              <a href="https://datosmacro.expansion.com/demografia" title="">
#               Demografía
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/mercado-dinero" title="">
#               Mercado de dinero
#              </a>
#             </li>
#             <li class="last leaf">
#              <a href="https://datosmacro.expansion.com/indicadores" title="">
#               Otros indicadores
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="expanded dropdown">
#            <a class="dropdown-toggle" data-toggle="dropdown" href="https://datosmacro.expansion.com/indicadores" title="">
#             Análisis
#             <span class="caret">
#             </span>
#            </a>
#            <ul class="dropdown-menu">
#             <li class="first leaf">
#              <a href="https://datosmacro.expansion.com/analisis/actualidad" title="">
#               Actualidad
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/analisis/breves" title="">
#               Breves
#              </a>
#             </li>
#             <li class="leaf">
#              <a href="https://datosmacro.expansion.com/analisis/los-mejores" title="">
#               Las mejores economías
#              </a>
#             </li>
#             <li class="last leaf">
#              <a href="https://datosmacro.expansion.com/analisis/los-peores" title="">
#               Las peores economías
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="last leaf">
#            <a href="https://datosmacro.expansion.com/diccionario" title="">
#             Diccionario
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="block block-block" id="block-block-18">
#          <div class="pull-right hidden-xs" id="toolbar">
#           <div class="socialMedia" itemprop="publisher" itemscope="" itemtype="https://schema.org/Organization">
#            <meta content="https://www.datosmacro.com" itemprop="url"/>
#            <meta content="Datosmacro" itemprop="name"/>
#            <ul class="socialMedia">
#             <li class="listLabel pull-left">
#              Siguenos en
#              <a href="https://www.facebook.com/datosmacro" itemprop="sameAs" target="_blank">
#               <img alt="Facebook" class="icon-svg-22 bgcw" src="/img/fbi.svg" title="Facebook"/>
#              </a>
#             </li>
#             <li class="pull-left">
#              <a href="https://twitter.com/datosmacro" itemprop="sameAs" target="_blank">
#               <img alt="Twitter" class="icon-svg-22" src="/img/twi.svg" title="Twitter"/>
#              </a>
#             </li>
#             <li class="pull-left">
#              <a href="https://www.linkedin.com/company/datosmacro" itemprop="sameAs" target="_blank">
#               <img alt="Linkedin" class="icon-svg-22" src="/img/lni.svg" title="Linkedin"/>
#              </a>
#             </li>
#            </ul>
#            <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
#             <meta content="https://datosmacro.expansion.com/logo.png" itemprop="url"/>
#            </span>
#           </div>
#          </div>
#         </div>
#         <div class="block block-block" id="block-block-36">
#          <div class="pull-right hidden-xs" itemscope="" itemtype="https://schema.org/WebSite">
#           <meta content="/" itemprop="url"/>
#           <form action="/buscador" class="navbar-form navbar-left" id="cse-search-box" itemprop="potentialAction" itemscope="" itemtype="https://schema.org/SearchAction">
#            <meta content="/buscador?search={search}" itemprop="target"/>
#            <input class="form-control input-sm" itemprop="query-input" name="search" placeholder="Search" type="text"/>
#           </form>
#          </div>
#         </div>
#         <div class="block block-block" id="block-block-53">
#          <div class="pull-right">
#           <div class="btn-group" role="group">
#            <button class="btn btn-sm navbar-btn" data-placement="bottom" id="btnDi1" title="Visualiza los datos en euros" type="button">
#             €
#            </button>
#            <button class="btn btn-sm navbar-btn" data-placement="bottom" id="btnDi2" title="Visualiza los datos en dólares" type="button">
#             $
#            </button>
#           </div>
#          </div>
#         </div>
#        </div>
#       </nav>
#      </div>
#     </div>
#    </header>
#    <div class="main-container container">
#     <header id="page-header" role="banner">
#      <div class="region region-header">
#       <div class="block block-block" id="block-block-28">
#        <div class="publicidad publicidad-superior-bajo-navegacion adsdesktop" id="div-gpt-ad-dm_c990x50">
#         <script>
#          googletag.cmd.push(function () { googletag.display('div-gpt-ad-dm_c990x50'); });
#         </script>
#        </div>
#       </div>
#       <div class="block block-block" id="block-block-54">
#        <div class="expansion cabecera hidden-xs" id="exp_cabecera" role="banner">
#         <h2>
#          <a href="http://www.expansion.com/" id="logo" rel="nofollow" title="Ir a la portada de expansion.com">
#           <img alt="expansion.com" src="/expansion/logo_expansion_noticia.png"/>
#          </a>
#          <a href="/" title="Ir a la portada de DatosMacro.com">
#           <span class="logodmexp">
#            / Datosmacro.com
#           </span>
#          </a>
#         </h2>
#         <div class="navegacion_global">
#          <div>
#           <a class="orbyt" href="http://expansionpro.orbyt.es" rel="nofollow" title="Orbyt">
#            <img alt="Orbyt" src="/expansion/logo-orbyt.png"/>
#           </a>
#           <div class="ediciones">
#            <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#             <span>
#              Ediciones
#             </span>
#            </a>
#            <ul class="selector dropdown-menu" id="ediciones">
#             <li>
#              <a href="http://www.expansion.com/catalunya/index.html?cid=GEN22401&amp;s_kw=catalunya" rel="nofollow">
#               Cataluña
#              </a>
#             </li>
#             <li>
#              <a href="http://www.expansion.com/valencia/index.html?cid=GEN22401&amp;s_kw=valencia" rel="nofollow">
#               C. Valenciana
#              </a>
#             </li>
#             <li>
#              <a href="http://www.expansion.com/andalucia/index.html?cid=GEN22401&amp;s_kw=andalucia" rel="nofollow">
#               Andalucía
#              </a>
#             </li>
#             <li>
#              <a href="http://www.expansion.com/pais-vasco/index.html?cid=GEN22401&amp;s_kw=paisvasco" rel="nofollow">
#               País Vasco
#              </a>
#             </li>
#             <li>
#              <a href="http://www.expansion.com/extremadura/index.html?cid=GEN22401&amp;s_kw=extremadura" rel="nofollow">
#               Extremadura
#              </a>
#             </li>
#             <li>
#              <a href="http://www.expansion.com/aragon/index.html?cid=GEN22401&amp;s_kw=aragon" rel="nofollow">
#               Aragón
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="block block-system block-menu hidden-xs" id="block-system-main-menu">
#        <ul class="menu nav navbar-nav">
#         <li class="first leaf">
#          <a href="https://datosmacro.expansion.com/ipc" title="Indice de precios de consumo">
#           IPC
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/paro">
#           Paro
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/prima-riesgo">
#           Prima de riesgo
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/bono" title="Rendimiento bonos del Estado a 10 años">
#           Bonos
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/ratings" title="Ratings: Calificación de la deuda">
#           Ratings
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/deuda" title="Deuda pública">
#           Deuda
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/deficit" title="Déficit público">
#           Deficit
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/pib" title="Producto Interior Bruto">
#           PIB
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/hipotecas">
#           Hipotecas
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/tipo-interes" title="Tipos de interés banco central">
#           Tipos
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/smi" title="salario mínimo interprofesional ">
#           Salario SMI
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/paro-epa" title="Encuesta de Población Activa">
#           EPA
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/bolsa" title="Gráficos y cotizaciones de indices bursátiles de los principales mercados de valores mundiales.  Ibex, Dow Jones, Nasdaq, Eurostoxx, etc">
#           Bolsas
#          </a>
#         </li>
#         <li class="leaf">
#          <a href="https://datosmacro.expansion.com/divisas" title="Tipo de cambio">
#           Divisas
#          </a>
#         </li>
#         <li class="last leaf">
#          <a href="https://datosmacro.expansion.com/materias-primas">
#           Materias Primas
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="block block-block" id="block-block-16">
#        <div id="pubFlot">
#         <div class="publicidad" id="div-gpt-ad-dm_m">
#          <script>
#           googletag.cmd.push(function() { googletag.display('div-gpt-ad-dm_m');});
#          </script>
#         </div>
#        </div>
#       </div>
#      </div>
#     </header>
#     <!-- /#page-header -->
#     <div class="row">
#      <section class="col-sm-8 col-sm-8-asd">
#       <ol class="breadcrumb" itemscope="" itemtype="https://schema.org/BreadcrumbList">
#        <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#         <a href="https://datosmacro.expansion.com/otros/coronavirus" itemprop="item">
#          <span itemprop="name">
#           COVID-19 - Crisis del coronavirus
#          </span>
#         </a>
#         <meta content="1" itemprop="position"/>
#        </li>
#       </ol>
#       <a id="main-content">
#       </a>
#       <h1 class="page-header">
#        <a href="/paises/colombia">
#         <img alt="Colombia" src="/img/flag/COp.png" style="vertical-align:middle"/>
#        </a>
#        <a href="/otros/coronavirus/colombia" itemprop="url">
#         Colombia - COVID-19 - Crisis del coronavirus
#        </a>
#       </h1>
#       <div class="region region-help clearfix">
#        <div class="block block-block" id="block-block-35">
#         <a class="btn btn-sm btn-warning pull-left" href="/suscripcion">
#          ¿Quieres que lo enviémos a tu correo?
#         </a>
#         <div class="social-buttons">
#          <a href="javascript:void(0);" onclick="dmSocial('facebook');">
#           <img alt="Share Facebook" class="icon-svg-22" src="/img/fbi.svg" title="Share Facebook"/>
#          </a>
#          <a href="javascript:void(0);" onclick="dmSocial('twitter');">
#           <img alt="Twitter" class="icon-svg-22" src="/img/tbi.svg" title="Twitter"/>
#          </a>
#          <a href="javascript:void(0);" onclick="dmSocial('linkedin');">
#           <img alt="Share Linkedin" class="icon-svg-22" src="/img/lni.svg" title="Share Linkedin"/>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="region region-content">
#        <div class="block block-system" id="block-system-main">
#         <article class="node node-stat2 clearfix" id="node-43845" itemscope="" itemtype="https://schema.org/ItemPage">
#          <header>
#          </header>
#          <div class="book-navigation" id="book-navigation-U43811">
#           <div class="page-links clearfix">
#            <a class="page-previous" href="https://datosmacro.expansion.com/otros/coronavirus/chipre" title="Ir a la página anterior">
#             ‹ Chipre - COVID-19 - Crisis del coronavirus
#            </a>
#            <a class="page-next" href="https://datosmacro.expansion.com/otros/coronavirus/comoras" title="Ir a la página siguiente">
#             Comoras - COVID-19 - Crisis del coronavirus ›
#            </a>
#           </div>
#          </div>
#          <div class="row">
#           <div class="col-sm-12">
#            <div class="field-item even">
#             <article itemscope="" itemtype="https://schema.org/NewsArticle">
#              <meta content="2020-12-04 01:24:28" itemprop="dateCreated"/>
#              <p class="art-ante">
#               CORONAVIRUS Colombia el 2 de diciembre de 2020
#              </p>
#              <h2 class="art-title" itemprop="headline">
#              </h2>
#              <div itemprop="articleBody">
#               <p>
#                Colombia contabiliza, 1.334.089 personas confirmadas de coronavirus, 9.297 personas confirmadas más que el día anterior.
#               </p>
#               <p>
#                Para interpretar estos datos, conviene saber que
#                <a href="/paises/colombia">
#                 Colombia
#                </a>
#                , con 49.834.000 de habitantes,
# puede considerarse un país con un número de habitantes significativo, como puede comprobarse en la tabla de
#                <a href="/demografia/poblacion">
#                 población mundial
#                </a>
#                que publicamos en datosmacro.com.
#               </p>
#               <p>
#                En la tabla inferior podemos ver que la tasa de pacientes confirmados de coronavirus es de 2.677,07 por cada cien mil habitantes, así pues tiene una
#                <strong>
#                 alta tasa de confirmados de coronavirus
#                </strong>
#                si la comparamos con la del resto de los países.
#               </p>
#               <p>
#                En este momento hay 37.117 personas fallecidas por coronavirus, en la última jornada 183 personas han muerto, una cifra mayor que la del día previo En Colombia en 2018 fallecieron de media al día 759 personas, cifra que este año podría verse incrementada por la cifra de muertes por coronavirus. Si estás interesado, puedes consultar las cifras de la
#                <a href="/demografia/mortalidad/colombia">
#                 mortalidad de Colombia
#                </a>
#                .
# La tasa de letalidad (fallecidos respecto a confirmados) es del 2,78%
#               </p>
#               <p>
#                Puedes ver el listado de los países con casos de coronavirus en
#                <a href="/otros/coronavirus">
#                 Datos de coronavirus por países
#                </a>
#                y ver toda la información económica de Colombia en
#                <a href="/paises/colombia">
#                 Economía de Colombia.
#                </a>
#               </p>
#               <p>
#               </p>
#               <p>
#                En la siguiente tabla puedes ver la evolución del coronavirus en Colombia.
#               </p>
#              </div>
#             </article>
#            </div>
#           </div>
#          </div>
#          <div class="publicidad adslotrobaM" id="div-gpt-ad-dm_rM">
#           <script>
#            if (adsIsDesktop==0) googletag.cmd.push(function () { googletag.display('div-gpt-ad-dm_rM'); });
#           </script>
#          </div>
#          <div class="row">
#           <div class="col-sm-12">
#            <div class="tabletit">
#             Colombia - COVID-19 - Crisis del coronavirus
#            </div>
#            <div class="table-responsive">
#             <script>
#              jQuery(document).ready(function(){  jQuery("#tb").tablesorter();}
# );
#             </script>
#             <table class="table tabledat table-striped table-condensed table-hover" id="tb">
#              <thead>
#               <tr class="tableheader">
#                <th>
#                 Fecha
#                </th>
#                <th title="COVID-19 - Incremento Muertos">
#                 Incremento Muertos
#                </th>
#                <th title="COVID-19 - Muertos">
#                 Muertos
#                </th>
#                <th title="COVID-19 - Muertos por millón habitantes">
#                 Muertos / millón
#                </th>
#                <th title="COVID-19 - Incremento Confirmados">
#                 Incremento Confirmados
#                </th>
#                <th title="COVID-19 - Confirmados">
#                 Confirmados
#                </th>
#                <th title="COVID-19 - Confirmados por 100.000 habitantes ultimos 14 días">
#                 Confirmados / 100.000 - 14 días
#                </th>
#               </tr>
#              </thead>
#              <tbody>
#               <tr>
#                <td class="fecha" data-value="2020-12-02">
#                 02/12/2020
#                </td>
#                <td class="numero" data-value="183">
#                 183
#                </td>
#                <td class="numero" data-value="37117">
#                 37.117
#                </td>
#                <td class="numero" data-value="744.81">
#                 744,81
#                </td>
#                <td class="numero" data-value="9297">
#                 9.297
#                </td>
#                <td class="numero" data-value="1334089">
#                 1.334.089
#                </td>
#                <td class="numero" data-value="232.95">
#                 232,95
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-12-01">
#                 01/12/2020
#                </td>
#                <td class="numero" data-value="168">
#                 168
#                </td>
#                <td class="numero" data-value="36934">
#                 36.934
#                </td>
#                <td class="numero" data-value="741.14">
#                 741,14
#                </td>
#                <td class="numero" data-value="7986">
#                 7.986
#                </td>
#                <td class="numero" data-value="1324792">
#                 1.324.792
#                </td>
#                <td class="numero" data-value="228.09">
#                 228,09
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-30">
#                 30/11/2020
#                </td>
#                <td class="numero" data-value="182">
#                 182
#                </td>
#                <td class="numero" data-value="36766">
#                 36.766
#                </td>
#                <td class="numero" data-value="737.77">
#                 737,77
#                </td>
#                <td class="numero" data-value="8430">
#                 8.430
#                </td>
#                <td class="numero" data-value="1316806">
#                 1.316.806
#                </td>
#                <td class="numero" data-value="223.92">
#                 223,92
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-29">
#                 29/11/2020
#                </td>
#                <td class="numero" data-value="183">
#                 183
#                </td>
#                <td class="numero" data-value="36584">
#                 36.584
#                </td>
#                <td class="numero" data-value="734.12">
#                 734,12
#                </td>
#                <td class="numero" data-value="8763">
#                 8.763
#                </td>
#                <td class="numero" data-value="1308376">
#                 1.308.376
#                </td>
#                <td class="numero" data-value="219.99">
#                 219,99
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-28">
#                 28/11/2020
#                </td>
#                <td class="numero" data-value="187">
#                 187
#                </td>
#                <td class="numero" data-value="36401">
#                 36.401
#                </td>
#                <td class="numero" data-value="730.45">
#                 730,45
#                </td>
#                <td class="numero" data-value="9103">
#                 9.103
#                </td>
#                <td class="numero" data-value="1299613">
#                 1.299.613
#                </td>
#                <td class="numero" data-value="216.68">
#                 216,68
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-27">
#                 27/11/2020
#                </td>
#                <td class="numero" data-value="195">
#                 195
#                </td>
#                <td class="numero" data-value="36214">
#                 36.214
#                </td>
#                <td class="numero" data-value="726.69">
#                 726,69
#                </td>
#                <td class="numero" data-value="10023">
#                 10.023
#                </td>
#                <td class="numero" data-value="1290510">
#                 1.290.510
#                </td>
#                <td class="numero" data-value="216.34">
#                 216,34
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-26">
#                 26/11/2020
#                </td>
#                <td class="numero" data-value="159">
#                 159
#                </td>
#                <td class="numero" data-value="36019">
#                 36.019
#                </td>
#                <td class="numero" data-value="722.78">
#                 722,78
#                </td>
#                <td class="numero" data-value="9496">
#                 9.496
#                </td>
#                <td class="numero" data-value="1280487">
#                 1.280.487
#                </td>
#                <td class="numero" data-value="213.66">
#                 213,66
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-25">
#                 25/11/2020
#                </td>
#                <td class="numero" data-value="183">
#                 183
#                </td>
#                <td class="numero" data-value="35860">
#                 35.860
#                </td>
#                <td class="numero" data-value="719.59">
#                 719,59
#                </td>
#                <td class="numero" data-value="8497">
#                 8.497
#                </td>
#                <td class="numero" data-value="1270991">
#                 1.270.991
#                </td>
#                <td class="numero" data-value="212.03">
#                 212,03
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-24">
#                 24/11/2020
#                </td>
#                <td class="numero" data-value="198">
#                 198
#                </td>
#                <td class="numero" data-value="35677">
#                 35.677
#                </td>
#                <td class="numero" data-value="715.92">
#                 715,92
#                </td>
#                <td class="numero" data-value="7515">
#                 7.515
#                </td>
#                <td class="numero" data-value="1262494">
#                 1.262.494
#                </td>
#                <td class="numero" data-value="214.99">
#                 214,99
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-23">
#                 23/11/2020
#                </td>
#                <td class="numero" data-value="192">
#                 192
#                </td>
#                <td class="numero" data-value="35479">
#                 35.479
#                </td>
#                <td class="numero" data-value="711.94">
#                 711,94
#                </td>
#                <td class="numero" data-value="6562">
#                 6.562
#                </td>
#                <td class="numero" data-value="1254979">
#                 1.254.979
#                </td>
#                <td class="numero" data-value="212.54">
#                 212,54
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-22">
#                 22/11/2020
#                </td>
#                <td class="numero" data-value="183">
#                 183
#                </td>
#                <td class="numero" data-value="35287">
#                 35.287
#                </td>
#                <td class="numero" data-value="708.09">
#                 708,09
#                </td>
#                <td class="numero" data-value="7924">
#                 7.924
#                </td>
#                <td class="numero" data-value="1248417">
#                 1.248.417
#                </td>
#                <td class="numero" data-value="209.76">
#                 209,76
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-21">
#                 21/11/2020
#                </td>
#                <td class="numero" data-value="175">
#                 175
#                </td>
#                <td class="numero" data-value="35104">
#                 35.104
#                </td>
#                <td class="numero" data-value="704.42">
#                 704,42
#                </td>
#                <td class="numero" data-value="7049">
#                 7.049
#                </td>
#                <td class="numero" data-value="1240493">
#                 1.240.493
#                </td>
#                <td class="numero" data-value="208.79">
#                 208,79
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-20">
#                 20/11/2020
#                </td>
#                <td class="numero" data-value="168">
#                 168
#                </td>
#                <td class="numero" data-value="34929">
#                 34.929
#                </td>
#                <td class="numero" data-value="700.91">
#                 700,91
#                </td>
#                <td class="numero" data-value="7954">
#                 7.954
#                </td>
#                <td class="numero" data-value="1233444">
#                 1.233.444
#                </td>
#                <td class="numero" data-value="212.13">
#                 212,13
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-19">
#                 19/11/2020
#                </td>
#                <td class="numero" data-value="198">
#                 198
#                </td>
#                <td class="numero" data-value="34761">
#                 34.761
#                </td>
#                <td class="numero" data-value="697.54">
#                 697,54
#                </td>
#                <td class="numero" data-value="7487">
#                 7.487
#                </td>
#                <td class="numero" data-value="1225490">
#                 1.225.490
#                </td>
#                <td class="numero" data-value="215.74">
#                 215,74
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-18">
#                 18/11/2020
#                </td>
#                <td class="numero" data-value="182">
#                 182
#                </td>
#                <td class="numero" data-value="34563">
#                 34.563
#                </td>
#                <td class="numero" data-value="693.56">
#                 693,56
#                </td>
#                <td class="numero" data-value="6875">
#                 6.875
#                </td>
#                <td class="numero" data-value="1218003">
#                 1.218.003
#                </td>
#                <td class="numero" data-value="220.57">
#                 220,57
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-17">
#                 17/11/2020
#                </td>
#                <td class="numero" data-value="158">
#                 158
#                </td>
#                <td class="numero" data-value="34381">
#                 34.381
#                </td>
#                <td class="numero" data-value="689.91">
#                 689,91
#                </td>
#                <td class="numero" data-value="5911">
#                 5.911
#                </td>
#                <td class="numero" data-value="1211128">
#                 1.211.128
#                </td>
#                <td class="numero" data-value="224.22">
#                 224,22
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-16">
#                 16/11/2020
#                </td>
#                <td class="numero" data-value="192">
#                 192
#                </td>
#                <td class="numero" data-value="34223">
#                 34.223
#                </td>
#                <td class="numero" data-value="686.74">
#                 686,74
#                </td>
#                <td class="numero" data-value="6471">
#                 6.471
#                </td>
#                <td class="numero" data-value="1205217">
#                 1.205.217
#                </td>
#                <td class="numero" data-value="224.67">
#                 224,67
#                </td>
#               </tr>
#               <tr>
#                <td class="fecha" data-value="2020-11-15">
#                 15/11/2020
#                </td>
#                <td class="numero" data-value="202">
#                 202
#                </td>
#                <td class="numero" data-value="34031">
#                 34.031
#                </td>
# ...
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/nigeria" onclick="gaFlg();" title="Nigeria">
#            <span class="sprflag NGp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/noruega" onclick="gaFlg();" title="Noruega">
#            <span class="sprflag NOp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-009">
#           <a href="/paises/nueva-zelanda" onclick="gaFlg();" title="Nueva Zelanda">
#            <span class="sprflag NZp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/oman" onclick="gaFlg();" title="Omán">
#            <span class="sprflag OMp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/paises-bajos" onclick="gaFlg();" title="Países Bajos">
#            <span class="sprflag NLp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/pakistan" onclick="gaFlg();" title="Pakistán">
#            <span class="sprflag PKp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-009">
#           <a href="/paises/palaos" onclick="gaFlg();" title="Palaos">
#            <span class="sprflag PWp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/panama" onclick="gaFlg();" title="Panamá">
#            <span class="sprflag PAp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-009">
#           <a href="/paises/papua-nueva-guinea" onclick="gaFlg();" title="Papúa Nueva Guinea">
#            <span class="sprflag PGp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/paraguay" onclick="gaFlg();" title="Paraguay">
#            <span class="sprflag PYp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/peru" onclick="gaFlg();" title="Perú">
#            <span class="sprflag PEp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/polonia" onclick="gaFlg();" title="Polonia">
#            <span class="sprflag PLp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/portugal" onclick="gaFlg();" title="Portugal">
#            <span class="sprflag PTp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/uk" onclick="gaFlg();" title="Reino Unido">
#            <span class="sprflag GBp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/republica-centroafricana" onclick="gaFlg();" title="República Centroafricana">
#            <span class="sprflag CFp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/republica-checa" onclick="gaFlg();" title="República Checa">
#            <span class="sprflag CZp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/congo" onclick="gaFlg();" title="República del Congo">
#            <span class="sprflag CGp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/republica-democratica-congo" onclick="gaFlg();" title="República Democrática del Congo">
#            <span class="sprflag CDp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/republica-dominicana" onclick="gaFlg();" title="República Dominicana">
#            <span class="sprflag DOp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/ruanda" onclick="gaFlg();" title="Ruanda">
#            <span class="sprflag RWp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/rumania" onclick="gaFlg();" title="Rumanía">
#            <span class="sprflag ROp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/rusia" onclick="gaFlg();" title="Rusia">
#            <span class="sprflag RUp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-009">
#           <a href="/paises/samoa" onclick="gaFlg();" title="Samoa">
#            <span class="sprflag WSp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/san-cristobal-nieves" onclick="gaFlg();" title="San Cristóbal y Nieves">
#            <span class="sprflag KNp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/san-marino" onclick="gaFlg();" title="San Marino">
#            <span class="sprflag SMp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/san-vicente-las-granadinas" onclick="gaFlg();" title="San Vicente y las Granadinas">
#            <span class="sprflag VCp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/santa-lucia" onclick="gaFlg();" title="Santa Lucía">
#            <span class="sprflag LCp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/santo-tome-principe" onclick="gaFlg();" title="Santo Tomé y Príncipe">
#            <span class="sprflag STp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/senegal" onclick="gaFlg();" title="Senegal">
#            <span class="sprflag SNp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/serbia" onclick="gaFlg();" title="Serbia">
#            <span class="sprflag RSp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/seychelles" onclick="gaFlg();" title="Seychelles">
#            <span class="sprflag SCp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/sierra-leona" onclick="gaFlg();" title="Sierra Leona">
#            <span class="sprflag SLp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/singapur" onclick="gaFlg();" title="Singapur">
#            <span class="sprflag SGp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/siria" onclick="gaFlg();" title="Siria">
#            <span class="sprflag SYp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/somalia" onclick="gaFlg();" title="Somalia">
#            <span class="sprflag SOp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/sri-lanka" onclick="gaFlg();" title="Sri Lanka">
#            <span class="sprflag LKp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/suazilandia" onclick="gaFlg();" title="Suazilandia">
#            <span class="sprflag SZp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/sudafrica" onclick="gaFlg();" title="Sudáfrica">
#            <span class="sprflag ZAp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/sudan" onclick="gaFlg();" title="Sudán">
#            <span class="sprflag SDp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/sudan-del-sur" onclick="gaFlg();" title="Sudán del Sur">
#            <span class="sprflag SSp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/suecia" onclick="gaFlg();" title="Suecia">
#            <span class="sprflag SEp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/suiza" onclick="gaFlg();" title="Suiza">
#            <span class="sprflag CHp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/surinam" onclick="gaFlg();" title="Surinam">
#            <span class="sprflag SRp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/tailandia" onclick="gaFlg();" title="Tailandia">
#            <span class="sprflag THp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/taiwan" onclick="gaFlg();" title="Taiwan">
#            <span class="sprflag TWp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/tanzania" onclick="gaFlg();" title="Tanzania">
#            <span class="sprflag TZp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/tayikistan" onclick="gaFlg();" title="Tayikistán">
#            <span class="sprflag TJp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/timor-oriental" onclick="gaFlg();" title="Timor Oriental">
#            <span class="sprflag TLp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/togo" onclick="gaFlg();" title="Togo">
#            <span class="sprflag TGp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-009">
#           <a href="/paises/tonga" onclick="gaFlg();" title="Tonga">
#            <span class="sprflag TOp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/trinidad-tobago" onclick="gaFlg();" title="Trinidad y Tobago">
#            <span class="sprflag TTp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/tunez" onclick="gaFlg();" title="Túnez">
#            <span class="sprflag TNp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/turkmenistan" onclick="gaFlg();" title="Turkmenistán">
#            <span class="sprflag TMp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/turquia" onclick="gaFlg();" title="Turquía">
#            <span class="sprflag TRp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-009">
#           <a href="/paises/tuvalu" onclick="gaFlg();" title="Tuvalu">
#            <span class="sprflag TVp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/ucrania" onclick="gaFlg();" title="Ucrania">
#            <span class="sprflag UAp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/uganda" onclick="gaFlg();" title="Uganda">
#            <span class="sprflag UGp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/uruguay" onclick="gaFlg();" title="Uruguay">
#            <span class="sprflag UYp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/uzbekistan" onclick="gaFlg();" title="Uzbekistán">
#            <span class="sprflag UZp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-009">
#           <a href="/paises/vanuatu" onclick="gaFlg();" title="Vanuatu">
#            <span class="sprflag VUp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-019">
#           <a href="/paises/venezuela" onclick="gaFlg();" title="Venezuela">
#            <span class="sprflag VEp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/vietnam" onclick="gaFlg();" title="Vietnam">
#            <span class="sprflag VNp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-142">
#           <a href="/paises/yemen" onclick="gaFlg();" title="Yemen">
#            <span class="sprflag YEp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/yibuti" onclick="gaFlg();" title="Yibuti">
#            <span class="sprflag DJp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/zambia" onclick="gaFlg();" title="Zambia">
#            <span class="sprflag ZMp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-002">
#           <a href="/paises/zimbabue" onclick="gaFlg();" title="Zimbabue">
#            <span class="sprflag ZWp">
#            </span>
#           </a>
#          </div>
#          <div class="flg flg-150">
#           <a href="/paises/zona-euro" onclick="gaFlg();" title="Zona Euro">
#            <span class="sprflag EAp">
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="block block-block" id="block-block-22">
#         <div class="publicidad" id="div-gpt-ad-dm_rc">
#          <script>
#           googletag.cmd.push(function () { googletag.display('div-gpt-ad-dm_rc'); });
#          </script>
#         </div>
#        </div>
#       </div>
#      </aside>
#      <!-- /#sidebar-second -->
#     </div>
#    </div>
#    <footer class="footer container">
#     <div class="region region-footer">
#      <div class="block block-block" id="block-block-56">
#       <div class="publicidad publicidad-inferior">
#        <div class="publicidad adsdesktop" id="div-gpt-ad-dm_mb">
#         <script>
#          googletag.cmd.push(function () { googletag.display('div-gpt-ad-dm_mb'); });
#         </script>
#        </div>
#       </div>
#      </div>
#      <div class="block block-menu" id="block-menu-secondary-menu">
#       <ul class="menu nav navbar-nav">
#        <li class="first leaf">
#         <a href="https://datosmacro.expansion.com/legal/acerca-de" title="">
#          Copyright Datosmacro.com
#         </a>
#        </li>
#        <li class="leaf">
#         <a href="https://datosmacro.expansion.com/legal/terminos" title="">
#          Aviso legal
#         </a>
#        </li>
#        <li class="leaf">
#         <a href="https://datosmacro.expansion.com/legal/fuentes" title="">
#          Fuentes
#         </a>
#        </li>
#        <li class="leaf">
#         <a href="http://cookies.unidadeditorial.es/" title="">
#          Política de cookies
#         </a>
#        </li>
#        <li class="last leaf">
#         <a href="https://datosmacro.expansion.com/legal/renuncia" title="">
#          Renuncia de responsabilidad
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </footer>
#    <div class="isfront">
#     <div class="publicidad_lateral_a adsdesktop">
#      <div class="publicidad" id="div-gpt-ad-dm_si">
#       <script>
#        googletag.cmd.push(function () { googletag.display('div-gpt-ad-dm_si'); });
#       </script>
#      </div>
#     </div>
#     <div class="publicidad_lateral_b adsdesktop">
#      <div class="publicidad" id="div-gpt-ad-dm_sd">
#       <script>
#        googletag.cmd.push(function () { googletag.display('div-gpt-ad-dm_sd'); });
#       </script>
#      </div>
#     </div>
#    </div>
#    <script src="https://datosmacro.expansion.com/sites/default/files/js/js_KvrB92EiscwTHE_NFdhxWxwxMXE894Op94-DReG2W4s.js">
#    </script>
#   </div>
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script>
#    TMSBottom();
#   </script>
#  </body>
# </html>

# %%
# Search for the table and extracting it
tableciudad = soup.find('table', attrs={'class': 'tabla1'})
tabledep = soup.find('table', attrs={'class': 'tabla2'})
tableedad = soupedad.find('table', attrs={'class': 'tabla1'})
tablegen = soupgen.find('table', attrs={'id': 'tb'})

# %% [markdown]
# data recolectada

# %%
tableciudad
# Out:
# <table border="0" class="tabla1">
# <thead><tr><td>Ciudad</td><td>Casos</td></tr></thead>
# <tbody>
# <tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ABEJORRAL_5002">ABEJORRAL</a></td><td style="text-align:center;">96</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ABREGO_54003">ABREGO</a></td><td style="text-align:center;">96</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ABRIAQUI_5004">ABRIAQUI</a></td><td style="text-align:center;">23</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ACACIAS_50006">ACACIAS</a></td><td style="text-align:center;">2380</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ACANDI_27006">ACANDI</a></td><td style="text-align:center;">97</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ACEVEDO_41006">ACEVEDO</a></td><td style="text-align:center;">121</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ACHI_13006">ACHI</a></td><td style="text-align:center;">69</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGRADO_41013">AGRADO</a></td><td style="text-align:center;">80</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUA DE DIOS_25001">AGUA DE DIOS</a></td><td style="text-align:center;">103</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUACHICA_20011">AGUACHICA</a></td><td style="text-align:center;">2309</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUADAS_17013">AGUADAS</a></td><td style="text-align:center;">133</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUADA_68013">AGUADA</a></td><td style="text-align:center;">7</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUAZUL_85010">AGUAZUL</a></td><td style="text-align:center;">450</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AGUSTIN CODAZZI_20013">AGUSTIN CODAZZI</a></td><td style="text-align:center;">1227</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=AIPE_41016">AIPE</a></td><td style="text-align:center;">233</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALBAN (SAN JOSE)_52019">ALBAN SAN JOSE</a></td><td style="text-align:center;">99</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALBANIA_18029">ALBANIA</a></td><td style="text-align:center;">186</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALBANIA_44035">ALBANIA</a></td><td style="text-align:center;">337</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALBANIA_68020">ALBANIA</a></td><td style="text-align:center;">5</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALBAN_25019">ALBAN</a></td><td style="text-align:center;">71</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALCALA_76020">ALCALA</a></td><td style="text-align:center;">163</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALDANA_52022">ALDANA</a></td><td style="text-align:center;">56</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALEJANDRIA_5021">ALEJANDRIA</a></td><td style="text-align:center;">21</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALGARROBO_47030">ALGARROBO</a></td><td style="text-align:center;">70</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALGECIRAS_41020">ALGECIRAS</a></td><td style="text-align:center;">369</td></tr><tr><td><a href="https://coronavirus.wilkinsonpc.com.co/casos-por-ciudad.html?c=ALMAGUER_19022">ALMAGU ...
# </table>

# %%
tabledep
# Out:
# <table border="0" class="tabla2">
# <thead><tr><td>Departamento</td><td>Casos</td></tr></thead>
# <tbody>
# <tr><td><a href="/casos-por-departamento.html?d=AMAZONAS">AMAZONAS</a></td><td style="text-align:center;">3159</td></tr><tr><td><a href="/casos-por-departamento.html?d=ANTIOQUIA">ANTIOQUIA</a></td><td style="text-align:center;">220859</td></tr><tr><td><a href="/casos-por-departamento.html?d=ARAUCA">ARAUCA</a></td><td style="text-align:center;">4201</td></tr><tr><td><a href="/casos-por-departamento.html?d=ATLANTICO">ATLANTICO</a></td><td style="text-align:center;">33373</td></tr><tr><td><a href="/casos-por-departamento.html?d=BARRANQUILLA">BARRANQUILLA</a></td><td style="text-align:center;">46532</td></tr><tr><td><a href="/casos-por-departamento.html?d=BOGOTA">BOGOTA</a></td><td style="text-align:center;">387418</td></tr><tr><td><a href="/casos-por-departamento.html?d=BOLIVAR">BOLIVAR</a></td><td style="text-align:center;">7301</td></tr><tr><td><a href="/casos-por-departamento.html?d=BOYACA">BOYACA</a></td><td style="text-align:center;">22862</td></tr><tr><td><a href="/casos-por-departamento.html?d=CALDAS">CALDAS</a></td><td style="text-align:center;">26489</td></tr><tr><td><a href="/casos-por-departamento.html?d=CAQUETA">CAQUETA</a></td><td style="text-align:center;">13619</td></tr><tr><td><a href="/casos-por-departamento.html?d=CARTAGENA">CARTAGENA</a></td><td style="text-align:center;">32999</td></tr><tr><td><a href="/casos-por-departamento.html?d=CASANARE">CASANARE</a></td><td style="text-align:center;">7296</td></tr><tr><td><a href="/casos-por-departamento.html?d=CAUCA">CAUCA</a></td><td style="text-align:center;">16206</td></tr><tr><td><a href="/casos-por-departamento.html?d=CESAR">CESAR</a></td><td style="text-align:center;">30391</td></tr><tr><td><a href="/casos-por-departamento.html?d=CHOCO">CHOCO</a></td><td style="text-align:center;">4563</td></tr><tr><td><a href="/casos-por-departamento.html?d=CORDOBA">CORDOBA</a></td><td style="text-align:center;">28486</td></tr><tr><td><a href="/casos-por-departamento.html?d=CUNDINAMARCA">CUNDINAMARCA</a></td><td style="text-align:center;">54753</td></tr><tr><td><a href="/casos-por-departamento.html?d=GUAINIA">GUAINIA</a></td><td style="text-align:center;">1210</td></tr><tr><td><a href="/casos-por-departamento.html?d=GUAJIRA">GUAJIRA</a></td><td style="text-align:center;">12357</td></tr><tr><td><a href="/casos-por-departamento.html?d=GUAVIARE">GUAVIARE</a></td><td style="text-align:center;">1863</td></tr><tr><td><a href="/casos-por-departamento.html?d=HUILA">HUILA</a></td><td style="text-align:center;">30870</td></tr><tr><td><a href="/casos-por-departamento.html?d=MAGDALENA">MAGDALENA</a></td><td style="text-align:center;">6802</td></tr><tr><td><a href="/casos-por-departamento.html?d=META">META</a></td><td style="text-align:center;">29074</td></tr><tr><td><a href="/casos-por-departamento.html?d=NARIÑO">NARIÑO</a></td><td style="text-align:center;">26186</td></tr><tr><td><a href="/casos-por-departamento.html?d=NORTE SANTANDER">NORTE SANTANDER</a></td><td style="text-align:center;">30733</td></tr><tr><td><a href="/casos-por-departamento.html?d=PUTUMAYO">PUTUMAYO</a></td><td style="text-align:center;">5103</td></tr><tr><td><a href="/casos-por-departamento.html?d=QUINDIO">QUINDIO</a></td><td style="text-align:center;">18179</td></tr><tr><td><a href="/casos-por-departamento.html?d=RISARALDA">RISARALDA</a></td><td style="text-align:center;">24619</td></tr><tr><td><a href="/casos-por-departamento.html?d=SAN ANDRES">SAN ANDRES</a></td><td style="text-align:center;">2239</td></tr><tr><td><a href="/casos-por-departamento.html?d=SANTANDER">SANTANDER</a></td><td style="text-align:center;">55434</td></tr><tr><td><a href="/casos-por-departamento.html?d=STA MARTA D.E.">STA MARTA D.E.</a></td><td style="text-align:center;">14279</td></tr><tr><td><a href="/casos-por-departamento.html?d=SUCRE">SUCRE</a></td><td style="text-align:center;">16714</td></tr><tr><td><a href="/casos-por-departamento.html?d=TOLIMA">TOLIMA</a></td><td style="text-align:center;">31353</td></tr><tr><td><a href="/casos-por-dep ...
# </table>

# %%
tableedad
# Out:
# <table border="0" class="tabla1">
# <thead>
# <tr class="hidden-xs hidden-sm"><td style="text-align:center;font-weight:bold;">Edad</td><td style="text-align:center;font-weight:bold;">Mujeres</td><td style="text-align:center;font-weight:bold;">Hombres</td><td style="text-align:center;font-weight:bold;">Recuperados</td><td style="text-align:center;font-weight:bold;">Fallecidos</td><td style="text-align:center;font-weight:bold;">Críticos</td><td style="text-align:center;font-weight:bold;">Hospital</td><td style="text-align:center;font-weight:bold;">Casa</td><td style="text-align:center;font-weight:bold;">Total</td></tr></thead>
# <tr class="visible-xs visible-sm"><td style="font-size:2.2em;color:#666;text-align:center;"><i class="fas fa-id-card"></i></td><td style="font-size:2.2em;color:#C822FF;text-align:center;"><i class="fas fa-female"></i></td><td style="font-size:2.2em;color:#265CFF;text-align:center;"><i class="fas fa-male"></i></td><td style="font-size:2.2em;color:#008C23;text-align:center;"><i class="fas fa-thumbs-up"></i></td><td style="font-size:2.2em;color:#000;text-align:center;"><i class="fas fa-ribbon"></i></td><td style="font-size:2.2em;color:#666;text-align:center;"><i class="fas fa-equals"></i></td></tr>
# <tbody>
# <tr><td nowrap="">0 a 9</td><td style="text-align:center;">22034</td><td style="text-align:center;">23138</td><td style="text-align:center;">42459</td><td style="text-align:center;">57</td><td style="text-align:center;">71</td><td style="text-align:center;">1023</td><td style="text-align:center;">1506</td><td style="text-align:center;">45172</td></tr><tr><td nowrap="">10 a 19</td><td style="text-align:center;">43412</td><td style="text-align:center;">43753</td><td style="text-align:center;">82988</td><td style="text-align:center;">54</td><td style="text-align:center;">40</td><td style="text-align:center;">484</td><td style="text-align:center;">3550</td><td style="text-align:center;">87165</td></tr><tr><td nowrap="">20 a 29</td><td style="text-align:center;">155295</td><td style="text-align:center;">145124</td><td style="text-align:center;">286039</td><td style="text-align:center;">412</td><td style="text-align:center;">88</td><td style="text-align:center;">1502</td><td style="text-align:center;">12232</td><td style="text-align:center;">300419</td></tr><tr><td nowrap="">30 a 39</td><td style="text-align:center;">156810</td><td style="text-align:center;">161717</td><td style="text-align:center;">302954</td><td style="text-align:center;">1027</td><td style="text-align:center;">196</td><td style="text-align:center;">1999</td><td style="text-align:center;">12219</td><td style="text-align:center;">318527</td></tr><tr><td nowrap="">40 a 49</td><td style="text-align:center;">111484</td><td style="text-align:center;">110654</td><td style="text-align:center;">208854</td><td style="text-align:center;">2221</td><td style="text-align:center;">281</td><td style="text-align:center;">2188</td><td style="text-align:center;">8386</td><td style="text-align:center;">222138</td></tr><tr><td nowrap="">50 a 59</td><td style="text-align:center;">92832</td><td style="text-align:center;">89590</td><td style="text-align:center;">166659</td><td style="text-align:center;">4852</td><td style="text-align:center;">523</td><td style="text-align:center;">3159</td><td style="text-align:center;">6879</td><td style="text-align:center;">182422</td></tr><tr><td nowrap="">60 a 69</td><td style="text-align:center;">54972</td><td style="text-align:center;">55538</td><td style="text-align:center;">93348</td><td style="text-align:center;">8662</td><td style="text-align:center;">582</td><td style="text-align:center;">3330</td><td style="text-align:center;">3935</td><td style="text-align:center;">110510</td></tr><tr><td nowrap="">70 a 79</td><td style="text-align:center;">28658</td><td style="text-align:center;">30594</td><td style="text-align:center;">43852</td><td style="text-align:center;">9915</td><td style="text-align:center;">427</td><td style="text-align:center;">2486</td><td style="text-align:center;">1839</td><td style="text-align:center;">59252</td></tr><tr><td nowrap="">80 a 89</td><td style="text-align:center;">15418</td><td style="text-align:center;">14795</td><td style="text-align:center;">19007</td><td style="text-align:center;">8183</td><td style="text-align:center;">165</td><td style="text-align:center;">1371</td><td style="text-align:center;">819</td><td style="text-align:center;">30213</td></tr><tr><td nowrap="">90 a 99</td><td style="text-align:center;">3426</td><td style="text-align:center;">2756</td><td style="text-align:center;">3404</td><td style="text-align:center;">2172</td><td style="text-align:center;">15</td><td style="text-align:center;">236</td><td style="text-align:center;">156</td><td style="text-align:center;">6182</td></tr><tr><td nowrap="">100 a 109</td><td style="text-align:center;">149</td><td style="text-align:center;">97</td><td style="text-align:center;">136</td><td style="text-align:center;">78</td><td style="text-align:center;">0</td><td style="text-align:center;">12</td><td style="text-align:center;">5</td><td style="text-align:center;">246</td></tr><tr><td nowrap="">110 a 119</td><td style="text-align:center;">1</td><td style=" ...
# </tbody>
# </table>

# %%
tablegen
# Out:
# <table class="table tabledat table-striped table-condensed table-hover" id="tb">
# <thead><tr class="tableheader"><th>Fecha</th><th title="COVID-19 - Incremento Muertos">Incremento Muertos</th><th title="COVID-19 - Muertos">Muertos</th><th title="COVID-19 - Muertos por millón habitantes">Muertos / millón</th><th title="COVID-19 - Incremento Confirmados">Incremento Confirmados</th><th title="COVID-19 - Confirmados">Confirmados</th><th title="COVID-19 - Confirmados por 100.000 habitantes ultimos 14 días">Confirmados / 100.000 - 14 días</th></tr></thead><tbody><tr><td class="fecha" data-value="2020-12-02">02/12/2020</td><td class="numero" data-value="183">183</td><td class="numero" data-value="37117">37.117</td><td class="numero" data-value="744.81">744,81</td><td class="numero" data-value="9297">9.297</td><td class="numero" data-value="1334089">1.334.089</td><td class="numero" data-value="232.95">232,95</td></tr><tr><td class="fecha" data-value="2020-12-01">01/12/2020</td><td class="numero" data-value="168">168</td><td class="numero" data-value="36934">36.934</td><td class="numero" data-value="741.14">741,14</td><td class="numero" data-value="7986">7.986</td><td class="numero" data-value="1324792">1.324.792</td><td class="numero" data-value="228.09">228,09</td></tr><tr><td class="fecha" data-value="2020-11-30">30/11/2020</td><td class="numero" data-value="182">182</td><td class="numero" data-value="36766">36.766</td><td class="numero" data-value="737.77">737,77</td><td class="numero" data-value="8430">8.430</td><td class="numero" data-value="1316806">1.316.806</td><td class="numero" data-value="223.92">223,92</td></tr><tr><td class="fecha" data-value="2020-11-29">29/11/2020</td><td class="numero" data-value="183">183</td><td class="numero" data-value="36584">36.584</td><td class="numero" data-value="734.12">734,12</td><td class="numero" data-value="8763">8.763</td><td class="numero" data-value="1308376">1.308.376</td><td class="numero" data-value="219.99">219,99</td></tr><tr><td class="fecha" data-value="2020-11-28">28/11/2020</td><td class="numero" data-value="187">187</td><td class="numero" data-value="36401">36.401</td><td class="numero" data-value="730.45">730,45</td><td class="numero" data-value="9103">9.103</td><td class="numero" data-value="1299613">1.299.613</td><td class="numero" data-value="216.68">216,68</td></tr><tr><td class="fecha" data-value="2020-11-27">27/11/2020</td><td class="numero" data-value="195">195</td><td class="numero" data-value="36214">36.214</td><td class="numero" data-value="726.69">726,69</td><td class="numero" data-value="10023">10.023</td><td class="numero" data-value="1290510">1.290.510</td><td class="numero" data-value="216.34">216,34</td></tr><tr><td class="fecha" data-value="2020-11-26">26/11/2020</td><td class="numero" data-value="159">159</td><td class="numero" data-value="36019">36.019</td><td class="numero" data-value="722.78">722,78</td><td class="numero" data-value="9496">9.496</td><td class="numero" data-value="1280487">1.280.487</td><td class="numero" data-value="213.66">213,66</td></tr><tr><td class="fecha" data-value="2020-11-25">25/11/2020</td><td class="numero" data-value="183">183</td><td class="numero" data-value="35860">35.860</td><td class="numero" data-value="719.59">719,59</td><td class="numero" data-value="8497">8.497</td><td class="numero" data-value="1270991">1.270.991</td><td class="numero" data-value="212.03">212,03</td></tr><tr><td class="fecha" data-value="2020-11-24">24/11/2020</td><td class="numero" data-value="198">198</td><td class="numero" data-value="35677">35.677</td><td class="numero" data-value="715.92">715,92</td><td class="numero" data-value="7515">7.515</td><td class="numero" data-value="1262494">1.262.494</td><td class="numero" data-value="214.99">214,99</td></tr><tr><td class="fecha" data-value="2020-11-23">23/11/2020</td><td class="numero" data-value="192">192</td><td class="numero" data-value="35479">35.479</td><td class="numero" data-value="711.94">711,94</td><td class="numero" data-value="6562">6.562</td><td class="numero" data-va ...

# %% [markdown]
# Se guarda la data recolectada en arreglos

# %%
dataciudad = []
table_rowsciudad = tableciudad.find_all('tr')
for tr in table_rowsciudad:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    dataciudad.append(row)

datadepartamento = []
table_rowsdep = tabledep.find_all('tr')
for tr in table_rowsdep:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    datadepartamento.append(row)

dataedad = []
table_rowsedad = tableedad.find_all('tr')
for tr in table_rowsedad:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    dataedad.append(row)

datageneral = []
table_rowsgen = tablegen.find_all('tr')
for tr in table_rowsgen:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    datageneral.append(row)

# %%
datadepartamento
# Out:
# [['Departamento', 'Casos'],
#  ['AMAZONAS', '3159'],
#  ['ANTIOQUIA', '220859'],
#  ['ARAUCA', '4201'],
#  ['ATLANTICO', '33373'],
#  ['BARRANQUILLA', '46532'],
#  ['BOGOTA', '387418'],
#  ['BOLIVAR', '7301'],
#  ['BOYACA', '22862'],
#  ['CALDAS', '26489'],
#  ['CAQUETA', '13619'],
#  ['CARTAGENA', '32999'],
#  ['CASANARE', '7296'],
#  ['CAUCA', '16206'],
#  ['CESAR', '30391'],
#  ['CHOCO', '4563'],
#  ['CORDOBA', '28486'],
#  ['CUNDINAMARCA', '54753'],
#  ['GUAINIA', '1210'],
#  ['GUAJIRA', '12357'],
#  ['GUAVIARE', '1863'],
#  ['HUILA', '30870'],
#  ['MAGDALENA', '6802'],
#  ['META', '29074'],
#  ['NARIÑO', '26186'],
#  ['NORTE SANTANDER', '30733'],
#  ['PUTUMAYO', '5103'],
#  ['QUINDIO', '18179'],
#  ['RISARALDA', '24619'],
#  ['SAN ANDRES', '2239'],
#  ['SANTANDER', '55434'],
#  ['STA MARTA D.E.', '14279'],
#  ['SUCRE', '16714'],
#  ['TOLIMA', '31353'],
#  ['VALLE', '112671'],
#  ['VAUPES', '1123'],
#  ['VICHADA', '933']]

# %%
dtgen = pd.DataFrame(datageneral, columns=["Fecha" ,"Incremento Muertos", "Muertos", "Muertos / millón", "Incremento Confirmados", "Confirmados", "Confirmados / 100.000 - 14 días"])
dtedad = pd.DataFrame(dataedad, columns=["Edad","Mujeres","Hombres","Recuperados","Fallecidos","Críticos","Hospital","Casa","Total"])
dtciudad = pd.DataFrame(dataciudad, columns=["Ciudad","Casos"])
dtdepartamento = pd.DataFrame(datadepartamento, columns=["Departamento","Casos"])

# %%
dtgen
# Out:
#           Fecha Incremento Muertos  ... Confirmados Confirmados / 100.000 - 14 días
# 0          None               None  ...        None                            None
# 1    02/12/2020                183  ...   1.334.089                          232,95
# 2    01/12/2020                168  ...   1.324.792                          228,09
# 3    30/11/2020                182  ...   1.316.806                          223,92
# 4    29/11/2020                183  ...   1.308.376                          219,99
# ..          ...                ...  ...         ...                             ...
# 96   29/08/2020                297  ...     599.884                          287,34
# 97   28/08/2020                299  ...     590.492                          291,73
# 98   27/08/2020                283  ...     581.995                          297,37
# 99   26/08/2020                295  ...     572.243                          300,45
# 100  25/08/2020                277  ...     562.113                          304,33
#
# [101 rows x 7 columns]

# %%
dtciudad
# Out:
#              Ciudad  Casos
# 0            Ciudad  Casos
# 1         ABEJORRAL     96
# 2            ABREGO     96
# 3          ABRIAQUI     23
# 4           ACACIAS   2380
# ...             ...    ...
# 1107         ZARZAL    690
# 1108      ZETAQUIRA     19
# 1109        ZIPACON     26
# 1110      ZIPAQUIRA   4412
# 1111  ZONA BANANERA    329
#
# [1112 rows x 2 columns]

# %%
dciudad = dtciudad.drop([0],axis=0)

# %%
import plotly.express as px

fig = px.scatter(dtciudad, x='Casos', y='Ciudad')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="01d71b69-9415-42f8-a5bb-e292b128a497" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("01d71b69-9415-42f8-a5bb-e292b128a497")) {
#                     Plotly.newPlot(
#                         '01d71b69-9415-42f8-a5bb-e292b128a497',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Casos=%{x}<br>Ciudad=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": ["Casos", "96", "96", "23", "2380", "97", "121", "69", "80", "103", "2309", "133", "7", "450", "1227", "233", "99", "186", "337", "5", "71", "163", "56", "21", "70", "369", "14", "2", "3", "42", "41", "30", "37", "374", "120", "27", "209", "20", "177", "230", "29", "36", "34", "108", "114", "414", "45", "28", "3953", "70", "78", "245", "75", "32", "2254", "449", "67", "24", "31", "235", "34", "65", "127", "36", "23", "142", "397", "40", "13182", "58", "10", "174", "57", "50", "114", "61", "63", "32", "74", "42", "2332", "75", "556", "920", "255", "12", "34", "9701", "622", "50", "53", "46532", "257", "77", "7", "185", "264", "50", "9", "19289", "18", "2", "5", "46", "34", "21", "2", "22", "70", "387418", "137", "14", "52", "225", "21", "36", "700", "25", "12", "84", "23603", "19", "2929", "27", "102", "40", "271", "42", "167", "245", "3446", "593", "7", "9", "48", "163", "50", "3", "7", "258", "55", "94", "271", "107", "2778", "98", "44", "1958", "11", "4384", "82", "23", "81116", "115", "30", "187", "634", "215", "1384", "264", "114", "16", "37", "19", "283", "29", "3", "12", "1345", "65", "65", "980", "15", "35", "499", "32999", "2416", "42", "6", "214", "898", "86", "5", "2131", "18", "42", "108", "20", "113", "3", "9", "11", "533", "31", "1", "4086", "898", "84", "3", "171", "129", "9", "1212", "378", "197", "6", "1057", "30", "392", "4", "34", "29", "51", "12", "123", "5", "43", "135", "154", "672", "1690", "25", "348", "495", "87", "53", "114", "14", "590", "23", "129", "64", "26", "230", "33", "13", "57", "40", "27", "10", "90", "47", "9", "36", "3039", "14", "308", "64", "78", "68", "2", "1035", "10", "792", "196", "15", "501", "213", "9", "46", "91", "44", "31", "98", "20609", "31", "2", "202", "176", "264", "88", "29", "132", "44", "631", "258", "327", "175", "1", "170", "285", "19", "540", "4966", "3737", "27", "47", "12", "627", "724", "27", "2", "340", "406", "69", "18", "35", "951", "178", "30", "145", "328", "321", "10", "52", "1", "10", "4", "13", "113", "323", "1", "258", "52", "23", "8", "15", "36", "85", "121", "83", "52", "310", "128", "132", "193", "116", "76", "302", "25", "2", "11", "247", "10425", "2088", "2975", "13", "42", "162", "31", "287", "9850", "29", "4", "9", "8585", "712", "54", "693", "124", "13", "49", "127", "309", "51", "75", "765", "32", "2261", "23", "2281", "12", "262", "34", "37", "2", "1735", "119", "101", "6", "12", "12", "63", "1415", "57", "416", "255", "133", "1577", "3114", "4561", "35", "58", "34", "73", "1206", "33", "11", "334", "10", "68", "71", "91", "139", "19", "401", "94", "24", "106", "107", "431", "87", "2", "116", "1135", "94", "96", "3", "21", "98", "40", "9", "3", "25", "5", "9", "1", "20", "23", "63", "298", "3", "64", "31", "18", "65", "85", "345", "23362", "32", "19", "68", "51", "2516", "38", "393", "12360", "1", "188", "1035", "25", "37", "2440", "135", "11", "4", "61", "1", "2", "351", "13", "3", "128", "92", "31", "425", "2", "1259", "53", "14", "329", "88", "1750", "46", "2624", "80", "233", "886", "10", "75", "41", "70", "215", "168", "20", "27", "79", "2", "127", "529", "11", "24", "10", "35", "645", "53", "426", "259", "102", "207", "9", "5", "13", "66", "15", "79", "943", "18", "1", "52", "315", "63", "32", "70", "107", "2893", "265", "65", "32", "2", "14", "11", "1183", "69", "117", "187", "2286", "43", "10", "249", "12", "4", "82", "25", "2307", "1458", "213", "95", "2681", "93", "410", "2966", "80", "312", "95", "173", "18483", "228", "4", "164", "19", "40", "11", "66", "1256", "47", "371", "354", "198", "54", "32", "25", "125828", "5", "21", "28", "1077", "80", "34", "94", "36", "61", "204", "102", "894", "1595", "14", "11", "116", "353", "18", "62", "315", "32", "36", "1215", "672", "17010", "162", "2 ...

# %%
dtedad
# Out:
#          Edad  Mujeres  Hombres  ...  Hospital   Casa    Total
# 0        Edad  Mujeres  Hombres  ...  Hospital   Casa    Total
# 1                                ...      None   None     None
# 2       0 a 9    22034    23138  ...      1023   1506    45172
# 3     10 a 19    43412    43753  ...       484   3550    87165
# 4     20 a 29   155295   145124  ...      1502  12232   300419
# 5     30 a 39   156810   161717  ...      1999  12219   318527
# 6     40 a 49   111484   110654  ...      2188   8386   222138
# 7     50 a 59    92832    89590  ...      3159   6879   182422
# 8     60 a 69    54972    55538  ...      3330   3935   110510
# 9     70 a 79    28658    30594  ...      2486   1839    59252
# 10    80 a 89    15418    14795  ...      1371    819    30213
# 11    90 a 99     3426     2756  ...       236    156     6182
# 12  100 a 109      149       97  ...        12      5      246
# 13  110 a 119        1        2  ...         0      1        3
# 14    Totales   684491   677758  ...     17790  51527  1362249
#
# [15 rows x 9 columns]

# %%
dedad = dtedad.drop([0, 1, 14],axis=0)

# %%
dedad.Fallecidos=pd.to_numeric(dedad.Fallecidos)
dedad.Mujeres=pd.to_numeric(dedad.Mujeres)
dedad.Hombres=pd.to_numeric(dedad.Hombres)
dedad.Recuperados=pd.to_numeric(dedad.Recuperados)
dedad.Críticos=pd.to_numeric(dedad.Críticos)
dedad.Hospital=pd.to_numeric(dedad.Hospital)

# %%
##dtciudad.plot(x="Ciudad", y="Casos")
##plt.plot(dedad["Edad"],dedad["Mujeres"])
##plt.show()

fig = go.Figure(data=[
    go.Bar(name='Mujeres', x=dedad["Edad"],y=dedad["Mujeres"]),
    go.Bar(name='Hombres', x=dedad["Edad"],y=dedad["Hombres"])
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="af07489b-0a9e-43a1-9903-cce43763c075" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("af07489b-0a9e-43a1-9903-cce43763c075")) {
#                     Plotly.newPlot(
#                         'af07489b-0a9e-43a1-9903-cce43763c075',
#                         [{"name": "Mujeres", "type": "bar", "x": ["0 a 9", "10 a 19", "20 a 29", "30 a 39", "40 a 49", "50 a 59", "60 a 69", "70 a 79", "80 a 89", "90 a 99", "100 a 109", "110 a 119"], "y": [22034, 43412, 155295, 156810, 111484, 92832, 54972, 28658, 15418, 3426, 149, 1]}, {"name": "Hombres", "type": "bar", "x": ["0 a 9", "10 a 19", "20 a 29", "30 a 39", "40 a 49", "50 a 59", "60 a 69", "70 a 79", "80 a 89", "90 a 99", "100 a 109", "110 a 119"], "y": [23138, 43753, 145124, 161717, 110654, 89590, 55538, 30594, 14795, 2756, 97, 2]}],
#                         {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"mark ...

# %%
fig = go.Figure(data=[
    go.Bar(name='Hospital', x=dedad["Edad"],y=dedad["Hospital"]),
    go.Bar(name='Casa', x=dedad["Edad"],y=dedad["Casa"])
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9dba973b-e51e-44f2-99a4-fc0c8955d25a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9dba973b-e51e-44f2-99a4-fc0c8955d25a")) {
#                     Plotly.newPlot(
#                         '9dba973b-e51e-44f2-99a4-fc0c8955d25a',
#                         [{"name": "Hospital", "type": "bar", "x": ["0 a 9", "10 a 19", "20 a 29", "30 a 39", "40 a 49", "50 a 59", "60 a 69", "70 a 79", "80 a 89", "90 a 99", "100 a 109", "110 a 119"], "y": [1023, 484, 1502, 1999, 2188, 3159, 3330, 2486, 1371, 236, 12, 0]}, {"name": "Casa", "type": "bar", "x": ["0 a 9", "10 a 19", "20 a 29", "30 a 39", "40 a 49", "50 a 59", "60 a 69", "70 a 79", "80 a 89", "90 a 99", "100 a 109", "110 a 119"], "y": ["1506", "3550", "12232", "12219", "8386", "6879", "3935", "1839", "819", "156", "5", "1"]}],
#                         {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"mark ...

# %%
import plotly.express as px

fig = px.pie(dedad, values='Recuperados', names='Edad')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f268e25e-dd29-4ddb-83ad-58ed0a360ad9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f268e25e-dd29-4ddb-83ad-58ed0a360ad9")) {
#                     Plotly.newPlot(
#                         'f268e25e-dd29-4ddb-83ad-58ed0a360ad9',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "Edad=%{label}<br>Recuperados=%{value}", "labels": ["0 a 9", "10 a 19", "20 a 29", "30 a 39", "40 a 49", "50 a 59", "60 a 69", "70 a 79", "80 a 89", "90 a 99", "100 a 109", "110 a 119"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [42459, 82988, 286039, 302954, 208854, 166659, 93348, 43852, 19007, 3404, 136, 2]}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
import plotly.express as px

fig = px.pie(dedad, values='Fallecidos', names='Edad', hole=.3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8b5313e6-de4b-46c7-98a6-bf6802ec7400" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8b5313e6-de4b-46c7-98a6-bf6802ec7400")) {
#                     Plotly.newPlot(
#                         '8b5313e6-de4b-46c7-98a6-bf6802ec7400',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.3, "hoverlabel": {"namelength": 0}, "hovertemplate": "Edad=%{label}<br>Fallecidos=%{value}", "labels": ["0 a 9", "10 a 19", "20 a 29", "30 a 39", "40 a 49", "50 a 59", "60 a 69", "70 a 79", "80 a 89", "90 a 99", "100 a 109", "110 a 119"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [57, 54, 412, 1027, 2221, 4852, 8662, 9915, 8183, 2172, 78, 0]}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
dtdepartamento
# Out:
#        Departamento   Casos
# 0      Departamento   Casos
# 1          AMAZONAS    3159
# 2         ANTIOQUIA  220859
# 3            ARAUCA    4201
# 4         ATLANTICO   33373
# 5      BARRANQUILLA   46532
# 6            BOGOTA  387418
# 7           BOLIVAR    7301
# 8            BOYACA   22862
# 9            CALDAS   26489
# 10          CAQUETA   13619
# 11        CARTAGENA   32999
# 12         CASANARE    7296
# 13            CAUCA   16206
# 14            CESAR   30391
# 15            CHOCO    4563
# 16          CORDOBA   28486
# 17     CUNDINAMARCA   54753
# 18          GUAINIA    1210
# 19          GUAJIRA   12357
# 20         GUAVIARE    1863
# 21            HUILA   30870
# 22        MAGDALENA    6802
# 23             META   29074
# 24           NARIÑO   26186
# 25  NORTE SANTANDER   30733
# 26         PUTUMAYO    5103
# 27          QUINDIO   18179
# 28        RISARALDA   24619
# 29       SAN ANDRES    2239
# 30        SANTANDER   55434
# 31   STA MARTA D.E.   14279
# 32            SUCRE   16714
# 33           TOLIMA   31353
# 34            VALLE  112671
# 35           VAUPES    1123
# 36          VICHADA     933

# %%
ddepartamento = dtdepartamento.drop([0],axis=0)

# %%
fig = go.Figure(data=[
    go.Bar(name='Departamento', x=ddepartamento["Departamento"],y=ddepartamento["Casos"])
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1f121991-6680-4711-906d-50e868bd62e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1f121991-6680-4711-906d-50e868bd62e8")) {
#                     Plotly.newPlot(
#                         '1f121991-6680-4711-906d-50e868bd62e8',
#                         [{"name": "Departamento", "type": "bar", "x": ["AMAZONAS", "ANTIOQUIA", "ARAUCA", "ATLANTICO", "BARRANQUILLA", "BOGOTA", "BOLIVAR", "BOYACA", "CALDAS", "CAQUETA", "CARTAGENA", "CASANARE", "CAUCA", "CESAR", "CHOCO", "CORDOBA", "CUNDINAMARCA", "GUAINIA", "GUAJIRA", "GUAVIARE", "HUILA", "MAGDALENA", "META", "NARI\u00d1O", "NORTE SANTANDER", "PUTUMAYO", "QUINDIO", "RISARALDA", "SAN ANDRES", "SANTANDER", "STA MARTA D.E.", "SUCRE", "TOLIMA", "VALLE", "VAUPES", "VICHADA"], "y": ["3159", "220859", "4201", "33373", "46532", "387418", "7301", "22862", "26489", "13619", "32999", "7296", "16206", "30391", "4563", "28486", "54753", "1210", "12357", "1863", "30870", "6802", "29074", "26186", "30733", "5103", "18179", "24619", "2239", "55434", "14279", "16714", "31353", "112671", "1123", "933"]}],
#                         {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"mark ...

# %%
pip install dask[dataframe]
# Out:
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.6/dist-packages (2.12.0)
# Requirement already satisfied: toolz>=0.7.3; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (0.11.1)
# Requirement already satisfied: pandas>=0.23.0; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (1.1.4)
# Requirement already satisfied: partd>=0.3.10; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (1.1.0)
# Requirement already satisfied: numpy>=1.13.0; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (1.18.5)
# Requirement already satisfied: fsspec>=0.6.0; extra == "dataframe" in /usr/local/lib/python3.6/dist-packages (from dask[dataframe]) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (2018.9)
# Requirement already satisfied: locket in /usr/local/lib/python3.6/dist-packages (from partd>=0.3.10; extra == "dataframe"->dask[dataframe]) (0.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.0; extra == "dataframe"->dask[dataframe]) (1.15.0)

# %%
# to suppress future warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import dask.dataframe as dd

# %%
dedad.describe().T
# Out:
#              count           mean            std  ...      50%        75%       max
# Mujeres       12.0   57040.916667   58130.852835  ...  36035.0   97495.00  156810.0
# Hombres       12.0   56479.833333   57129.065766  ...  37173.5   94856.00  161717.0
# Recuperados   12.0  104141.833333  110596.682275  ...  63420.0  177207.75  302954.0
# Fallecidos    12.0    3136.083333    3774.408863  ...   1599.5    5684.75    9915.0
# Críticos      12.0     199.000000     208.584406  ...    126.5     317.50     582.0
# Hospital      12.0    1482.500000    1172.810029  ...   1436.5    2262.50    3330.0
#
# [6 rows x 8 columns]

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sms
# Separar dependiendo un porcentaje, grupo de entrenamiento y grupo de prueba
from sklearn.model_selection import train_test_split
# Modelo de regresión lineal
from sklearn.linear_model import LinearRegression
# Métricas de evaluacion
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import math

# %%
matrixCorrelacion= dedad.corr()

# %%
matrixCorrelacion
# Out:
#               Mujeres   Hombres  Recuperados  Fallecidos  Críticos  Hospital
# Mujeres      1.000000  0.998219     0.998713   -0.135089  0.286347  0.518631
# Hombres      0.998219  1.000000     0.998436   -0.128177  0.296045  0.526960
# Recuperados  0.998713  0.998436     1.000000   -0.175199  0.253334  0.488038
# Fallecidos  -0.135089 -0.128177    -0.175199    1.000000  0.759141  0.664935
# Críticos     0.286347  0.296045     0.253334    0.759141  1.000000  0.955835
# Hospital     0.518631  0.526960     0.488038    0.664935  0.955835  1.000000

# %%
sms.heatmap(dedad.corr(), cmap="Blues" , fmt='g')

# %%
# En función del valor de correlación (umbral), se presenta una relación entre las variables
# Hacer una función que me selecciones las features según un "umbral"
def relacionFeatures(corrMatrix, umbral):
  feature = []
  valores = []

  for i, index in enumerate(corrMatrix.index):
    if abs(corrMatrix[index]) > umbral:
      feature.append(index)
      valores.append(corrMatrix[index])

  df = pd.DataFrame(data = valores, index = feature, columns=['Valor de Correlación'])
  return df

# %%
#Función que devuelva un dataframe con las métricas de rendimiento ['nombre features', 'valorCorrelacion', 'r2_score', 'MAE',  'MSE']

def Metricas(umbral):

  # Se seleccionan las  features según el umbral
  valorCorrelacion = relacionFeatures(matrixCorrelacion['Recuperados'], umbral)

  # Se obtiene y se envia al dataset el valor de la correlación
  dataCorrelacion = dedad[valorCorrelacion.index]
  y_predict,y_test = entrenamiento(dataCorrelacion)
  
  #Se evaluan los datos en el modelo
  puntuacion = r2_score(y_test, y_predict)
  MAE= mean_absolute_error(y_test, y_predict)
  MSE = mean_squared_error(y_test, y_predict)
  
  #Se agregan las metricas de rendimiento
  dataCorrelacion['r2_score']=puntuacion
  dataCorrelacion['Mean Absolute Error']=MAE
  dataCorrelacion['Mean Squared Error']=MSE
  return dataCorrelacion.head()

# %%
#Función que entrene el modelo y devuelva el y_predict directamente
def entrenamiento(dataCorrelacion):
  X = dataCorrelacion.drop('Recuperados', axis=1)
  y = dataCorrelacion['Recuperados']

  #Dividir en conjunto de train y test
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

  # Selección del Modelo Lineal
  modelo = LinearRegression()

  # Entrenar el modelo
  
  modelo.fit(X_train, y_train)

  # Variables de predicción
  y_predict_train = modelo.predict(X_train)
  y_predict = modelo.predict(X_test)
  return y_predict,y_test

# %%
#EL UMBRAL PARA ESTE SERA DE 0.7
Metricas(0.7)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Mujeres  Hombres  ...  Mean Absolute Error  Mean Squared Error
# 2    22034    23138  ...          4350.019907        2.975808e+07
# 3    43412    43753  ...          4350.019907        2.975808e+07
# 4   155295   145124  ...          4350.019907        2.975808e+07
# 5   156810   161717  ...          4350.019907        2.975808e+07
# 6   111484   110654  ...          4350.019907        2.975808e+07
#
# [5 rows x 6 columns]

# %%
#Se hace la regresión lineal, con la inversión realizada en innovación
#### REGRESIÓN MULTIVARIABLE ####

# El modelo de regresión lineal
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model

x = dedad['Hombres'].values.reshape(-1, 1)
y = dedad['Recuperados'].values.reshape(-1, 1)
regresionLinear = linear_model.LinearRegression()
regresionLinear.fit(x,y)
y_predit=regresionLinear.predict(x)

# %%
print("Mean Squared Error Hombres:",mean_squared_error(y, y_predit))
# Out:
# Mean Squared Error Hombres: 35040986.68934422

# %%
## la idea es seleccionar las variables segun el umbral de correlacion
## se desea identificar la multicolinealidad
## variable target es 'Profit'
## umbral 0.7

umbral = 0.7
valorcorrelacion = relacionFeatures(matrixCorrelacion['Recuperados'],umbral)
valorcorrelacion
# Out:
#              Valor de Correlación
# Mujeres                  0.998713
# Hombres                  0.998436
# Recuperados              1.000000

# %%
## se hace un analisis estadistico
## Importar las librerias necesarias

import statsmodels.api as sample_data
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Seleccionar las features según el umbral
valorCorrelacion = relacionFeatures(matrixCorrelacion['Recuperados'], 0.7)
  
# Se transforma el valor de correlacion
dataCorrelacion = dedad[valorCorrelacion.index]

# Se ajusta a un modelo de Regresión Lineal
X = dataCorrelacion.drop('Recuperados', axis=1)
y = dataCorrelacion['Recuperados']

pd.DataFrame([[var, variance_inflation_factor(X.values,X.columns.get_loc(var))] for var in X.columns],
             index=range(X.shape[1]), columns=['Variable','VIF'])
# Out:
#   Variable         VIF
# 0  Mujeres  573.310787
# 1  Hombres  573.310787

# %%
import numpy as np

# %%
def plot_learning_curve(estimator, title, X, y, axes=None, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)

    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y,
                                                            cv=cv, n_jobs=n_jobs,
                                                            train_sizes=train_sizes)
    
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    
    plt.grid()

    # Plot learning curve
    
    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                         train_scores_mean + train_scores_std, alpha=0.1,
                         color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                         test_scores_mean + test_scores_std, alpha=0.1,
                         color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
                 label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
                 label="Cross-validation score")
    plt.legend(loc="best")

    return plt

# %%
## Importar las librerias necesarias
from sklearn.model_selection import learning_curve, ShuffleSplit

# %%
# Seleccionar las features según el umbral
valorCorrelacion = relacionFeatures(matrixCorrelacion['Recuperados'], 0.7)
  
# Se transforma el valor de correlacion
dataCorrelacion = dedad[valorCorrelacion.index]

# Se ajusta a un modelo de Regresión Lineal
X = dataCorrelacion.drop('Recuperados', axis=1)
y = dataCorrelacion['Recuperados']

title = 'Curvas de aprendizaje'+ str(X.columns.values)
cv = ShuffleSplit(n_splits=100, test_size = 0.25)
estimador = LinearRegression()
plot_learning_curve(estimador,title,X,y,cv,n_jobs=1)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_regression.py:582: UndefinedMetricWarning:
#
# R^2 score is not well-defined with less than two samples.
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_regression.py:582: UndefinedMetricWarning:
#
# R^2 score is not well-defined with less than two samples.
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_regression.py:582: UndefinedMetricWarning:
#
# R^2 score is not well-defined with less than two samples.
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_regression.py:582: UndefinedMetricWarning:
#
# R^2 score is not well-defined with less than two samples.
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_regression.py:582: UndefinedMetricWarning:
#
# R^2 score is not well-defined with less than two samples.

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd  
import csv

url = "https://raw.githubusercontent.com/Jruedagutirrez/analisisdesenales/main/osbcovid19_Abril20.csv"
data = pd.read_csv(url, encoding = "ISO-8859-1")
data_copy=data.copy()

# %%
cantidad_contagiados=len(data)
print('cantidad de contagiados por COVID en Bogota:', cantidad_contagiados)

cantidad_contagiados_M=len(data[(data["Sexo"]=="M")])
print('cantidad de hombres contagiados por COVID:', cantidad_contagiados_M, '(',cantidad_contagiados_M*100/cantidad_contagiados, '%)')

cantidad_contagiados_F=len(data[(data["Sexo"]=="F")])
print('cantidad de mujeres contagiadas por COVID:', cantidad_contagiados_F, '(',cantidad_contagiados_F*100/cantidad_contagiados, '%)')
# Out:
# cantidad de contagiados por COVID en Bogota: 1597
# cantidad de hombres contagiados por COVID: 779 ( 48.77896055103319 %)
# cantidad de mujeres contagiadas por COVID: 818 ( 51.22103944896681 %)

# %%
registro=len(data)
data.head(registro)
# Out:
#      Fecha de diagnóstico Ciudad de residencia  ... Ubicación    Estado
# 0               6/03/2020               Bogotá  ...      Casa  Moderado
# 1              10/03/2020               Bogotá  ...      Casa  Moderado
# 2              10/03/2020               Bogotá  ...      Casa  Moderado
# 3              12/03/2020               Bogotá  ...      Casa  Moderado
# 4              12/03/2020               Bogotá  ...      Casa  Moderado
# ...                   ...                  ...  ...       ...       ...
# 1592           16/04/2020               Bogotá  ...      Casa  Moderado
# 1593           18/04/2020               Bogotá  ...      Casa  Moderado
# 1594           18/04/2020               Bogotá  ...      Casa  Moderado
# 1595           18/04/2020               Bogotá  ...      Casa  Moderado
# 1596           18/04/2020               Bogotá  ...      Casa  Moderado
#
# [1597 rows x 8 columns]

# %%
ax=data.hist('Edad', bins=np.int((max(data['Edad']) - min(data['Edad']) + 1)))
print('Casos contagio COVID-19 en Bogotá por edad')
# Out:
# Casos contagio COVID-19 en Bogotá por edad

# %%
data_fallecidos=data[(data["Estado"]=="Fallecido")]
print('Cantidad de fallecidos por COVID-19 en Bogotá:', len(data_fallecidos))
# Out:
# Cantidad de fallecidos por COVID-19 en Bogotá: 67

# %%
url = "https://raw.githubusercontent.com/Jruedagutirrez/analisisdesenales/main/dataset_covid_localidades_bogota.csv"
dataloc = pd.read_csv(url, encoding = "ISO-8859-1" , sep=';', index_col=0)
dataloc.head()
# Out:
#         Localidad  Femenino  Masculino
# Id
# 1         Usaquén     12123      10657
# 2       Chapinero      4312       4251
# 3        Santa Fe      3110       3268
# 4   San Cristobal      9704       8969
# 5            Usme      7846       6673

# %%
dataloc
# Out:
#           Localidad  Femenino  Masculino
# Id
# 1           Usaquén     12123      10657
# 2         Chapinero      4312       4251
# 3          Santa Fe      3110       3268
# 4     San Cristobal      9704       8969
# 5              Usme      7846       6673
# 6        Tunjuelito      5057       4872
# 7              Bosa     16120      14213
# 8           Kennedy     25701      23375
# 9          Fontibón      9201       8290
# 10         Engativá     20777      18953
# 11             Suba     26839      23523
# 12   Barrios Unidos      4282       3211
# 13      Teusaquillo      3710       2647
# 14     Los Mártires      2360       2645
# 15   Antonio Nariño      2726       2471
# 16    Puente Aranda      7299       7932
# 17    La candelaria       699        916
# 18     Rafael Uribe      8867       9604
# 19   Ciudad Bolivar     13289      11758
# 20          Sumapaz         5          0
# 21  Fuera de bogota      1313       1691
# 22         Sin Dato     15617      15542

# %%
dataloc.Femenino=pd.to_numeric(dataloc.Femenino)
dataloc.Masculino=pd.to_numeric(dataloc.Masculino)

# %%
import plotly.express as px

fig = px.bar(dataloc, x="Femenino", y="Localidad", color='Femenino', orientation='h',
             hover_data=["Localidad", "Femenino"],
             height=400,
             title='Femenino / Localidad / Covid-19')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6c392a48-9cba-458b-b6a2-0dadf631b3b5" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6c392a48-9cba-458b-b6a2-0dadf631b3b5")) {
#                     Plotly.newPlot(
#                         '6c392a48-9cba-458b-b6a2-0dadf631b3b5',
#                         [{"alignmentgroup": "True", "customdata": [["Usaqu\u00e9n", 12123], ["Chapinero", 4312], ["Santa Fe", 3110], ["San Cristobal", 9704], ["Usme", 7846], ["Tunjuelito", 5057], ["Bosa", 16120], ["Kennedy", 25701], ["Fontib\u00f3n", 9201], ["Engativ\u00e1", 20777], ["Suba", 26839], ["Barrios Unidos", 4282], ["Teusaquillo", 3710], ["Los M\u00e1rtires", 2360], ["Antonio Nari\u00f1o", 2726], ["Puente Aranda", 7299], ["La candelaria", 699], ["Rafael Uribe", 8867], ["Ciudad Bolivar", 13289], ["Sumapaz", 5], ["Fuera de bogota", 1313], ["Sin Dato", 15617]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Femenino=%{marker.color}<br>Localidad=%{customdata[0]}", "legendgroup": "", "marker": {"color": [12123, 4312, 3110, 9704, 7846, 5057, 16120, 25701, 9201, 20777, 26839, 4282, 3710, 2360, 2726, 7299, 699, 8867, 13289, 5, 1313, 15617], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [12123, 4312, 3110, 9704, 7846, 5057, 16120, 25701, 9201, 20777, 26839, 4282, 3710, 2360, 2726, 7299, 699, 8867, 13289, 5, 1313, 15617], "xaxis": "x", "y": ["Usaqu\u00e9n", "Chapinero", "Santa Fe", "San Cristobal", "Usme", "Tunjuelito", "Bosa", "Kennedy", "Fontib\u00f3n", "Engativ\u00e1", "Suba", "Barrios Unidos", "Teusaquillo", "Los M\u00e1rtires", "Antonio Nari\u00f1o", "Puente Aranda", "La candelaria", "Rafael Uribe", "Ciudad Bolivar", "Sumapaz", "Fuera de bogota", "Sin Dato"], "yaxis": "y"}],
#                         {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Femenino"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scatte ...

# %%
fig = px.bar(dataloc, x="Masculino", y="Localidad", color='Masculino', orientation='h',
             hover_data=["Localidad", "Masculino"],
             height=400,
             title='Masculino / Localidad / Covid-19')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a21e4bea-73a1-477d-b67d-9608728280dd" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a21e4bea-73a1-477d-b67d-9608728280dd")) {
#                     Plotly.newPlot(
#                         'a21e4bea-73a1-477d-b67d-9608728280dd',
#                         [{"alignmentgroup": "True", "customdata": [["Usaqu\u00e9n", 10657], ["Chapinero", 4251], ["Santa Fe", 3268], ["San Cristobal", 8969], ["Usme", 6673], ["Tunjuelito", 4872], ["Bosa", 14213], ["Kennedy", 23375], ["Fontib\u00f3n", 8290], ["Engativ\u00e1", 18953], ["Suba", 23523], ["Barrios Unidos", 3211], ["Teusaquillo", 2647], ["Los M\u00e1rtires", 2645], ["Antonio Nari\u00f1o", 2471], ["Puente Aranda", 7932], ["La candelaria", 916], ["Rafael Uribe", 9604], ["Ciudad Bolivar", 11758], ["Sumapaz", 0], ["Fuera de bogota", 1691], ["Sin Dato", 15542]], "hoverlabel": {"namelength": 0}, "hovertemplate": "Masculino=%{marker.color}<br>Localidad=%{customdata[0]}", "legendgroup": "", "marker": {"color": [10657, 4251, 3268, 8969, 6673, 4872, 14213, 23375, 8290, 18953, 23523, 3211, 2647, 2645, 2471, 7932, 916, 9604, 11758, 0, 1691, 15542], "coloraxis": "coloraxis"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": [10657, 4251, 3268, 8969, 6673, 4872, 14213, 23375, 8290, 18953, 23523, 3211, 2647, 2645, 2471, 7932, 916, 9604, 11758, 0, 1691, 15542], "xaxis": "x", "y": ["Usaqu\u00e9n", "Chapinero", "Santa Fe", "San Cristobal", "Usme", "Tunjuelito", "Bosa", "Kennedy", "Fontib\u00f3n", "Engativ\u00e1", "Suba", "Barrios Unidos", "Teusaquillo", "Los M\u00e1rtires", "Antonio Nari\u00f1o", "Puente Aranda", "La candelaria", "Rafael Uribe", "Ciudad Bolivar", "Sumapaz", "Fuera de bogota", "Sin Dato"], "yaxis": "y"}],
#                         {"barmode": "relative", "coloraxis": {"colorbar": {"title": {"text": "Masculino"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}, "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scatt ...
